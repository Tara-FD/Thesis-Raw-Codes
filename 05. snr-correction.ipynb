# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('group_T1w.tsv', sep='\t')

# %%
df.head()
# Out:
#                 bids_name       cjv       cnr       efc         fber  \
# 0  sub-0015_ses-wave1_T1w  0.350552  3.618620  0.643811   372.756683
# 1  sub-0015_ses-wave2_T1w  0.303827  4.125028  0.647729   472.670258
# 2  sub-0015_ses-wave3_T1w  0.317308  4.126958  0.537321  2532.179932
# 3  sub-0071_ses-wave1_T1w  0.368763  3.529735  0.623246   531.137207
# 4  sub-0085_ses-wave2_T1w  0.360801  3.248856  0.644359   644.782776
#
#    fwhm_avg    fwhm_x    fwhm_y    fwhm_z  icvs_csf  ...  summary_wm_mean  \
# 0  3.804095  3.932967  3.861448  3.617870  0.146626  ...       995.921570
# 1  3.679930  3.813922  3.749955  3.475912  0.144715  ...       997.602539
# 2  4.129593  4.204022  4.018734  4.166022  0.172050  ...       995.745911
# 3  3.832442  3.962122  3.860324  3.674880  0.156935  ...       998.345947
# 4  3.562156  3.651478  3.614920  3.420071  0.161303  ...       997.301331
#
#    summary_wm_median  summary_wm_n  summary_wm_p05  summary_wm_p95  \
# ...

# %%
df.plot(x='bids_name', y='snr_total', kind='scatter')
# Out:
# <AxesSubplot:xlabel='bids_name', ylabel='snr_total'>

# %% [markdown]
# ### finding outlayers

# %%
outlayer = df['snr_total'] < 9
df2 = df[outlayer]

# %%
df2.plot(x='bids_name', y='snr_total', kind='scatter')
# Out:
# <AxesSubplot:xlabel='bids_name', ylabel='snr_total'>

# %%
df2.to_csv(r'/media/tara/HD710PRO/Thesis/snr-corrected.tsv', index = False)

# %%
df2
# Out:
#                          bids_name       cjv       cnr       efc        fber  \
# 92   sub-1705_ses-wave1_run-01_T1w  0.729209  1.767522  0.720579   91.460732
# 144  sub-2442_ses-wave1_run-01_T1w  0.620850  2.115478  0.689680  227.490234
# 172  sub-2670_ses-wave2_run-01_T1w  0.811232  1.659653  0.720665  159.651398
# 213  sub-4332_ses-wave1_run-01_T1w  0.830798  1.515808  0.686592  284.121185
# 259  sub-4939_ses-wave1_run-01_T1w  0.732982  1.540401  0.774169   40.083157
# 260  sub-4939_ses-wave1_run-02_T1w  0.735975  1.726892  0.684547  220.861893
#
#      fwhm_avg    fwhm_x    fwhm_y    fwhm_z  icvs_csf  ...  summary_wm_mean  \
# 92   4.635590  4.676511  4.735098  4.495160  0.206316  ...      1009.507446
# 144  4.251639  4.361067  4.223677  4.170173  0.191766  ...      1005.799255
# 172  4.233436  4.260145  4.338643  4.101521  0.196501  ...      1008.265747
# 213  4.865491  4.903689  4.895911  4.796872  0.217517  ...      1011.912903
# ...

# %%
df2["bids_name"] = df2["bids_name"].str.split("_")
# Out:
# <ipython-input-31-dd3f26d0a641>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["bids_name"] = df2["bids_name"].str.split("_")

# %%
df2.insert(1, "subject", "0")
df2.insert(2, "wave", "0")
df2.head()
# Out:
#                               bids_name subject wave       cjv       cnr  \
# 92   [sub-1705, ses-wave1, run-01, T1w]       0    0  0.729209  1.767522
# 144  [sub-2442, ses-wave1, run-01, T1w]       0    0  0.620850  2.115478
# 172  [sub-2670, ses-wave2, run-01, T1w]       0    0  0.811232  1.659653
# 213  [sub-4332, ses-wave1, run-01, T1w]       0    0  0.830798  1.515808
# 259  [sub-4939, ses-wave1, run-01, T1w]       0    0  0.732982  1.540401
#
#           efc        fber  fwhm_avg    fwhm_x    fwhm_y  ...  summary_wm_mean  \
# 92   0.720579   91.460732  4.635590  4.676511  4.735098  ...      1009.507446
# 144  0.689680  227.490234  4.251639  4.361067  4.223677  ...      1005.799255
# 172  0.720665  159.651398  4.233436  4.260145  4.338643  ...      1008.265747
# 213  0.686592  284.121185  4.865491  4.903689  4.895911  ...      1011.912903
# 259  0.774169   40.083157  4.823345  4.824689  4.870823  ...      1014.342102
#
# ...

# %%
df2=df2.reset_index(drop=True)
for i in range(df2.shape[0]):
    df2["subject"][i] = df2["bids_name"][i][0]
    df2["wave"][i] = df2["bids_name"][i][1]
# Out:
# <ipython-input-33-57e80a71db2d>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["subject"][i] = df2["bids_name"][i][0]
# <ipython-input-33-57e80a71db2d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["wave"][i] = df2["bids_name"][i][1]

# %%
df2
# Out:
#                             bids_name   subject       wave       cjv  \
# 0  [sub-1705, ses-wave1, run-01, T1w]  sub-1705  ses-wave1  0.729209
# 1  [sub-2442, ses-wave1, run-01, T1w]  sub-2442  ses-wave1  0.620850
# 2  [sub-2670, ses-wave2, run-01, T1w]  sub-2670  ses-wave2  0.811232
# 3  [sub-4332, ses-wave1, run-01, T1w]  sub-4332  ses-wave1  0.830798
# 4  [sub-4939, ses-wave1, run-01, T1w]  sub-4939  ses-wave1  0.732982
# 5  [sub-4939, ses-wave1, run-02, T1w]  sub-4939  ses-wave1  0.735975
#
#         cnr       efc        fber  fwhm_avg    fwhm_x    fwhm_y  ...  \
# 0  1.767522  0.720579   91.460732  4.635590  4.676511  4.735098  ...
# 1  2.115478  0.689680  227.490234  4.251639  4.361067  4.223677  ...
# 2  1.659653  0.720665  159.651398  4.233436  4.260145  4.338643  ...
# 3  1.515808  0.686592  284.121185  4.865491  4.903689  4.895911  ...
# 4  1.540401  0.774169   40.083157  4.823345  4.824689  4.870823  ...
# ...

# %%
import nilearn as nl
from nilearn import image

# %%
img = image.load_img('/media/tara/HD710PRO/Thesis/NICAP_ADHD_sleep_DATA(fd)/sub-0015/ses-wave3/func/sub-0015_ses-wave3_task-rest_bold.nii.gz')

# %%
img.shape[3]
# Out:
# 250
