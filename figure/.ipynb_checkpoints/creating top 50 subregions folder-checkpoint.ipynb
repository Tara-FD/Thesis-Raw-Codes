# %%
import pandas as pd
import numpy as np
import os 
import shutil 
import fsl.wrappers as fsl

# %%
df = pd.read_csv('top50feat.csv')

# %%
df["Measurment"] = [meas.split("_")[0] for meas in df["region"]]

# %%
df["region"] = ["_".join(meas.split("_")[1:]) for meas in df["region"]]

# %%
reho = df[df["Measurment"]=="ReHo"]

# %%
sch_regions = pd.read_csv("Schaefer2018_400Parcels_17Networks_order_FSLMNI152_1mm.Centroid_RAS.csv").set_index("ROI Name")

# %%
BN_regions = pd.read_csv('BN_Atlas_246_LUT_text.csv').set_index("ROI_Name")
#BN_regions

# %%
Buck_regions = pd.read_csv('atl-Buckner17.csv').set_index('name')
Buck_regions
# Out:
#             index    color
# name
# Network_1       1  #b52bd4
# Network_2       2  #ff0000
# Network_3       3  #a1e1ff
# Network_4       4  #6cffc2
# Network_5       5  #4ac33b
# Network_6       6  #1f911b
# Network_7       7  #ff77ff
# Network_8       8  #ffacd2
# Network_9       9  #f4ffc4
# Network_10     10  #9ebc46
# Network_11     11  #99acc6
# Network_12     12  #f9a41e
# Network_13     13  #cd466a
# Network_14     14  #aeb8ff
# Network_15     15  #3334ff
# Network_16     16  #ffff00
# Network_17     17  #ff7d82

# %%
#sch_regions

# %%
for i, region in enumerate(reho["region"]):
    if (region.find("17Network") != -1) and ( len(region) != 12 ):
        value = sch_regions.loc[[region], "ROI Label"].values[0]
        name = 'reho/'+region+'.nii.gz'
        imp = reho.iloc[[i], 1].values[0]*100
        fsl.fslmaths('Schaefer2018_400Parcels_17Networks_order_FSLMNI152_2mm.nii').thr(value-0.1).uthr(value+0.1).run(name)
        fsl.fslmaths(name).bin().mul(imp).run(name)
        
        
    if (region.find("17Network") == -1):
        value = BN_regions.loc[[region], "Value"].values[0]
        name = 'reho/'+region+'.nii.gz'
        imp = reho.iloc[[i], 1].values[0]*100
        fsl.fslmaths('BN_Atlas_246_2mm.nii.gz').thr(value-0.1).uthr(value+0.1).run(name)
        fsl.fslmaths(name).bin().mul(imp).run(name)
        
                
    if (region.find("17Network") != -1) and ( len(region) == 12 ):
        value = Buck_regions.loc[[region], "index"].values[0]
        name = 'reho/'+region+'.nii.gz'
        imp = reho.iloc[[i], 1].values[0]*100
        fsl.fslmaths('atl-Buckner17_space-MNI_dseg.nii').thr(value-0.1).uthr(value+0.1).run(name)
        fsl.fslmaths(name).bin().mul(imp).run(name)
# Out:
# terminate called after throwing an instance of 'NiftiIO::NiftiException'
#   what():  Error: cant open file reho/17Networks_LH_ContA_IPS_2.nii.gz
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-164-e4695dca7a89> in <module>
#       4         name = 'reho/'+region+'.nii.gz'
#       5         imp = reho.iloc[[i], 1].values[0]*100
# ----> 6         fsl.fslmaths('Schaefer2018_400Parcels_17Networks_order_FSLMNI152_2mm.nii').thr(value-0.1).uthr(value+0.1).run(name)
#       7         fsl.fslmaths(name).bin().mul(imp).run(name)
#       8
#
# ~/Programming/env/lib/python3.8/site-packages/fsl/wrappers/fslmaths.py in run(self, output)
#     186
#     187         cmd   += [output]
# --> 188         result = self.__run(*cmd)
#     189
#     190         # if output is LOADed, there
#
# ~/Programming/env/lib/python3.8/site-packages/fsl/wrappers/wrapperutils.py in wrapper(*args, **kwargs)
#    1092
#    1093         def wrapper(*args, **kwargs):
# -> 1094             result = fot(*args, **kwargs)
#    1095             intypes[:] = []
#    1096             return result
#
# ~/Programming/env/lib/python3.8/site-packages/fsl/wrappers/wrapperutils.py in __call__(self, *args, **kwargs)
#     754             # Call the function
#     755             try:
# --> 756                 result = func(*args, **kwargs)
#     757
#     758             finally:
#
# ~/Programming/env/lib/python3.8/site-packages/fsl/wrappers/wrapperutils.py in wrapper(*args, **kwargs)
#     195             cmd = func(*args, **kwargs)
#     196
# --> 197         return runner(cmd,
#     198                       stderr=stderr,
#     199                       log=log,
#
# ~/Programming/env/lib/python3.8/site-packages/fsl/utils/run.py in runfsl(*args, **kwargs)
#     388             args[0], ', '.join(prefixes)))
#     389
# --> 390     return run(*args, **kwargs)
#     391
#     392
#
# ~/Programming/env/lib/python3.8/site-packages/fsl/utils/run.py in run(*args, **kwargs)
#     227
#     228     if not returnExitcode and (exitcode != 0):
# --> 229         raise RuntimeError('{} returned non-zero exit code: {}'.format(
#     230             args[0], exitcode))
#     231
#
# RuntimeError: /usr/local/fsl/bin/fslmaths returned non-zero exit code: -6

# %% [markdown]
# ## fALFF

# %%
fALFF = df[df["Measurment"]=="fALFF"]
fALFF
# Out:
#                                 region  importance  importance2 Measurment
# 2      17Networks_LH_DorsAttnB_PostC_5    0.010299       0.0103      fALFF
# 4   17Networks_RH_SalVentAttnB_PFCmp_2    0.010002       0.0100      fALFF
# 5                              cHipp_L    0.009721       0.0097      fALFF
# 7     17Networks_LH_DefaultA_pCunPCC_7    0.009032       0.0091      fALFF
# 9          17Networks_RH_ContB_PFCld_3    0.008686       0.0087      fALFF
# 11    17Networks_LH_LimbicA_TempPole_5    0.008042       0.0080      fALFF
# 12             17Networks_LH_TempPar_1    0.008012       0.0080      fALFF
# 14   17Networks_RH_DorsAttnA_TempOcc_3    0.007888       0.0079      fALFF
# 15    17Networks_LH_LimbicA_TempPole_6    0.007854       0.0079      fALFF
# 17       17Networks_RH_DefaultA_PFCd_2    0.007761       0.0078      fALFF
# 18             17Networks_RH_SomMotA_4    0.007730       0.0077      fALFF
# 19                              Stha_R    0.007647       0.0076      fALFF
# 20     17Networks_RH_DorsAttnB_PostC_5    0.007632       0.0076      fALFF
# 21       17Networks_RH_DefaultB_Temp_1    0.007544       0.0075      fALFF
# 22             17Networks_RH_SomMotA_7    0.007452       0.0075      fALFF
# 24  17Networks_RH_SalVentAttnB_PFCmp_1    0.007315       0.0073      fALFF
# 28  17Networks_LH_SalVentAttnB_PFCmp_1    0.007176       0.0072      fALFF
# 30     17Networks_RH_DorsAttnB_PostC_3    0.007080       0.0071      fALFF
# 31  17Networks_RH_SalVentAttnB_PFClv_1    0.007056       0.0071      fALFF
# 32                             cTtha_L    0.007051       0.0071      fALFF
# 34         17Networks_RH_ContB_PFClv_4    0.006864       0.0069      fALFF
# 36    17Networks_LH_LimbicA_TempPole_1    0.006765       0.0068      fALFF
# 37                             rHipp_R    0.006720       0.0067      fALFF
# 38         17Networks_LH_ContA_PFClv_2    0.006693       0.0067      fALFF
# 39          17Networks_LH_ContA_PFCl_3    0.006639       0.0066      fALFF
# 40       17Networks_RH_DefaultA_PFCm_4    0.006629       0.0066      fALFF
# 42        17Networks_LH_SomMotB_Cent_3    0.006572       0.0066      fALFF
# 43                             rTtha_R    0.006568       0.0066      fALFF
# 44           17Networks_LH_ContA_IPS_1    0.006558       0.0066      fALFF
# 46  17Networks_RH_SalVentAttnA_FrMed_2    0.006360       0.0064      fALFF
# 47          17Networks_RH_ContA_PFCl_3    0.006343       0.0063      fALFF
# 48           17Networks_LH_ContA_IPS_3    0.006312       0.0063      fALFF

# %%
for i, region in enumerate(fALFF["region"]):
    if (region.find("17Network") != -1) and ( len(region) != 12 ):
        value = sch_regions.loc[[region], "ROI Label"].values[0]
        name = 'fALFF_subregions/'+region+'.nii.gz'
        imp = fALFF.iloc[[i], 1].values[0]*100
        fsl.fslmaths('Schaefer2018_400Parcels_17Networks_order_FSLMNI152_2mm.nii').thr(value-0.1).uthr(value+0.1).run(name)
        fsl.fslmaths(name).bin().mul(imp).run(name)
        
        
    if (region.find("17Network") == -1):
        value = BN_regions.loc[[region], "Value"].values[0]
        name = 'fALFF_subregions/'+region+'.nii.gz'
        imp = fALFF.iloc[[i], 1].values[0]*100
        fsl.fslmaths('BN_Atlas_246_2mm.nii.gz').thr(value-0.1).uthr(value+0.1).run(name)
        fsl.fslmaths(name).bin().mul(imp).run(name)
        
                
    if (region.find("17Network") != -1) and ( len(region) == 12 ):
        value = Buck_regions.loc[[region], "index"].values[0]
        name = 'fALFF_subregions/'+region+'.nii.gz'
        imp = fALFF.iloc[[i], 1].values[0]*100
        fsl.fslmaths('atl-Buckner17_space-MNI_dseg.nii').thr(value-0.1).uthr(value+0.1).run(name)
        fsl.fslmaths(name).bin().mul(imp).run(name)

# %% [markdown]
# ## DC

# %%
DC = df[df["Measurment"]=="DC"]
DC
# Out:
#                                  region  importance  importance2 Measurment
# 3    17Networks_LH_SalVentAttnA_FrMed_1    0.010067       0.0100         DC
# 6       17Networks_RH_DorsAttnB_PostC_8    0.009060       0.0091         DC
# 8            17Networks_RH_SomMotB_S2_3    0.008830       0.0088         DC
# 29  17Networks_RH_SalVentAttnA_ParMed_2    0.007116       0.0071         DC
# 33              17Networks_RH_TempPar_4    0.006955       0.0070         DC
# 35              17Networks_RH_SomMotA_6    0.006786       0.0068         DC
# 45                         17Networks_9    0.006522       0.0065         DC

# %%
for i, region in enumerate(DC["region"]):
    if (region.find("17Network") != -1) and ( len(region) != 12 ):
        value = sch_regions.loc[[region], "ROI Label"].values[0]
        name = 'DC_subregions/'+region+'.nii.gz'
        imp = DC.iloc[[i], 1].values[0]*100
        fsl.fslmaths('Schaefer2018_400Parcels_17Networks_order_FSLMNI152_2mm.nii').thr(value-0.1).uthr(value+0.1).run(name)
        fsl.fslmaths(name).bin().mul(imp).run(name)
        
        
    if (region.find("17Network") == -1):
        value = BN_regions.loc[[region], "Value"].values[0]
        name = 'DC_subregions/'+region+'.nii.gz'
        imp = DC.iloc[[i], 1].values[0]*100
        fsl.fslmaths('BN_Atlas_246_2mm.nii.gz').thr(value-0.1).uthr(value+0.1).run(name)
        fsl.fslmaths(name).bin().mul(imp).run(name)
        
                
    if (region.find("17Network") != -1) and ( len(region) == 12 ):
        reg = "Network_" + region.split("_")[1]
        value = Buck_regions.loc[[reg], "index"].values[0]
        name = 'DC_subregions/'+reg+'.nii.gz'
        imp = DC.iloc[[i], 1].values[0]*100
        fsl.fslmaths('atl-Buckner17_space-MNI_dseg.nii').thr(value-0.1).uthr(value+0.1).run(name)
        fsl.fslmaths(name).bin().mul(imp).run(name)

# %%
value
# Out:
# 229
