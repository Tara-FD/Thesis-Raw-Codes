# %%
import pandas as pd
import numpy as np
import os 
import shutil

# %%
df = pd.read_excel('all_correlation_results(fdr).xlsx', 'correlation_SWSrw')
df.shape
# Out:
# (454, 1024)

# %%
for cols in df.columns:
    if cols.find('Unnamed') != -1:
        #print(cols)
        df = df.drop(cols, axis = 1)

# %%
df.head()
# Out:
#        parc_name  gmd_sws_rw_fdr  zALFF_sws_rw_fdr  zfALFF_sws_rw_fdr  \
# 0  17Networks_17        0.048864          0.041528                NaN
# 1  17Networks_16             NaN               NaN                NaN
# 2  17Networks_15             NaN               NaN           0.043514
# 3  17Networks_14             NaN               NaN                NaN
# 4  17Networks_13             NaN               NaN                NaN
#
#    zDCbin_sws_rw_fdr  zDCbin_sws_rw_bonferroni  zDCwei_sws_rw_fdr  \
# 0                NaN                       NaN                NaN
# 1                NaN                       NaN                NaN
# 2                NaN                       NaN                NaN
# 3                NaN                       NaN                NaN
# 4                NaN                       NaN                NaN
#
#    zReHo_sws_rw_fdr
# 0               NaN
# 1               NaN
# 2          0.041528
# 3               NaN
# 4               NaN

# %%
#df2 = df.drop(['zALFF_sws_fa_fdr', 'sws_fa'], axis=1)
#df2.head()

# %%
df2 = df.dropna(subset = ['gmd_sws_rw_fdr'])

# %%
df2
# Out:
#                                parc_name  gmd_sws_rw_fdr  zALFF_sws_rw_fdr  \
# 0                          17Networks_17        0.048864          0.041528
# 16                          17Networks_1        0.042370               NaN
# 19                               cTtha_R        0.041528               NaN
# 39                                 NAC_R        0.044913               NaN
# 45                               cHipp_R        0.041528               NaN
# 46                               cHipp_L        0.048864               NaN
# 77      17Networks_RH_DefaultB_AntTemp_1        0.041528               NaN
# 81         17Networks_RH_DefaultA_PFCm_5        0.036685               NaN
# 83         17Networks_RH_DefaultA_PFCm_3        0.045443               NaN
# 85         17Networks_RH_DefaultA_PFCm_1        0.041528               NaN
# 111          17Networks_RH_ContB_PFCld_1        0.041528               NaN
# 117           17Networks_RH_ContB_Temp_1        0.035376               NaN
# 145    17Networks_RH_SalVentAttnB_PFCl_3        0.041528               NaN
# 146    17Networks_RH_SalVentAttnB_PFCl_2        0.035376               NaN
# 170        17Networks_RH_DorsAttnB_FEF_2        0.047862               NaN
# 252        17Networks_RH_VisCent_ExStr_1        0.042274               NaN
# 261         17Networks_LH_DefaultC_PHC_1        0.041528               NaN
# 265         17Networks_LH_DefaultC_IPL_1        0.048972               NaN
# 272        17Networks_LH_DefaultB_PFCl_1        0.041528               NaN
# 281        17Networks_LH_DefaultB_Temp_6        0.041528               NaN
# 282        17Networks_LH_DefaultB_Temp_5        0.042370               NaN
# 289        17Networks_LH_DefaultA_PFCm_4        0.041528               NaN
# 290        17Networks_LH_DefaultA_PFCm_3        0.047862               NaN
# 291        17Networks_LH_DefaultA_PFCm_2        0.041528               NaN
# 292        17Networks_LH_DefaultA_PFCm_1        0.042370               NaN
# 308           17Networks_LH_ContC_pCun_2        0.041528               NaN
# 343          17Networks_LH_LimbicB_OFC_2        0.028405               NaN
# 350    17Networks_LH_SalVentAttnB_PFCl_3        0.041528               NaN
# 357  17Networks_LH_SalVentAttnA_ParMed_2        0.035376               NaN
# 382        17Networks_LH_DorsAttnA_SPL_6        0.035376               NaN
# 385        17Networks_LH_DorsAttnA_SPL_3        0.040780               NaN
# 402           17Networks_LH_SomMotB_S2_3        0.048864               NaN
# 406           17Networks_LH_SomMotB_S2_1        0.045443               NaN
# 423              17Networks_LH_SomMotA_6        0.041528               NaN
# 443        17Networks_LH_VisCent_ExStr_9        0.035376               NaN
# 450        17Networks_LH_VisCent_ExStr_3        0.048864               NaN
# 452        17Networks_LH_VisCent_ExStr_1        0.041528               NaN
# 453             total_significant_values       37.000000          7.000000
#
#      zfALFF_sws_rw_fdr  zDCbin_sws_rw_fdr  zDCbin_sws_rw_bonferroni  \
# 0                  NaN                NaN                       NaN
# 16                 NaN                NaN                       NaN
# 19                 NaN                NaN                       NaN
# 39                 NaN                NaN                       NaN
# 45                 NaN                NaN                       NaN
# 46                 NaN                NaN                       NaN
# 77                 NaN                NaN                       NaN
# 81                 NaN                NaN                       NaN
# 83                 NaN                NaN                       NaN
# 85                 NaN           0.042370                       NaN
# 111                NaN                NaN                       NaN
# 117                NaN                NaN                       NaN
# 145                NaN                NaN                       NaN
# 146                NaN                NaN                       NaN
# 170           0.047014                NaN                       NaN
# 252                NaN                NaN                       NaN
# 261                NaN                NaN                       NaN
# 265                NaN                NaN                       NaN
# 272                NaN                NaN                       NaN
# 281                NaN                NaN                       NaN
# 282           0.041528           0.035376                       NaN
# 289                NaN                NaN                       NaN
# 290                NaN                NaN                       NaN
# 291                NaN                NaN                       NaN
# 292                NaN                NaN                       NaN
# 308                NaN                NaN                       NaN
# 343                NaN                NaN                       NaN
# 350                NaN                NaN                       NaN
# 357                NaN                NaN                       NaN
# 382           0.047862                NaN                       NaN
# 385           0.047862                NaN                       NaN
# 402                NaN           0.041528                       NaN
# 406                NaN                NaN                       NaN
# 423                NaN                NaN                       NaN
# 443                NaN                NaN                       NaN
# 450                NaN                NaN                       NaN
# 452                NaN                NaN                       NaN
# 453          27.000000          35.000000                       2.0
#
#      zDCwei_sws_rw_fdr  zReHo_sws_rw_fdr
# 0                  NaN               NaN
# 16                 NaN               NaN
# 19                 NaN               NaN
# 39                 NaN               NaN
# 45                 NaN               NaN
# 46                 NaN               NaN
# 77            0.047862               NaN
# 81                 NaN               NaN
# 83                 NaN               NaN
# 85            0.041528               NaN
# 111                NaN               NaN
# 117                NaN               NaN
# 145                NaN               NaN
# 146                NaN               NaN
# 170                NaN               NaN
# 252                NaN               NaN
# 261                NaN               NaN
# 265                NaN               NaN
# 272                NaN               NaN
# 281                NaN               NaN
# 282           0.038405               NaN
# 289                NaN               NaN
# 290                NaN               NaN
# 291                NaN               NaN
# 292                NaN               NaN
# 308                NaN               NaN
# 343                NaN               NaN
# 350                NaN               NaN
# 357                NaN               NaN
# 382                NaN               NaN
# 385                NaN               NaN
# 402           0.048864               NaN
# 406                NaN               NaN
# 423                NaN               NaN
# 443                NaN               NaN
# 450                NaN               NaN
# 452                NaN               NaN
# 453          35.000000              21.0

# %% [markdown]
# ### gmd

# %%
df1 = df[['parc_name', 'gmd_sws_total_fdr']]
df1.head()
# Out:
#        parc_name  gmd_sws_total_fdr
# 0  17Networks_17                NaN
# 1  17Networks_16                NaN
# 2  17Networks_15                NaN
# 3  17Networks_14                NaN
# 4  17Networks_13                NaN

# %%
df2 = df1.dropna()

# %%
df2 = df2.reset_index()

# %%
df.head()
# Out:
#        parc_name  gmd_sws_total_fdr  zALFF_sws_total_fdr  \
# 0  17Networks_17                NaN                  NaN
# 1  17Networks_16                NaN                  NaN
# 2  17Networks_15                NaN                  NaN
# 3  17Networks_14                NaN                  NaN
# 4  17Networks_13                NaN                  NaN
#
#    zfALFF_sws_total_fdr  zDCbin_sws_total_fdr  zDCwei_sws_total_fdr  \
# 0                   NaN                   NaN                   NaN
# 1                   NaN                   NaN                   NaN
# 2                   NaN                   NaN                   NaN
# 3                   NaN                   NaN                   NaN
# 4                   NaN                   NaN                   NaN
#
#    zReHo_sws_total_fdr
# 0                  NaN
# 1                  NaN
# 2              0.04454
# 3                  NaN
# 4                  NaN

# %%
df = df2.drop('index', axis = 1)

# %%
#directory = input('Enter the root directory: ')
directory = '/home/tara/MRIcroGL_linux/masks'

# %%
ls = os.listdir(directory)

# %% [markdown]
# ### copy gmd

# %%
for i in range(1,len(df['parc_name'])):
    for j in range (1,len(ls)):
        if df['parc_name'][i] == ls[j][0:len(ls[j])-7]:
            #print(df['parc_name'][i])
            original = directory + '/' + ls[j]
            target = '/media/tara/HD710PRO/Thesis/Atlas/subregions/gmd/' 
            os.makedirs(target, exist_ok = True)
            target = target + ls[j]
            shutil.copyfile(original, target)

# %% [markdown]
# ### copy zALFF

# %%
df = pd.read_csv('subregions.csv')
df.head()
# Out:
#        parc_name  gmd_sws_total_fdr  zALFF_sws_total_fdr  \
# 0  17Networks_17                NaN                  NaN
# 1  17Networks_16                NaN                  NaN
# 2  17Networks_15                NaN                  NaN
# 3  17Networks_14                NaN                  NaN
# 4  17Networks_13                NaN                  NaN
#
#    zfALFF_sws_total_fdr  zDCbin_sws_total_fdr  zDCwei_sws_total_fdr  \
# 0                   NaN                   NaN                   NaN
# 1                   NaN                   NaN                   NaN
# 2                   NaN                   NaN                   NaN
# 3                   NaN                   NaN                   NaN
# 4                   NaN                   NaN                   NaN
#
#    zReHo_sws_total_fdr
# 0                  NaN
# 1                  NaN
# 2              0.04454
# 3                  NaN
# 4                  NaN

# %%
df1 = df[['parc_name', 'zALFF_sws_total_fdr']]
df1.head()
# Out:
#        parc_name  zALFF_sws_total_fdr
# 0  17Networks_17                  NaN
# 1  17Networks_16                  NaN
# 2  17Networks_15                  NaN
# 3  17Networks_14                  NaN
# 4  17Networks_13                  NaN

# %%
df2 = df1.dropna()

# %%
df = df2.reset_index()

# %%
df2 = df.drop('index', axis = 1)

# %%
df = df2

# %%
for i in range(1,len(df['parc_name'])):
    for j in range (1,len(ls)):
        if df['parc_name'][i] == ls[j][0:len(ls[j])-7]:
            #print(df['parc_name'][i])
            original = directory + '/' + ls[j]
            target = '/media/tara/HD710PRO/Thesis/Atlas/subregions/zALFF/' 
            os.makedirs(target, exist_ok = True)
            target = target + ls[j]
            shutil.copyfile(original, target)

# %% [markdown]
# ### copy zfALFF

# %%
df = pd.read_csv('subregions.csv')
df1 = df[['parc_name', 'zfALFF_sws_total_fdr']]
df2 = df1.dropna()

# %%
df = df2.reset_index()
df2 = df.drop('index', axis = 1)
df = df2

# %%
df.head()
# Out:
#       parc_name  zfALFF_sws_total_fdr
# 0  17Networks_9              0.044478
# 1  17Networks_2              0.049611
# 2      lPFtha_L              0.044478
# 3       cTtha_L              0.049611
# 4        Otha_L              0.041309

# %%
for i in range(1,len(df['parc_name'])):
    for j in range (1,len(ls)):
        if df['parc_name'][i] == ls[j][0:len(ls[j])-7]:
            #print(df['parc_name'][i])
            original = directory + '/' + ls[j]
            target = '/media/tara/HD710PRO/Thesis/Atlas/subregions/zfALFF/' 
            os.makedirs(target, exist_ok = True)
            target = target + ls[j]
            shutil.copyfile(original, target)

# %% [markdown]
# ### copy zDCbin

# %%
df = pd.read_csv('subregions.csv')
df1 = df[['parc_name', 'zDCbin_sws_total_fdr']]
df2 = df1.dropna()

# %%
df = df2.reset_index()
df2 = df.drop('index', axis = 1)
df = df2

# %%
df.head()
# Out:
#                  parc_name  zDCbin_sws_total_fdr
# 0             17Networks_9              0.048667
# 1                 lPFtha_L              0.043910
# 2                 mPMtha_L              0.036365
# 3  17Networks_RH_TempPar_9              0.049054
# 4  17Networks_RH_TempPar_5              0.047507

# %%
for i in range(1,len(df['parc_name'])):
    for j in range (1,len(ls)):
        if df['parc_name'][i] == ls[j][0:len(ls[j])-7]:
            #print(df['parc_name'][i])
            original = directory + '/' + ls[j]
            target = '/media/tara/HD710PRO/Thesis/Atlas/subregions/zDCbin/' 
            os.makedirs(target, exist_ok = True)
            target = target + ls[j]
            shutil.copyfile(original, target)

# %% [markdown]
# ### zDCwei

# %%
df = pd.read_csv('subregions.csv')
df1 = df[['parc_name', 'zDCwei_sws_total_fdr']]
df2 = df1.dropna()

# %%
df = df2.reset_index()
df2 = df.drop('index', axis = 1)
df = df2

# %%
df.head()
# Out:
#                  parc_name  zDCwei_sws_total_fdr
# 0             17Networks_9              0.044540
# 1                 lPFtha_L              0.035961
# 2                 mPMtha_L              0.034448
# 3                   dlPu_L              0.041309
# 4  17Networks_RH_TempPar_5              0.049220

# %%
for i in range(1,len(df['parc_name'])):
    for j in range (1,len(ls)):
        if df['parc_name'][i] == ls[j][0:len(ls[j])-7]:
            #print(df['parc_name'][i])
            original = directory + '/' + ls[j]
            target = '/media/tara/HD710PRO/Thesis/Atlas/subregions/zDCwei/' 
            os.makedirs(target, exist_ok = True)
            target = target + ls[j]
            shutil.copyfile(original, target)

# %% [markdown]
# ### zReHo

# %%
df = pd.read_csv('subregions.csv')
df1 = df[['parc_name', 'zReHo_sws_total_fdr']]
df2 = df1.dropna()

# %%
df = df2.reset_index()
df2 = df.drop('index', axis = 1)
df = df2

# %%
df.head()
# Out:
#                        parc_name  zReHo_sws_total_fdr
# 0                  17Networks_15             0.044540
# 1                        cHipp_L             0.039714
# 2                        mAmyg_L             0.033089
# 3  17Networks_RH_DefaultA_PFCm_5             0.044478
# 4   17Networks_RH_DefaultA_IPL_2             0.039525

# %%
for i in range(1,len(df['parc_name'])):
    for j in range (1,len(ls)):
        if df['parc_name'][i] == ls[j][0:len(ls[j])-7]:
            #print(df['parc_name'][i])
            original = directory + '/' + ls[j]
            target = '/media/tara/HD710PRO/Thesis/Atlas/subregions/zReHo/' 
            os.makedirs(target, exist_ok = True)
            target = target + ls[j]
            shutil.copyfile(original, target)
