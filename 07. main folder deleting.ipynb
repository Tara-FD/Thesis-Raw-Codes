# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os 
import shutil

# %%
#directory = '/media/tara/HD710PRO/Thesis/NICAP_ADHD_sleep_DATA'
directory = '/media/tara/HD710PRO/Thesis/NICAP_ADHD_sleep_DATA(freesurfer_design)'

# %%
s = os.listdir(directory)
s
# Out:
# ['sub-0152',
#  'sub-0260',
#  'sub-0550',
#  'sub-0718',
#  'sub-0015',
#  'sub-0856',
#  'sub-0085',
#  'sub-0134',
#  'sub-1110',
#  'sub-0307',
#  'sub-1403',
#  'sub-1490',
#  'sub-0334',
#  'sub-1764',
#  'sub-2093',
#  'sub-0517',
#  'sub-0526',
#  'sub-2498',
#  'sub-0575',
#  'sub-2523',
#  'sub-2582',
#  'sub-0613',
#  'sub-2654',
#  'sub-0616',
#  'sub-2704',
#  'sub-4062',
#  'sub-0755',
#  'sub-4264',
#  'sub-0788',
#  'sub-0802',
#  'sub-4305',
#  'sub-1127',
#  'sub-4656',
#  'sub-1170',
#  'sub-4873',
#  'sub-1264',
#  'sub-4925',
#  'sub-5051',
#  'sub-1274',
#  'sub-7020',
#  'sub-5117',
#  'sub-1348',
#  'sub-1596',
#  'sub-5180',
#  'sub-1714',
#  'sub-1745',
#  'sub-5532',
#  'sub-5588',
#  'sub-1908',
#  'sub-5604',
#  'sub-1938',
#  'sub-5606',
#  'sub-1994',
#  'sub-2004',
#  'sub-5927',
#  'sub-2031',
#  'sub-5946',
#  'sub-6015',
#  'sub-6026',
#  'sub-2105',
#  'sub-6039',
#  'sub-6240',
#  'sub-2159',
#  'sub-6392',
#  'sub-2263',
#  'sub-6461',
# ...

# %%
#df = pd.read_csv('/media/tara/HD710PRO/Thesis/main_dataframe/final2.tsv')
#df

# %%
df2 = df.set_index('Subject_ID')
for file in s:
    waves = os.listdir(directory + '/' + file)
    try:
        df3 = df2.loc[[file]]
        for wave in waves:
            df3 = df3.reset_index().set_index('imaging waves')
            if wave.find('.')==0:
                continue
            try:
                df3.loc[[wave]]
            except:
                shutil.rmtree(directory + '/' + file + '/' + wave)    
    except:
        shutil.rmtree(directory + '/' + file)

# %%
for file in s:
    waves = os.listdir(directory + '/' + file)
    #finalpath = directory + waves + '/anat'
    print(waves)
# Out:
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ['anat']
# ...
