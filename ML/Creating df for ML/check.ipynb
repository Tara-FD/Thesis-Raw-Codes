# %%
import pandas as pd

# %%
# %config Completer.use_jedi = False

# %%
rdf = pd.read_csv('df_forR_toCorrect.csv')
rdf = rdf.drop('Unnamed: 0', axis = 1)
new = rdf.rename(columns = {'0': 'Subject_ID'})
new.head()
# Out:
#   Subject_ID  zfALFF_17Networks_15  zfALFF_17Networks_9  zfALFF_17Networks_2  \
# 0   sub-0015             -0.347018            -0.787030            -0.445804
# 1   sub-0085             -0.298331            -0.601078            -0.304966
# 2   sub-0134             -0.390213            -0.799635            -0.231216
# 3   sub-0152             -0.516628            -0.485006            -0.223685
# 4   sub-0260             -0.314693            -0.853856            -0.356149
#
#    zfALFF_lPFtha_R  zfALFF_lPFtha_L  zfALFF_cTtha_L  zfALFF_Otha_L  \
# 0        -0.760500        -0.929277       -0.743303      -0.701746
# 1        -0.234355        -0.397031       -0.381863      -0.449357
# 2        -1.012589        -0.840667       -0.901478      -0.487365
# 3        -0.682773        -0.294288       -0.634390      -0.597999
# 4        -0.814174        -0.863769       -0.617213      -0.475704
#
#    zfALFF_rTtha_R  zfALFF_rTtha_L  ...  zDCwei_17Networks_LH_SomMotB_Aud_3  \
# ...

# %%
info = pd.read_csv('info.csv')
info = info.drop('Unnamed: 0', axis = 1)
info.head()
# Out:
#   Subject_ID  CHILDgender  diagadhd
# 0   sub-0015            1         0
# 1   sub-0085            0         0
# 2   sub-0134            1         0
# 3   sub-0152            0         0
# 4   sub-0260            1         1

# %%
df = new.merge(info, how = "left", on = 'Subject_ID')

# %%
df.head()
# Out:
#   Subject_ID  zfALFF_17Networks_15  zfALFF_17Networks_9  zfALFF_17Networks_2  \
# 0   sub-0015             -0.347018            -0.787030            -0.445804
# 1   sub-0085             -0.298331            -0.601078            -0.304966
# 2   sub-0134             -0.390213            -0.799635            -0.231216
# 3   sub-0152             -0.516628            -0.485006            -0.223685
# 4   sub-0260             -0.314693            -0.853856            -0.356149
#
#    zfALFF_lPFtha_R  zfALFF_lPFtha_L  zfALFF_cTtha_L  zfALFF_Otha_L  \
# 0        -0.760500        -0.929277       -0.743303      -0.701746
# 1        -0.234355        -0.397031       -0.381863      -0.449357
# 2        -1.012589        -0.840667       -0.901478      -0.487365
# 3        -0.682773        -0.294288       -0.634390      -0.597999
# 4        -0.814174        -0.863769       -0.617213      -0.475704
#
#    zfALFF_rTtha_R  zfALFF_rTtha_L  ...  zDCwei_17Networks_LH_SomMotB_Aud_1  \
# ...

# %%
fdr = pd.read_csv('fdr.csv')
#info = info.drop('Unnamed: 0', axis = 1)
fdr.head()
# Out:
#            parcel_name    sws_rs  sws_gb  sws_ms  sws_fa    sws_rw  sws_total
# 0    gmd_17Networks_17       NaN     NaN     NaN     NaN  0.048864        NaN
# 1     gmd_17Networks_1       NaN     NaN     NaN     NaN  0.042370        NaN
# 2  zReHo_17Networks_15  0.017524     NaN     NaN     NaN  0.041528    0.04454
# 3  zReHo_17Networks_11  0.016880     NaN     NaN     NaN  0.048864        NaN
# 4   zReHo_17Networks_9  0.024346     NaN     NaN     NaN  0.041528        NaN

# %%
for num in df.zReHo_17Networks_15:
    print(num)
# Out:
# -0.2595151537
# -0.2978264511
# -0.356670028
# -0.2390983876
# -0.2748675136
# -0.4329781863
# -0.3066258498
# -0.3204248559
# -0.376581432
# -0.3576691336
# -0.5845885416
# -0.3871600349
# -0.6213036699
# -0.007800542893
# 0.0885828746
# -0.5878991712
# -0.3461172221
# -0.6241593143
# -0.9355818975
# -0.4304173763
# -0.583598509
# -0.4604606026
# -0.808909429
# -0.4929862031
# -0.827755601
# -0.585517554
# -0.2467332233
# -0.4545042347
# -0.6062653123
# -0.4131158195
# -0.5013873284
# -0.2266490988
# -0.411513116
# -0.7308951814
# -0.5638967736
# -0.3858744329
# 0.01341779011
# -0.7629073295
# -0.3090766237
# -0.5414521191
# -0.5029054808
# -0.5248458528
# -0.697155428
# -0.2941325078
# -0.2981479109
# -0.6046852092
# -0.5121562909
# -0.2316664519
# -0.3201401641
# -0.4359737254
# -0.5886448574
# -0.6261035672
# -0.4348763902
# -0.4682007063
# -0.6216794814
# -0.3765351285
# -0.3515029913
# -0.1716477825
# -0.7572271326
# -0.2493212015
# -0.4271333996
# -0.6238325483
# ...

# %%
df.to_csv('df_forR_toCorrect.csv')
