# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import ExtraTreesClassifier

# %%
df = pd.read_csv('finaldf_orderd.csv')

df.head()
# Out:
#    Unnamed: 0 Subject_ID  diagadhd  CHILDgender   age  sws_total  \
# 0           0   sub-0015         0            1  13.0   1.513333
# 1           1   sub-0085         0            0  11.5   2.560000
# 2           2   sub-0134         0            1  13.0   2.346667
# 3           3   sub-0152         0            0  11.5   2.066667
# 4           4   sub-0260         1            1  11.5   3.120000
#
#    gmd_17Networks_1  zfALFF_17Networks_1  zDCwei_17Networks_1  \
# 0          1.304940            -0.129129            -0.255912
# 1          0.416967            -0.370917             0.014907
# 2          1.376817             0.249346             0.287834
# 3          0.620056            -0.054428             0.011391
# 4          0.760185            -0.241427            -0.121562
#
#    zReHo_17Networks_1  ...  zDCwei_vCa_R  zReHo_vCa_R  gmd_vmPu_L  \
# 0           -0.144680  ...     -0.164447    -0.464885    0.443390
# 1           -0.385798  ...     -0.535982    -0.579071    0.550866
# 2           -0.004400  ...      0.226537    -0.060230    0.743458
# 3           -0.038562  ...     -0.237428    -0.031055    0.691905
# 4           -0.235275  ...      0.283735     0.201138    0.350098
#
#    zfALFF_vmPu_L  zDCwei_vmPu_L  zReHo_vmPu_L  gmd_vmPu_R  zfALFF_vmPu_R  \
# 0      -0.571002      -0.303500     -0.378953    0.563376      -0.601837
# 1      -0.168972      -0.651936     -0.535457    0.428719      -0.439474
# 2      -0.105006      -0.325386      0.053537    0.581800      -0.229170
# 3      -0.262465      -0.103280      0.214787    0.638877      -0.411452
# 4      -0.357051      -0.141482      0.063200    0.487531      -0.119186
#
#    zDCwei_vmPu_R  zReHo_vmPu_R
# 0      -0.388848     -0.467961
# 1      -0.705622     -0.601932
# 2      -0.227449     -0.026262
# 3      -0.345689      0.352952
# 4      -0.046044      0.383860
#
# [5 rows x 1818 columns]
