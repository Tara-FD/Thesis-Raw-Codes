# %%
# %config Completer.use_jedi = False

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('df_184feat.csv')
df.drop('Unnamed: 0', axis=1, inplace=True)
df.drop('Unnamed: 0.1', axis=1, inplace=True)
df.head()
# Out:
#    sws_total Subject_ID  diagadhd  CHILDgender  zfALFF_17Networks_9  \
# 0   1.513333   sub-0015         0            1            -0.787030
# 1   2.560000   sub-0085         0            0            -0.601078
# 2   2.346667   sub-0134         0            1            -0.799635
# 3   2.066667   sub-0152         0            0            -0.485006
# 4   3.120000   sub-0260         1            1            -0.853856
#
#    zfALFF_17Networks_2  zfALFF_lPFtha_L  zfALFF_cTtha_L  zfALFF_Otha_L  \
# 0            -0.445804        -0.929277       -0.743303      -0.701746
# 1            -0.304966        -0.397031       -0.381863      -0.449357
# 2            -0.231216        -0.840667       -0.901478      -0.487365
# 3            -0.223685        -0.294288       -0.634390      -0.597999
# 4            -0.356149        -0.863769       -0.617213      -0.475704
#
#    zfALFF_rTtha_R  ...  zDCwei_17Networks_RH_SomMotA_6  \
# 0       -0.843242  ...                        0.570004
# 1       -0.341996  ...                        0.280915
# 2       -0.710494  ...                        0.631763
# 3       -0.640255  ...                       -0.034122
# 4       -0.797962  ...                       -0.181578
#
#    zDCwei_17Networks_LH_DefaultC_PHC_3  zDCwei_17Networks_LH_DefaultB_Temp_5  \
# 0                            -0.130038                             -0.047269
# 1                            -0.321277                             -0.009029
# 2                             0.249275                              0.492542
# 3                             0.082488                              0.263105
# 4                             0.304288                              0.449225
#
#    zDCwei_17Networks_LH_ContB_Temp_2  \
# 0                           0.388094
# 1                          -0.196261
# 2                           0.465131
# 3                           0.375573
# 4                           0.739805
#
#    zDCwei_17Networks_LH_SalVentAttnA_FrMed_2  \
# 0                                   0.158019
# 1                                   0.080881
# 2                                   0.149572
# 3                                  -0.179384
# 4                                   0.125963
#
#    zDCwei_17Networks_LH_SalVentAttnA_FrMed_1  \
# 0                                   0.257226
# 1                                   0.170051
# 2                                   0.168241
# 3                                   0.009714
# 4                                   0.116520
#
#    zDCwei_17Networks_LH_SalVentAttnA_ParMed_1  \
# 0                                    0.094419
# 1                                    0.153607
# 2                                    0.310641
# 3                                    0.205987
# 4                                    0.293805
#
#    zDCwei_17Networks_LH_SalVentAttnA_ParOper_1  \
# 0                                     0.157887
# 1                                     0.192767
# 2                                     0.219820
# 3                                     0.018744
# 4                                     0.122458
#
#    zDCwei_17Networks_LH_DorsAttnB_PostC_1  \
# 0                                0.042376
# 1                               -0.052853
# 2                                0.148504
# 3                                0.069715
# 4                               -0.000745
#
#    zDCwei_17Networks_LH_DorsAttnA_TempOcc_2
# 0                                 -0.074321
# 1                                  0.049870
# 2                                  0.236822
# 3                                  0.291880
# 4                                  0.174841
#
# [5 rows x 188 columns]

# %%
df = df.drop(columns = ['Subject_ID', 'diagadhd', 'CHILDgender'])
df.head()
# Out:
#    sws_total  zfALFF_17Networks_9  zfALFF_17Networks_2  zfALFF_lPFtha_L  \
# 0   1.513333            -0.787030            -0.445804        -0.929277
# 1   2.560000            -0.601078            -0.304966        -0.397031
# 2   2.346667            -0.799635            -0.231216        -0.840667
# 3   2.066667            -0.485006            -0.223685        -0.294288
# 4   3.120000            -0.853856            -0.356149        -0.863769
#
#    zfALFF_cTtha_L  zfALFF_Otha_L  zfALFF_rTtha_R  zfALFF_rTtha_L  \
# 0       -0.743303      -0.701746       -0.843242       -0.764751
# 1       -0.381863      -0.449357       -0.341996       -0.347692
# 2       -0.901478      -0.487365       -0.710494       -0.512793
# 3       -0.634390      -0.597999       -0.640255       -0.425914
# 4       -0.617213      -0.475704       -0.797962       -0.641054
#
#    zfALFF_Stha_R  zfALFF_Stha_L  ...  zDCwei_17Networks_RH_SomMotA_6  \
# 0      -0.830111      -0.858958  ...                        0.570004
# 1      -0.348079      -0.334773  ...                        0.280915
# 2      -0.807105      -0.824212  ...                        0.631763
# 3      -0.672409      -0.644164  ...                       -0.034122
# 4      -0.861669      -0.868551  ...                       -0.181578
#
#    zDCwei_17Networks_LH_DefaultC_PHC_3  zDCwei_17Networks_LH_DefaultB_Temp_5  \
# 0                            -0.130038                             -0.047269
# 1                            -0.321277                             -0.009029
# 2                             0.249275                              0.492542
# 3                             0.082488                              0.263105
# 4                             0.304288                              0.449225
#
#    zDCwei_17Networks_LH_ContB_Temp_2  \
# 0                           0.388094
# 1                          -0.196261
# 2                           0.465131
# 3                           0.375573
# 4                           0.739805
#
#    zDCwei_17Networks_LH_SalVentAttnA_FrMed_2  \
# 0                                   0.158019
# 1                                   0.080881
# 2                                   0.149572
# 3                                  -0.179384
# 4                                   0.125963
#
#    zDCwei_17Networks_LH_SalVentAttnA_FrMed_1  \
# 0                                   0.257226
# 1                                   0.170051
# 2                                   0.168241
# 3                                   0.009714
# 4                                   0.116520
#
#    zDCwei_17Networks_LH_SalVentAttnA_ParMed_1  \
# 0                                    0.094419
# 1                                    0.153607
# 2                                    0.310641
# 3                                    0.205987
# 4                                    0.293805
#
#    zDCwei_17Networks_LH_SalVentAttnA_ParOper_1  \
# 0                                     0.157887
# 1                                     0.192767
# 2                                     0.219820
# 3                                     0.018744
# 4                                     0.122458
#
#    zDCwei_17Networks_LH_DorsAttnB_PostC_1  \
# 0                                0.042376
# 1                               -0.052853
# 2                                0.148504
# 3                                0.069715
# 4                               -0.000745
#
#    zDCwei_17Networks_LH_DorsAttnA_TempOcc_2
# 0                                 -0.074321
# 1                                  0.049870
# 2                                  0.236822
# 3                                  0.291880
# 4                                  0.174841
#
# [5 rows x 185 columns]

# %%
vals = df.drop('sws_total', axis=1)
# Out:
# array([[-0.78703014, -0.44580398, -0.92927723, ...,  0.15788668,
#          0.04237612, -0.07432115],
#        [-0.6010784 , -0.30496612, -0.39703067, ...,  0.19276692,
#         -0.05285255,  0.04987013],
#        [-0.79963451, -0.23121618, -0.84066715, ...,  0.21981957,
#          0.14850439,  0.23682245],
#        ...,
#        [-0.7042394 , -0.33127325, -0.71825975, ..., -0.03435734,
#         -0.14369024, -0.26943154],
#        [-0.70158408, -0.20736238, -0.82770128, ..., -0.09213748,
#         -0.01810745,  0.29861245],
#        [-0.77518194, -0.37789821, -0.87692198, ..., -0.05689349,
#         -0.08638776, -0.00134313]])

# %%
from scipy.stats import pearsonr

# Convert dataframe into series
list1 = df['sws_total']
list2 = vals.values
 
# Apply the pearsonr()
corr, _ = pearsonr(list1, list2)
print('Pearsons correlation: %.3f' % corr)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-c30d208d43ea> in <module>
#       6
#       7 # Apply the pearsonr()
# ----> 8 corr, _ = pearsonr(list1, list2)
#       9 print('Pearsons correlation: %.3f' % corr)
#
# ~/Programming/env/lib/python3.8/site-packages/scipy/stats/stats.py in pearsonr(x, y)
#    4032         return dtype(np.sign(x[1] - x[0])*np.sign(y[1] - y[0])), 1.0
#    4033
# -> 4034     xmean = x.mean(dtype=dtype)
#    4035     ymean = y.mean(dtype=dtype)
#    4036
#
# ~/Programming/env/lib/python3.8/site-packages/numpy/core/_methods.py in _mean(a, axis, dtype, out, keepdims)
#     158             is_float16_result = True
#     159
# --> 160     ret = umr_sum(arr, axis, dtype, out, keepdims)
#     161     if isinstance(ret, mu.ndarray):
#     162         ret = um.true_divide(
#
# TypeError: No loop matching the specified signature and casting was found for ufunc add

# %%
correlation = df.corr()
# Out:
#                                              sws_total  zfALFF_17Networks_9  \
# sws_total                                     1.000000             0.193462
# zfALFF_17Networks_9                           0.193462             1.000000
# zfALFF_17Networks_2                           0.182355             0.679088
# zfALFF_lPFtha_L                               0.192590             0.285898
# zfALFF_cTtha_L                                0.182097             0.214426
# ...                                                ...                  ...
# zDCwei_17Networks_LH_SalVentAttnA_FrMed_1    -0.258578            -0.059065
# zDCwei_17Networks_LH_SalVentAttnA_ParMed_1   -0.203535            -0.141622
# zDCwei_17Networks_LH_SalVentAttnA_ParOper_1  -0.184510            -0.076770
# zDCwei_17Networks_LH_DorsAttnB_PostC_1       -0.219417            -0.001068
# zDCwei_17Networks_LH_DorsAttnA_TempOcc_2     -0.190194            -0.042464
#
#                                              zfALFF_17Networks_2  \
# sws_total                                               0.182355
# zfALFF_17Networks_9                                     0.679088
# zfALFF_17Networks_2                                     1.000000
# zfALFF_lPFtha_L                                        -0.134009
# zfALFF_cTtha_L                                         -0.225052
# ...                                                          ...
# zDCwei_17Networks_LH_SalVentAttnA_FrMed_1              -0.020516
# zDCwei_17Networks_LH_SalVentAttnA_ParMed_1             -0.080770
# zDCwei_17Networks_LH_SalVentAttnA_ParOper_1             0.061969
# zDCwei_17Networks_LH_DorsAttnB_PostC_1                  0.172666
# zDCwei_17Networks_LH_DorsAttnA_TempOcc_2                0.115291
#
#                                              zfALFF_lPFtha_L  zfALFF_cTtha_L  \
# sws_total                                           0.192590        0.182097
# zfALFF_17Networks_9                                 0.285898        0.214426
# zfALFF_17Networks_2                                -0.134009       -0.225052
# zfALFF_lPFtha_L                                     1.000000        0.714266
# zfALFF_cTtha_L                                      0.714266        1.000000
# ...                                                      ...             ...
# zDCwei_17Networks_LH_SalVentAttnA_FrMed_1          -0.174860       -0.111449
# zDCwei_17Networks_LH_SalVentAttnA_ParMed_1         -0.174187       -0.062492
# zDCwei_17Networks_LH_SalVentAttnA_ParOper_1        -0.121525       -0.148119
# zDCwei_17Networks_LH_DorsAttnB_PostC_1             -0.028047       -0.105170
# zDCwei_17Networks_LH_DorsAttnA_TempOcc_2           -0.128418       -0.236654
#
#                                              zfALFF_Otha_L  zfALFF_rTtha_R  \
# sws_total                                         0.204450        0.220086
# zfALFF_17Networks_9                               0.280039        0.273831
# zfALFF_17Networks_2                              -0.001338        0.010136
# zfALFF_lPFtha_L                                   0.684242        0.689138
# zfALFF_cTtha_L                                    0.761818        0.801493
# ...                                                    ...             ...
# zDCwei_17Networks_LH_SalVentAttnA_FrMed_1        -0.110283       -0.165596
# zDCwei_17Networks_LH_SalVentAttnA_ParMed_1       -0.051066       -0.126855
# zDCwei_17Networks_LH_SalVentAttnA_ParOper_1      -0.094614       -0.027765
# zDCwei_17Networks_LH_DorsAttnB_PostC_1           -0.010038       -0.000120
# zDCwei_17Networks_LH_DorsAttnA_TempOcc_2         -0.147718       -0.152339
#
#                                              zfALFF_rTtha_L  zfALFF_Stha_R  \
# sws_total                                          0.201739       0.233828
# zfALFF_17Networks_9                                0.247368       0.258376
# zfALFF_17Networks_2                                0.076227      -0.176322
# zfALFF_lPFtha_L                                    0.579689       0.804276
# zfALFF_cTtha_L                                     0.672049       0.754472
# ...                                                     ...            ...
# zDCwei_17Networks_LH_SalVentAttnA_FrMed_1         -0.005243      -0.207373
# zDCwei_17Networks_LH_SalVentAttnA_ParMed_1        -0.047409      -0.135240
# zDCwei_17Networks_LH_SalVentAttnA_ParOper_1       -0.064343      -0.188216
# zDCwei_17Networks_LH_DorsAttnB_PostC_1            -0.029843      -0.072587
# zDCwei_17Networks_LH_DorsAttnA_TempOcc_2          -0.199962      -0.208187
#
#                                              zfALFF_Stha_L  ...  \
# sws_total                                         0.213936  ...
# zfALFF_17Networks_9                               0.294580  ...
# zfALFF_17Networks_2                              -0.081453  ...
# zfALFF_lPFtha_L                                   0.813329  ...
# zfALFF_cTtha_L                                    0.822442  ...
# ...                                                    ...  ...
# zDCwei_17Networks_LH_SalVentAttnA_FrMed_1        -0.113000  ...
# zDCwei_17Networks_LH_SalVentAttnA_ParMed_1       -0.104772  ...
# zDCwei_17Networks_LH_SalVentAttnA_ParOper_1      -0.053794  ...
# zDCwei_17Networks_LH_DorsAttnB_PostC_1            0.000050  ...
# zDCwei_17Networks_LH_DorsAttnA_TempOcc_2         -0.232071  ...
#
#                                              zDCwei_17Networks_RH_SomMotA_6  \
# sws_total                                                         -0.216580
# zfALFF_17Networks_9                                               -0.379597
# zfALFF_17Networks_2                                               -0.334215
# zfALFF_lPFtha_L                                                   -0.063412
# zfALFF_cTtha_L                                                     0.059925
# ...                                                                     ...
# zDCwei_17Networks_LH_SalVentAttnA_FrMed_1                         -0.010215
# zDCwei_17Networks_LH_SalVentAttnA_ParMed_1                        -0.023503
# zDCwei_17Networks_LH_SalVentAttnA_ParOper_1                       -0.010478
# zDCwei_17Networks_LH_DorsAttnB_PostC_1                            -0.062582
# zDCwei_17Networks_LH_DorsAttnA_TempOcc_2                          -0.203554
#
#                                              zDCwei_17Networks_LH_DefaultC_PHC_3  \
# sws_total                                                              -0.204419
# zfALFF_17Networks_9                                                    -0.074739
# zfALFF_17Networks_2                                                     0.039455
# zfALFF_lPFtha_L                                                         0.105205
# zfALFF_cTtha_L                                                         -0.009319
# ...                                                                          ...
# zDCwei_17Networks_LH_SalVentAttnA_FrMed_1                               0.118906
# zDCwei_17Networks_LH_SalVentAttnA_ParMed_1                              0.114401
# zDCwei_17Networks_LH_SalVentAttnA_ParOper_1                             0.125945
# zDCwei_17Networks_LH_DorsAttnB_PostC_1                                  0.287482
# zDCwei_17Networks_LH_DorsAttnA_TempOcc_2                                0.421364
#
#                                              zDCwei_17Networks_LH_DefaultB_Temp_5  \
# sws_total                                                               -0.183486
# zfALFF_17Networks_9                                                     -0.100723
# zfALFF_17Networks_2                                                      0.024721
# zfALFF_lPFtha_L                                                         -0.126643
# zfALFF_cTtha_L                                                          -0.120537
# ...                                                                           ...
# zDCwei_17Networks_LH_SalVentAttnA_FrMed_1                                0.165776
# zDCwei_17Networks_LH_SalVentAttnA_ParMed_1                               0.120534
# zDCwei_17Networks_LH_SalVentAttnA_ParOper_1                              0.301841
# zDCwei_17Networks_LH_DorsAttnB_PostC_1                                   0.315592
# zDCwei_17Networks_LH_DorsAttnA_TempOcc_2                                 0.416437
#
#                                              zDCwei_17Networks_LH_ContB_Temp_2  \
# sws_total                                                            -0.203438
# zfALFF_17Networks_9                                                  -0.059463
# zfALFF_17Networks_2                                                  -0.011365
# zfALFF_lPFtha_L                                                      -0.132059
# zfALFF_cTtha_L                                                       -0.142537
# ...                                                                        ...
# zDCwei_17Networks_LH_SalVentAttnA_FrMed_1                             0.049426
# zDCwei_17Networks_LH_SalVentAttnA_ParMed_1                            0.075689
# zDCwei_17Networks_LH_SalVentAttnA_ParOper_1                           0.253688
# zDCwei_17Networks_LH_DorsAttnB_PostC_1                                0.102460
# zDCwei_17Networks_LH_DorsAttnA_TempOcc_2                              0.557763
#
#                                              zDCwei_17Networks_LH_SalVentAttnA_FrMed_2  \
# sws_total                                                                    -0.197819
# zfALFF_17Networks_9                                                          -0.177004
# zfALFF_17Networks_2                                                          -0.089372
# zfALFF_lPFtha_L                                                              -0.148358
# zfALFF_cTtha_L                                                               -0.013256
# ...                                                                                ...
# zDCwei_17Networks_LH_SalVentAttnA_FrMed_1                                     0.514450
# zDCwei_17Networks_LH_SalVentAttnA_ParMed_1                                    0.413699
# zDCwei_17Networks_LH_SalVentAttnA_ParOper_1                                   0.215159
# zDCwei_17Networks_LH_DorsAttnB_PostC_1                                        0.184988
# zDCwei_17Networks_LH_DorsAttnA_TempOcc_2                                     -0.207717
#
#                                              zDCwei_17Networks_LH_SalVentAttnA_FrMed_1  \
# sws_total                                                                    -0.258578
# zfALFF_17Networks_9                                                          -0.059065
# zfALFF_17Networks_2                                                          -0.020516
# zfALFF_lPFtha_L                                                              -0.174860
# zfALFF_cTtha_L                                                               -0.111449
# ...                                                                                ...
# zDCwei_17Networks_LH_SalVentAttnA_FrMed_1                                     1.000000
# zDCwei_17Networks_LH_SalVentAttnA_ParMed_1                                    0.517912
# zDCwei_17Networks_LH_SalVentAttnA_ParOper_1                                   0.196514
# zDCwei_17Networks_LH_DorsAttnB_PostC_1                                        0.223739
# zDCwei_17Networks_LH_DorsAttnA_TempOcc_2                                      0.046529
#
#                                              zDCwei_17Networks_LH_SalVentAttnA_ParMed_1  \
# sws_total                                                                     -0.203535
# zfALFF_17Networks_9                                                           -0.141622
# zfALFF_17Networks_2                                                           -0.080770
# zfALFF_lPFtha_L                                                               -0.174187
# zfALFF_cTtha_L                                                                -0.062492
# ...                                                                                 ...
# zDCwei_17Networks_LH_SalVentAttnA_FrMed_1                                      0.517912
# zDCwei_17Networks_LH_SalVentAttnA_ParMed_1                                     1.000000
# zDCwei_17Networks_LH_SalVentAttnA_ParOper_1                                    0.254781
# zDCwei_17Networks_LH_DorsAttnB_PostC_1                                         0.255482
# zDCwei_17Networks_LH_DorsAttnA_TempOcc_2                                       0.073989
#
#                                              zDCwei_17Networks_LH_SalVentAttnA_ParOper_1  \
# sws_total                                                                      -0.184510
# zfALFF_17Networks_9                                                            -0.076770
# zfALFF_17Networks_2                                                             0.061969
# zfALFF_lPFtha_L                                                                -0.121525
# zfALFF_cTtha_L                                                                 -0.148119
# ...                                                                                  ...
# zDCwei_17Networks_LH_SalVentAttnA_FrMed_1                                       0.196514
# zDCwei_17Networks_LH_SalVentAttnA_ParMed_1                                      0.254781
# zDCwei_17Networks_LH_SalVentAttnA_ParOper_1                                     1.000000
# zDCwei_17Networks_LH_DorsAttnB_PostC_1                                          0.503966
# zDCwei_17Networks_LH_DorsAttnA_TempOcc_2                                        0.205586
#
#                                              zDCwei_17Networks_LH_DorsAttnB_PostC_1  \
# sws_total                                                                 -0.219417
# zfALFF_17Networks_9                                                       -0.001068
# zfALFF_17Networks_2                                                        0.172666
# zfALFF_lPFtha_L                                                           -0.028047
# zfALFF_cTtha_L                                                            -0.105170
# ...                                                                             ...
# zDCwei_17Networks_LH_SalVentAttnA_FrMed_1                                  0.223739
# zDCwei_17Networks_LH_SalVentAttnA_ParMed_1                                 0.255482
# zDCwei_17Networks_LH_SalVentAttnA_ParOper_1                                0.503966
# zDCwei_17Networks_LH_DorsAttnB_PostC_1                                     1.000000
# zDCwei_17Networks_LH_DorsAttnA_TempOcc_2                                   0.167727
#
#                                              zDCwei_17Networks_LH_DorsAttnA_TempOcc_2
# sws_total                                                                   -0.190194
# zfALFF_17Networks_9                                                         -0.042464
# zfALFF_17Networks_2                                                          0.115291
# zfALFF_lPFtha_L                                                             -0.128418
# zfALFF_cTtha_L                                                              -0.236654
# ...                                                                               ...
# zDCwei_17Networks_LH_SalVentAttnA_FrMed_1                                    0.046529
# zDCwei_17Networks_LH_SalVentAttnA_ParMed_1                                   0.073989
# zDCwei_17Networks_LH_SalVentAttnA_ParOper_1                                  0.205586
# zDCwei_17Networks_LH_DorsAttnB_PostC_1                                       0.167727
# zDCwei_17Networks_LH_DorsAttnA_TempOcc_2                                     1.000000
#
# [185 rows x 185 columns]
