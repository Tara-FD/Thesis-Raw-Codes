# %%
import pandas as pd
import os
import shutil

# %%
fd_cor = pd.read_csv('/media/tara/HD710PRO/Thesis/group_bold_mcrr.csv')

# %%
#fd_cor = fd_cor.drop('Unnamed: 0', axis=1)
fd_cor.head()
# Out:
#    Unnamed: 0                          bids_name       aor       aqi  \
# 0           0  sub-0015_ses-wave1_task-rest_bold  0.006006  0.032845
# 1           1  sub-0015_ses-wave3_task-rest_bold  0.000899  0.017761
# 2           2  sub-0085_ses-wave2_task-rest_bold  0.000957  0.020011
# 3           3  sub-0085_ses-wave3_task-rest_bold  0.002002  0.032506
# 4           4  sub-0086_ses-wave1_task-rest_bold  0.018828  0.043133
#
#    dummy_trs  dvars_nstd  dvars_std  dvars_vstd       efc          fber  ...  \
# 0          0   41.352940   1.154422    1.039241  0.391380  10046.058594  ...
# 1          0   37.355798   1.292336    0.993327  0.395745  13287.402344  ...
# 2          0   36.674423   1.192335    1.018124  0.370917  16799.005859  ...
# 3          0   34.891304   1.129925    0.949688  0.374768  18025.064453  ...
# 4          0   47.081587   1.171964    1.113701  0.376065  15374.750000  ...
#
#    summary_bg_stdv  summary_fg_k  summary_fg_mad  summary_fg_mean  \
# ...

# %% [markdown]
# ### spliting subjects and waves from bids_name

# %%
fd_cor["bids_name"] = fd_cor["bids_name"].str.split("_")

# %%
fd_cor.insert(2, "subject", "0")
fd_cor.insert(3, "wave", "0")
fd_cor = fd_cor.drop('Unnamed: 0', axis=1)
fd_cor.head()
# Out:
#                                 bids_name subject wave       aor       aqi  \
# 0  [sub-0015, ses-wave1, task-rest, bold]       0    0  0.006006  0.032845
# 1  [sub-0015, ses-wave3, task-rest, bold]       0    0  0.000899  0.017761
# 2  [sub-0085, ses-wave2, task-rest, bold]       0    0  0.000957  0.020011
# 3  [sub-0085, ses-wave3, task-rest, bold]       0    0  0.002002  0.032506
# 4  [sub-0086, ses-wave1, task-rest, bold]       0    0  0.018828  0.043133
#
#    dummy_trs  dvars_nstd  dvars_std  dvars_vstd       efc  ...  \
# 0          0   41.352940   1.154422    1.039241  0.391380  ...
# 1          0   37.355798   1.292336    0.993327  0.395745  ...
# 2          0   36.674423   1.192335    1.018124  0.370917  ...
# 3          0   34.891304   1.129925    0.949688  0.374768  ...
# 4          0   47.081587   1.171964    1.113701  0.376065  ...
#
#    summary_bg_stdv  summary_fg_k  summary_fg_mad  summary_fg_mean  \
# ...

# %%
for i in range(fd_cor.shape[0]):
    fd_cor["subject"][i] = fd_cor["bids_name"][i][0]
    fd_cor["wave"][i] = fd_cor["bids_name"][i][1]
# Out:
# <ipython-input-6-1e580cb0aac0>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd_cor["subject"][i] = fd_cor["bids_name"][i][0]
# <ipython-input-6-1e580cb0aac0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd_cor["wave"][i] = fd_cor["bids_name"][i][1]

# %%
fd_cor.head()
# Out:
#                                 bids_name   subject       wave       aor  \
# 0  [sub-0015, ses-wave1, task-rest, bold]  sub-0015  ses-wave1  0.006006
# 1  [sub-0015, ses-wave3, task-rest, bold]  sub-0015  ses-wave3  0.000899
# 2  [sub-0085, ses-wave2, task-rest, bold]  sub-0085  ses-wave2  0.000957
# 3  [sub-0085, ses-wave3, task-rest, bold]  sub-0085  ses-wave3  0.002002
# 4  [sub-0086, ses-wave1, task-rest, bold]  sub-0086  ses-wave1  0.018828
#
#         aqi  dummy_trs  dvars_nstd  dvars_std  dvars_vstd       efc  ...  \
# 0  0.032845          0   41.352940   1.154422    1.039241  0.391380  ...
# 1  0.017761          0   37.355798   1.292336    0.993327  0.395745  ...
# 2  0.020011          0   36.674423   1.192335    1.018124  0.370917  ...
# 3  0.032506          0   34.891304   1.129925    0.949688  0.374768  ...
# 4  0.043133          0   47.081587   1.171964    1.113701  0.376065  ...
#
#    summary_bg_stdv  summary_fg_k  summary_fg_mad  summary_fg_mean  \
# ...

# %% [markdown]
# ### deleting ses-wave1 rows

# %%
w2 = fd_cor["wave"] == "ses-wave2"
w3 = fd_cor["wave"] == "ses-wave3"
fd_cor = fd_cor[w2 | w3]

# %%
#fd_cor = fd_cor.set_index('subject')
fd_cor.shape[0]
# Out:
# 185

# %%
subs= fd_cor[['subject', 'wave']]
subs.head()
# Out:
#     subject       wave
# 1  sub-0015  ses-wave3
# 2  sub-0085  ses-wave2
# 3  sub-0085  ses-wave3
# 5  sub-0086  ses-wave3
# 6  sub-0134  ses-wave3

# %% [markdown]
# ### deleting waves of subs with fd<0.5

# %%
directory = '/media/tara/HD710PRO/Thesis/NICAP_ADHD_sleep_DATA_FD'

for i, sub in enumerate(subs['subject'].transpose()):
    try:
        wave = subs['wave'][i]
        path = directory + '/' + sub + '/' + wave
        shutil.rmtree(path)
    except:
        print(sub)
        continue
# Out:
# sub-0015
# sub-0085
# sub-0085
# sub-0086
# sub-0134
# sub-0152
# sub-0152
# sub-0225
# sub-0260
# sub-0307
# sub-0307
# sub-0334
# sub-0334
# sub-0412
# sub-0412
# sub-0517
# sub-0526
# sub-0526
# sub-0550
# sub-0550
# sub-0575
# sub-0575
# sub-0613
# sub-0613
# sub-0616
# sub-0616
# sub-0647
# sub-0755
# sub-0788
# sub-0802
# sub-0802
# sub-0856
# sub-0856
# sub-1081
# sub-1081
# sub-1110
# sub-1110
# sub-1127
# sub-1127
# sub-1170
# sub-1170
# sub-1170
# sub-1264
# sub-1264
# sub-1274
# sub-1274
# sub-1274
# sub-1348
# sub-1403
# sub-1490
# sub-1490
# sub-1596
# sub-1714
# sub-1714
# sub-1745
# sub-1745
# sub-1764
# sub-1837
# sub-1837
# sub-1908
# sub-1908
# sub-1938
# sub-1938
# sub-1994
# sub-1994
# sub-2004
# sub-2004
# sub-2031
# sub-2031
# sub-2051
# sub-2051
# sub-2093
# sub-2093
# sub-2105
# sub-2105
# sub-2144
# sub-2159
# sub-2263
# sub-2263
# sub-2306
# sub-2348
# sub-2442
# sub-2447
# sub-2498
# sub-2498
# sub-2523
# sub-2564
# sub-2582
# sub-2583
# sub-2616
# ...

# %% [markdown]
# ### deleting empty folders

# %%
c=-1
for file in os.listdir(directory):
    path = directory + '/' + file
    ss=os.listdir(path)
    for i in range(len(ss)):
        if ss[i].find('.')==0:
            continue
        c+=1
    if c==-1:
        shutil.rmtree(path) # Delete..
    c=-1

# %% [markdown]
# ### fd<0.5:

# %%
fd = pd.read_csv('/media/tara/HD710PRO/Thesis/group_bold_max_crr.tsv', sep='\t')

# %% [markdown]
# ### spliting subjects and waves from bids_name

# %%
fd["bids_name"] = fd["bids_name"].str.split("_")

# %%
fd.insert(2, "subject", "0")
fd.insert(3, "wave", "0")
fd = fd.drop('Unnamed: 0', axis=1)
fd.head()
# Out:
#                                         bids_name subject wave       aor  \
# 0  [sub-0152, ses-wave1, task-rest, run-02, bold]       0    0  0.069217
# 1          [sub-0225, ses-wave1, task-rest, bold]       0    0  0.017809
# 2          [sub-0225, ses-wave2, task-rest, bold]       0    0  0.013058
# 3          [sub-0550, ses-wave1, task-rest, bold]       0    0  0.017346
# 4          [sub-0642, ses-wave1, task-rest, bold]       0    0  0.019006
#
#         aqi  dummy_trs  dvars_nstd  dvars_std  dvars_vstd       efc  ...  \
# 0  0.121768          0  123.469659   1.920597    4.070541  0.367816  ...
# 1  0.071585          0   61.629625   1.125930    1.062236  0.406290  ...
# 2  0.058460          0   52.441892   1.165983    1.081985  0.401961  ...
# 3  0.061564          0   53.955015   1.162997    1.047936  0.398887  ...
# 4  0.096072          0   78.688069   1.184838    1.111195  0.411635  ...
#
#    summary_bg_stdv  summary_fg_k  summary_fg_mad  summary_fg_mean  \
# ...

# %%
for i in range(fd.shape[0]):
    fd["subject"][i] = fd["bids_name"][i][0]
    fd["wave"][i] = fd["bids_name"][i][1]
# Out:
# <ipython-input-16-d5c1835bea86>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd["subject"][i] = fd["bids_name"][i][0]
# <ipython-input-16-d5c1835bea86>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd["wave"][i] = fd["bids_name"][i][1]

# %%
fd
# Out:
#                                          bids_name   subject       wave  \
# 0   [sub-0152, ses-wave1, task-rest, run-02, bold]  sub-0152  ses-wave1
# 1           [sub-0225, ses-wave1, task-rest, bold]  sub-0225  ses-wave1
# 2           [sub-0225, ses-wave2, task-rest, bold]  sub-0225  ses-wave2
# 3           [sub-0550, ses-wave1, task-rest, bold]  sub-0550  ses-wave1
# 4           [sub-0642, ses-wave1, task-rest, bold]  sub-0642  ses-wave1
# 5           [sub-0642, ses-wave2, task-rest, bold]  sub-0642  ses-wave2
# 6           [sub-0647, ses-wave1, task-rest, bold]  sub-0647  ses-wave1
# 7           [sub-0647, ses-wave3, task-rest, bold]  sub-0647  ses-wave3
# 8           [sub-0718, ses-wave2, task-rest, bold]  sub-0718  ses-wave2
# 9           [sub-0751, ses-wave2, task-rest, bold]  sub-0751  ses-wave2
# 10          [sub-1705, ses-wave1, task-rest, bold]  sub-1705  ses-wave1
# 11  [sub-1759, ses-wave1, task-rest, run-01, bold]  sub-1759  ses-wave1
# ...

# %% [markdown]
# ### deleting ses-wave1 rows

# %%
w2 = fd["wave"] == "ses-wave2"
w3 = fd["wave"] == "ses-wave3"
fd = fd[w2 | w3]

# %%
subs = fd[['subject', 'wave']]
subs = subs.reset_index(drop=True)
subs.head()
# Out:
#     subject       wave
# 0  sub-0225  ses-wave2
# 1  sub-0642  ses-wave2
# 2  sub-0647  ses-wave3
# 3  sub-0718  ses-wave2
# 4  sub-0751  ses-wave2

# %% [markdown]
# ### deleting waves of subs with fd>0.5

# %%
directory = '/media/tara/HD710PRO/Thesis/NICAP_ADHD_sleep_DATA(fd)'

for i, sub in enumerate(subs['subject'].transpose()):
    try:
        wave = subs['wave'][i]
        path = directory + '/' + sub + '/' + wave
        shutil.rmtree(path)
    except:
        print(sub)
        continue
# Out:
# sub-5449

# %% [markdown]
# ### deleting empty folders

# %%
c=-1
for file in os.listdir(directory):
    path = directory + '/' + file
    ss=os.listdir(path)
    for i in range(len(ss)):
        if ss[i].find('.')==0:
            continue
        c+=1
    if c==-1:
        shutil.rmtree(path) # Delete..
    c=-1
