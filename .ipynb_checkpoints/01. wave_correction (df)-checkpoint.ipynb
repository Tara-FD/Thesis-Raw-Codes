# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os 
import shutil 
import csv

# %%
data = pd.read_csv('group_bold.tsv', sep='\t')

# %%
data.head()
# Out:
#                            bids_name       aor       aqi  dummy_trs  \
# 0  sub-0015_ses-wave1_task-rest_bold  0.006006  0.032845          0
# 1  sub-0015_ses-wave3_task-rest_bold  0.000899  0.017761          0
# 2  sub-0085_ses-wave2_task-rest_bold  0.000957  0.020011          0
# 3  sub-0085_ses-wave3_task-rest_bold  0.002002  0.032506          0
# 4  sub-0086_ses-wave1_task-rest_bold  0.018828  0.043133          0
#
#    dvars_nstd  dvars_std  dvars_vstd       efc          fber   fd_mean  ...  \
# 0   41.352940   1.154422    1.039241  0.391380  10046.058594  0.273411  ...
# 1   37.355798   1.292336    0.993327  0.395745  13287.402344  0.110859  ...
# 2   36.674423   1.192335    1.018124  0.370917  16799.005859  0.217484  ...
# 3   34.891304   1.129925    0.949688  0.374768  18025.064453  0.248734  ...
# 4   47.081587   1.171964    1.113701  0.376065  15374.750000  0.472085  ...
#
#    summary_bg_stdv  summary_fg_k  summary_fg_mad  summary_fg_mean  \
# ...

# %%
dataM = data[data["fd_mean"] > 0.5]

# %%
datam = data[data["fd_mean"] < 0.5]

# %% [markdown]
# #### ByeBye (ses-wave1)

# %%
directory = '/media/tara/HD710PRO/Thesis/NICAP_ADHD_sleep_DATA'
for file in os.listdir(directory):
    path = directory + '/' + file
    try:
        shutil.rmtree(path + '/ses-wave1', ignore_errors=False, onerror=None)
    except:
        continue
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-6a91eea7500a> in <module>
#       1 directory = '/media/tara/HD710PRO/Thesis/NICAP_ADHD_sleep_DATA'
# ----> 2 for file in os.listdir(directory):
#       3     path = directory + '/' + file
#       4     try:
#       5         shutil.rmtree(path + '/ses-wave1', ignore_errors=False, onerror=None)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/media/tara/HD710PRO/Thesis/NICAP_ADHD_sleep_DATA'

# %%
datam.describe()
# Out:
#               aor         aqi   dummy_trs  dvars_nstd   dvars_std  dvars_vstd  \
# count  286.000000  286.000000  286.000000  286.000000  286.000000  286.000000
# mean     0.005521    0.026507    0.013986   37.357423    1.219254    1.032156
# std      0.006531    0.010670    0.144417    6.908492    0.103230    0.117249
# min      0.000430    0.009347    0.000000   24.663256    1.000276    0.941157
# 25%      0.001402    0.018364    0.000000   32.569934    1.149898    0.997631
# 50%      0.003135    0.024378    0.000000   35.816770    1.202320    1.016189
# 75%      0.007213    0.032647    0.000000   40.882500    1.271620    1.044592
# max      0.050133    0.059920    2.000000   74.183486    1.755464    2.799270
#
#               efc          fber     fd_mean      fd_num  ...  summary_bg_stdv  \
# count  286.000000    286.000000  286.000000  286.000000  ...       286.000000
# mean     0.394334  16399.740472    0.213229   75.527972  ...       129.803023
# ...

# %%
datam.to_csv('group_bold_mcrr.tsv', sep = '\t', quoting = csv.QUOTE_NONE)

# %%
dataM.to_csv('group_bold_Mcrr.tsv', sep = '\t', quoting = csv.QUOTE_NONE)
