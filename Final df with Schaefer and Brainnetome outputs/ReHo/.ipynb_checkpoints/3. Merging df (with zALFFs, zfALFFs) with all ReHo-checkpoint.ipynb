# %%
import nibabel as nl
import numpy as np
import pandas as pd
import os, shutil

# %%
df = pd.read_csv('df_with_schaefer_brainnetome_zfALFF_CorticalRemoved.csv')
df.head()
# Out:
#    Unnamed: 0 Subject_ID imaging waves  snr_total  \
# 0           0   sub-0015     ses-wave3  11.837327
# 1           1   sub-0085     ses-wave2  11.131926
# 2           2   sub-0134     ses-wave3  10.562882
# 3           3   sub-0152     ses-wave2  12.745413
# 4           4   sub-0260     ses-wave2  11.458236
#
#    zfALFF_17Networks_RH_TempPar_10  zfALFF_17Networks_RH_TempPar_9  \
# 0                         0.101760                       -0.155537
# 1                         0.109652                        0.450457
# 2                         0.194081                       -0.011667
# 3                        -0.077667                       -0.631299
# 4                         0.226929                        0.336683
#
#    zfALFF_17Networks_RH_TempPar_8  zfALFF_17Networks_RH_TempPar_7  \
# 0                        0.188868                        0.417086
# 1                        0.391265                        0.398096
# ...

# %%
df = df.drop('Unnamed: 0', axis=1)
df.head()
# Out:
#   Subject_ID imaging waves  snr_total  zfALFF_17Networks_RH_TempPar_10  \
# 0   sub-0015     ses-wave3  11.837327                         0.101760
# 1   sub-0085     ses-wave2  11.131926                         0.109652
# 2   sub-0134     ses-wave3  10.562882                         0.194081
# 3   sub-0152     ses-wave2  12.745413                        -0.077667
# 4   sub-0260     ses-wave2  11.458236                         0.226929
#
#    zfALFF_17Networks_RH_TempPar_9  zfALFF_17Networks_RH_TempPar_8  \
# 0                       -0.155537                        0.188868
# 1                        0.450457                        0.391265
# 2                       -0.011667                        0.341790
# 3                       -0.631299                       -0.227984
# 4                        0.336683                        0.265665
#
#    zfALFF_17Networks_RH_TempPar_7  zfALFF_17Networks_RH_TempPar_6  \
# 0                        0.417086                        0.480759
# ...

# %% [markdown]
# ## adding zfALFF of BN to dataframe

# %% [markdown]
# ### list of zfALFF (BN)

# %%
# opening the text file
lis = []
with open('zReHo_BN_meants.txt','r') as ALFFout:
   
    # reading each line    
    for line in ALFFout:
   
        # reading each word        
        for ALFF in line.split():
            lis.append(float(ALFF))
            # displaying the words           
            #print(ALFF)

# %% [markdown]
# ### list of region names in BN Atlas (246parc)

# %%
token = open('BN_Atlas_246_LUT.txt','r')
linestoken=token.readlines()
tokens_column_number = 1
parname=[]
for x in linestoken:
    parname.append(x.split()[tokens_column_number])
token.close()
print(parname)
# Out:
# ['A8m_L', 'A8m_R', 'A8dl_L', 'A8dl_R', 'A9l_L', 'A9l_R', 'A6dl_L', 'A6dl_R', 'A6m_L', 'A6m_R', 'A9m_L', 'A9m_R', 'A10m_L', 'A10m_R', 'A9/46d_L', 'A9/46d_R', 'IFJ_L', 'IFJ_R', 'A46_L', 'A46_R', 'A9/46v_L', 'A9/46v_R', 'A8vl_L', 'A8vl_R', 'A6vl_L', 'A6vl_R', 'A10l_L', 'A10l_R', 'A44d_L', 'A44d_R', 'IFS_L', 'IFS_R', 'A45c_L', 'A45c_R', 'A45r_L', 'A45r_R', 'A44op_L', 'A44op_R', 'A44v_L', 'A44v_R', 'A14m_L', 'A14m_R', 'A12/47o_L', 'A12/47o_R', 'A11l_L', 'A11l_R', 'A11m_L', 'A11m_R', 'A13_L', 'A13_R', 'A12/47l_L', 'A12/47l_R', 'A4hf_L', 'A4hf_R', 'A6cdl_L', 'A6cdl_R', 'A4ul_L', 'A4ul_R', 'A4t_L', 'A4t_R', 'A4tl_L', 'A4tl_R', 'A6cvl_L', 'A6cvl_R', 'A1/2/3ll_L', 'A1/2/3ll_R', 'A4ll_L', 'A4ll_R', 'A38m_L', 'A38m_R', 'A41/42_L', 'A41/42_R', 'TE1.0/TE1.2_L', 'TE1.0/TE1.2_R', 'A22c_L', 'A22c_R', 'A38l_L', 'A38l_R', 'A22r_L', 'A22r_R', 'A21c_L', 'A21c_R', 'A21r_L', 'A21r_R', 'A37dl_L', 'A37dl_R', 'aSTS_L', 'aSTS_R', 'A20iv_L', 'A20iv_R', 'A37elv_L', 'A37elv_R', 'A20r_L', 'A20r_R', 'A20il_L', 'A20
# ...

# %%
len(parname)
# Out:
# 246

# %% [markdown]
# ### merging regions and their values with dataframe

# %%
test = df.set_index('Subject_ID')
inds = test.index
test.head()
# Out:
#            imaging waves  snr_total  zfALFF_17Networks_RH_TempPar_10  \
# Subject_ID
# sub-0015       ses-wave3  11.837327                         0.101760
# sub-0085       ses-wave2  11.131926                         0.109652
# sub-0134       ses-wave3  10.562882                         0.194081
# sub-0152       ses-wave2  12.745413                        -0.077667
# sub-0260       ses-wave2  11.458236                         0.226929
#
#             zfALFF_17Networks_RH_TempPar_9  zfALFF_17Networks_RH_TempPar_8  \
# Subject_ID
# sub-0015                         -0.155537                        0.188868
# sub-0085                          0.450457                        0.391265
# sub-0134                         -0.011667                        0.341790
# sub-0152                         -0.631299                       -0.227984
# sub-0260                          0.336683                        0.265665
#
# ...

# %%
df = pd.DataFrame()
for j, ind in enumerate(inds):
    sub = test.loc[[ind]]
    for i, pars in enumerate(parname):
        col_name = 'zReHo_'+str(pars)
        if col_name not in sub:
            sub.insert(2, col_name, np.nan, True)
        sub[col_name] = lis[i+j*246]
    df = pd.concat([df, sub])

# %%
df.head()
# Out:
#            imaging waves  snr_total  zReHo_lPFtha_R  zReHo_lPFtha_L  \
# Subject_ID
# sub-0015       ses-wave3  11.837327       -0.680650       -0.740437
# sub-0085       ses-wave2  11.131926       -0.607122       -0.614975
# sub-0134       ses-wave3  10.562882       -0.263834       -0.493474
# sub-0152       ses-wave2  12.745413        0.258873        0.978757
# sub-0260       ses-wave2  11.458236       -0.338928       -0.980045
#
#             zReHo_cTtha_R  zReHo_cTtha_L  zReHo_Otha_R  zReHo_Otha_L  \
# Subject_ID
# sub-0015        -0.698144      -0.650759     -0.733759     -0.700806
# sub-0085        -0.431298      -0.432305     -0.471722     -0.649952
# sub-0134        -0.278857      -0.294843     -0.368193     -0.633978
# sub-0152         0.155146       0.000891      0.075672     -0.116517
# sub-0260        -0.135230      -0.253972     -0.105502     -0.099361
#
#             zReHo_PPtha_R  zReHo_PPtha_L  ...  summary_wm_mean  \
# Subject_ID                                ...
# ...

# %%
2050-1805+1
# Out:
# 246

# %%
df.to_csv("df_with_zReHo_brainnetome.csv")

# %% [markdown]
# ## adding zALFF of Schaefer to the dataframe

# %% [markdown]
# ### list of zALFF (Schaefer)

# %%
df = pd.read_csv('df_with_zReHo_brainnetome.csv')
df.head()
# Out:
#   Subject_ID imaging waves  snr_total  zReHo_lPFtha_R  zReHo_lPFtha_L  \
# 0   sub-0015     ses-wave3  11.837327       -0.680650       -0.740437
# 1   sub-0085     ses-wave2  11.131926       -0.607122       -0.614975
# 2   sub-0134     ses-wave3  10.562882       -0.263834       -0.493474
# 3   sub-0152     ses-wave2  12.745413        0.258873        0.978757
# 4   sub-0260     ses-wave2  11.458236       -0.338928       -0.980045
#
#    zReHo_cTtha_R  zReHo_cTtha_L  zReHo_Otha_R  zReHo_Otha_L  zReHo_PPtha_R  \
# 0      -0.698144      -0.650759     -0.733759     -0.700806      -0.594061
# 1      -0.431298      -0.432305     -0.471722     -0.649952      -0.509859
# 2      -0.278857      -0.294843     -0.368193     -0.633978      -0.544125
# 3       0.155146       0.000891      0.075672     -0.116517      -0.169480
# 4      -0.135230      -0.253972     -0.105502     -0.099361      -0.202247
#
#    ...  summary_wm_mean  summary_wm_median  summary_wm_n  summary_wm_p05  \
# ...

# %%
# opening the text file
lis = []
with open('zReHo_Schaefer_meants.txt','r') as ALFFout:
   
    # reading each line    
    for line in ALFFout:
   
        # reading each word        
        for ALFF in line.split():
            lis.append(float(ALFF))
            # displaying the words           
            #print(ALFF)

# %% [markdown]
# ### list of region names in Schaefer Atlas (400 parc-17 net)

# %%
token = open('Schaefer2018_400Parcels_17Networks_order.txt','r')
linestoken=token.readlines()
tokens_column_number = 1
parname=[]
for x in linestoken:
    parname.append(x.split()[tokens_column_number])
token.close()
print(parname)
# Out:
# ['17Networks_LH_VisCent_ExStr_1', '17Networks_LH_VisCent_ExStr_2', '17Networks_LH_VisCent_ExStr_3', '17Networks_LH_VisCent_ExStr_4', '17Networks_LH_VisCent_ExStr_5', '17Networks_LH_VisCent_ExStr_6', '17Networks_LH_VisCent_Striate_1', '17Networks_LH_VisCent_ExStr_7', '17Networks_LH_VisCent_ExStr_8', '17Networks_LH_VisCent_ExStr_9', '17Networks_LH_VisCent_ExStr_10', '17Networks_LH_VisCent_ExStr_11', '17Networks_LH_VisPeri_ExStrInf_1', '17Networks_LH_VisPeri_ExStrInf_2', '17Networks_LH_VisPeri_ExStrInf_3', '17Networks_LH_VisPeri_ExStrInf_4', '17Networks_LH_VisPeri_ExStrInf_5', '17Networks_LH_VisPeri_StriCal_1', '17Networks_LH_VisPeri_StriCal_2', '17Networks_LH_VisPeri_ExStrSup_1', '17Networks_LH_VisPeri_ExStrSup_2', '17Networks_LH_VisPeri_ExStrSup_3', '17Networks_LH_VisPeri_ExStrSup_4', '17Networks_LH_VisPeri_ExStrSup_5', '17Networks_LH_SomMotA_1', '17Networks_LH_SomMotA_2', '17Networks_LH_SomMotA_3', '17Networks_LH_SomMotA_4', '17Networks_LH_SomMotA_5', '17Networks_LH_SomMotA_6', '17Ne
# ...

# %% [markdown]
# ### merging regions and their values with dataframe

# %%
df = pd.read_csv('df_with_zReHo_brainnetome.csv')
test = df.set_index('Subject_ID')
inds = test.index
#inds
df.head()
# Out:
#   Subject_ID imaging waves  snr_total  zReHo_lPFtha_R  zReHo_lPFtha_L  \
# 0   sub-0015     ses-wave3  11.837327       -0.680650       -0.740437
# 1   sub-0085     ses-wave2  11.131926       -0.607122       -0.614975
# 2   sub-0134     ses-wave3  10.562882       -0.263834       -0.493474
# 3   sub-0152     ses-wave2  12.745413        0.258873        0.978757
# 4   sub-0260     ses-wave2  11.458236       -0.338928       -0.980045
#
#    zReHo_cTtha_R  zReHo_cTtha_L  zReHo_Otha_R  zReHo_Otha_L  zReHo_PPtha_R  \
# 0      -0.698144      -0.650759     -0.733759     -0.700806      -0.594061
# 1      -0.431298      -0.432305     -0.471722     -0.649952      -0.509859
# 2      -0.278857      -0.294843     -0.368193     -0.633978      -0.544125
# 3       0.155146       0.000891      0.075672     -0.116517      -0.169480
# 4      -0.135230      -0.253972     -0.105502     -0.099361      -0.202247
#
#    ...  summary_wm_mean  summary_wm_median  summary_wm_n  summary_wm_p05  \
# ...

# %%
df = pd.DataFrame()
for j, ind in enumerate(inds):
    sub = test.loc[[ind]]
    for i, pars in enumerate(parname):
        col_name = 'zReHo_'+str(pars)
        if col_name not in sub:
            sub.insert(2, col_name, np.nan, True)
        sub[col_name] = lis[i+j*400]
    df = pd.concat([df, sub])

# %%
df.head()
# Out:
#            imaging waves  snr_total  zReHo_17Networks_RH_TempPar_10  \
# Subject_ID
# sub-0015       ses-wave3  11.837327                        0.566731
# sub-0085       ses-wave2  11.131926                       -0.154702
# sub-0134       ses-wave3  10.562882                       -0.098518
# sub-0152       ses-wave2  12.745413                       -0.664612
# sub-0260       ses-wave2  11.458236                       -0.241127
#
#             zReHo_17Networks_RH_TempPar_9  zReHo_17Networks_RH_TempPar_8  \
# Subject_ID
# sub-0015                         0.103034                      -0.110347
# sub-0085                         0.397516                       0.180303
# sub-0134                         0.248985                      -0.234874
# sub-0152                        -0.645582                      -0.821353
# sub-0260                        -0.046510                      -0.186124
#
#             zReHo_17Networks_RH_TempPar_7  zReHo_17Networks_RH_TempPar_6  \
# Subject_ID
# ...

# %%
df.to_csv("df_with_zReHo_brainnetome_Schaefer.csv")

# %% [markdown]
# ### removing cortical regions of BN

# %%
df = pd.read_csv("df_with_zReHo_brainnetome_Schaefer.csv")
df.head()
# Out:
#   Subject_ID imaging waves  snr_total  zReHo_17Networks_RH_TempPar_10  \
# 0   sub-0015     ses-wave3  11.837327                        0.566731
# 1   sub-0085     ses-wave2  11.131926                       -0.154702
# 2   sub-0134     ses-wave3  10.562882                       -0.098518
# 3   sub-0152     ses-wave2  12.745413                       -0.664612
# 4   sub-0260     ses-wave2  11.458236                       -0.241127
#
#    zReHo_17Networks_RH_TempPar_9  zReHo_17Networks_RH_TempPar_8  \
# 0                       0.103034                      -0.110347
# 1                       0.397516                       0.180303
# 2                       0.248985                      -0.234874
# 3                      -0.645582                      -0.821353
# 4                      -0.046510                      -0.186124
#
#    zReHo_17Networks_RH_TempPar_7  zReHo_17Networks_RH_TempPar_6  \
# 0                       0.571371                       0.313235
# ...

# %%
df.columns.get_loc('zReHo_lsOccG_R')
# Out:
# 439

# %%
df.columns.get_loc('zReHo_A8m_L')
# Out:
# 648

# %%
df.drop(df.columns[439:648], axis = 1, inplace = True)
  
df.head()
# Out:
#   Subject_ID imaging waves  snr_total  zReHo_17Networks_RH_TempPar_10  \
# 0   sub-0015     ses-wave3  11.837327                        0.566731
# 1   sub-0085     ses-wave2  11.131926                       -0.154702
# 2   sub-0134     ses-wave3  10.562882                       -0.098518
# 3   sub-0152     ses-wave2  12.745413                       -0.664612
# 4   sub-0260     ses-wave2  11.458236                       -0.241127
#
#    zReHo_17Networks_RH_TempPar_9  zReHo_17Networks_RH_TempPar_8  \
# 0                       0.103034                      -0.110347
# 1                       0.397516                       0.180303
# 2                       0.248985                      -0.234874
# 3                      -0.645582                      -0.821353
# 4                      -0.046510                      -0.186124
#
#    zReHo_17Networks_RH_TempPar_7  zReHo_17Networks_RH_TempPar_6  \
# 0                       0.571371                       0.313235
# ...

# %%
2451-2242+1
# Out:
# 210

# %%
df.to_csv("df_with_schaefer_brainnetome_zReHo_CorticalRemoved.csv")
