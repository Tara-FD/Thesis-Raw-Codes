# %%
import pandas as pd

# %%
df = pd.read_csv('NICAP_Data_info.csv')

# %%
df.head()
# Out:
#    id_number Subject_ID  ChildGender  d1_diagadhd_dich  d3_diagadhd_dich  \
# 0         15   sub-0015            1               0.0                 0
# 1         71   sub-0071            1               1.0                 1
# 2         85   sub-0085            0               0.0                 0
# 3         86   sub-0086            1               1.0                 1
# 4        134   sub-0134            1               0.0                 0
#
#    d5_diagadhd_dich  p0_cpadhdi_raw  p3_cpadhdi_raw  p4_cpadhdi_raw  \
# 0               0.0               0             0.0             0.0
# 1               NaN              14            12.0            12.0
# 2               0.0               5            14.0             0.0
# 3               0.0              16            11.0            18.0
# 4               0.0               2             0.0             0.0
#
#    p5_cpadhdi_raw  ...  c5_a_sws_5c  c5_a_sws_5d  c5_a_sws_5e  c5_a_sws_5f  \
# ...
