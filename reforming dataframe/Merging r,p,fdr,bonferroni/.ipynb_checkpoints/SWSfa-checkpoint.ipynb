# %%
import pandas as pd
import numpy as np
import shutil,os

# %%
r = pd.read_csv('SWSgb_r_reformed.csv')
r.head()
#r.shape
# Out:
#        parc_name                                        parcel_name  \
# 0  17Networks_17  gmd_17Networks_17zReHo_17Networks_17zfALFF_17N...
# 1  17Networks_16  gmd_17Networks_16zReHo_17Networks_16zfALFF_17N...
# 2  17Networks_15  gmd_17Networks_15zReHo_17Networks_15zfALFF_17N...
# 3  17Networks_14  gmd_17Networks_14zReHo_17Networks_14zfALFF_17N...
# 4  17Networks_13  gmd_17Networks_13zReHo_17Networks_13zfALFF_17N...
#
#    zALFF_sws_gb_r  zDCbin_sws_gb_r  zDCwei_sws_gb_r  zfALFF_sws_gb_r  \
# 0       -0.084314         0.021328         0.027930         0.005906
# 1       -0.056554         0.043758         0.038428         0.036527
# 2       -0.064141         0.073994         0.061589         0.107159
# 3       -0.057892        -0.014148        -0.012942         0.006864
# 4        0.068312         0.023997         0.029364         0.056889
#
#    zReHo_sws_gb_r  gmd_sws_gb_r    sws_gb
# 0       -0.075312      0.051392 -0.053070
# 1        0.002387      0.035596  0.100143
# ...

# %%
p = pd.read_csv('SWSgb_p_reformed.csv')
p = p[["parc_name", "zALFF_sws_gb_p", "zDCbin_sws_gb_p", "zDCwei_sws_gb_p", "zfALFF_sws_gb_p", "zReHo_sws_gb_p", "gmd_sws_gb_p"]]
p.head()
# Out:
#        parc_name  zALFF_sws_gb_p  zDCbin_sws_gb_p  zDCwei_sws_gb_p  \
# 0  17Networks_17        0.366094         0.819455         0.764998
# 1  17Networks_16        0.544756         0.639458         0.680816
# 2  17Networks_15        0.492052         0.427861         0.509473
# 3  17Networks_14        0.535261         0.879664         0.889848
# 4  17Networks_13        0.464271         0.797318         0.753311
#
#    zfALFF_sws_gb_p  zReHo_sws_gb_p  gmd_sws_gb_p
# 0         0.949608        0.419655      0.582126
# 1         0.695803        0.979621      0.703188
# 2         0.250155        0.478610      0.773109
# 3         0.941452        0.920433      0.410975
# 4         0.542369        0.924851      0.968948

# %%
p.shape
# Out:
# (453, 7)

# %%
r.shape
# Out:
# (453, 9)

# %%
r_p = r.merge(p, how = 'left', left_on = 'parc_name', right_on = 'parc_name')

# %%
r_p.shape
# Out:
# (453, 15)

# %%
r_p.head()
# Out:
#        parc_name                                        parcel_name  \
# 0  17Networks_17  gmd_17Networks_17zReHo_17Networks_17zfALFF_17N...
# 1  17Networks_16  gmd_17Networks_16zReHo_17Networks_16zfALFF_17N...
# 2  17Networks_15  gmd_17Networks_15zReHo_17Networks_15zfALFF_17N...
# 3  17Networks_14  gmd_17Networks_14zReHo_17Networks_14zfALFF_17N...
# 4  17Networks_13  gmd_17Networks_13zReHo_17Networks_13zfALFF_17N...
#
#    zALFF_sws_gb_r  zDCbin_sws_gb_r  zDCwei_sws_gb_r  zfALFF_sws_gb_r  \
# 0       -0.084314         0.021328         0.027930         0.005906
# 1       -0.056554         0.043758         0.038428         0.036527
# 2       -0.064141         0.073994         0.061589         0.107159
# 3       -0.057892        -0.014148        -0.012942         0.006864
# 4        0.068312         0.023997         0.029364         0.056889
#
#    zReHo_sws_gb_r  gmd_sws_gb_r    sws_gb  zALFF_sws_gb_p  zDCbin_sws_gb_p  \
# ...

# %%
fdr = pd.read_csv('SWSgb_fdr_reformed.csv')
fdr = fdr[["parc_name", "zALFF_sws_gb_fdr", "zDCbin_sws_gb_fdr", "zDCwei_sws_gb_fdr", "zfALFF_sws_gb_fdr", "zReHo_sws_gb_fdr", "gmd_sws_gb_fdr"]]

fdr.head()
# Out:
#                           parc_name  zALFF_sws_gb_fdr  zDCbin_sws_gb_fdr  \
# 0  17Networks_RH_DefaultA_pCunPCC_3               NaN                NaN
# 1      17Networks_RH_DefaultA_IPL_2               NaN                NaN
# 2      17Networks_RH_DefaultA_IPL_1               0.0                0.0
# 3       17Networks_RH_LimbicB_OFC_5               NaN                NaN
# 4       17Networks_RH_LimbicB_OFC_3               NaN                NaN
#
#    zDCwei_sws_gb_fdr  zfALFF_sws_gb_fdr  zReHo_sws_gb_fdr  gmd_sws_gb_fdr
# 0                NaN                NaN          0.049186             NaN
# 1                NaN                NaN          0.047971             NaN
# 2                0.0                0.0          0.047971        0.047971
# 3                NaN                NaN          0.047971             NaN
# 4                NaN                NaN          0.047971             NaN

# %%
fdr.shape
# Out:
# (99, 7)

# %%
r_p_fdr = r_p.merge(fdr, how = 'left', left_on = 'parc_name', right_on = 'parc_name')

# %%
r_p_fdr.shape
# Out:
# (453, 21)

# %%
#bonferroni = pd.read_csv('SWSgb_bonferroni_reformed.csv')
#bonferroni = bonferroni[["parc_name","zfALFF_sws_rs_bonferroni"]]
#bonferroni.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-21-45e7aa6af3d4> in <module>
# ----> 1 bonferroni = pd.read_csv('SWSgb_bonferroni_reformed.csv')
#       2 #bonferroni = bonferroni[["parc_name","zfALFF_sws_rs_bonferroni"]]
#       3 bonferroni.head()
#
# ...

# %%
#bonferroni.shape
# Out:
# (8, 2)

# %%
#r_p_fdr_bonf = r_p_fdr.merge(bonferroni, how = 'left', left_on = 'parc_name', right_on = 'parc_name')

# %%
df = r_p_fdr

# %%
df.head()
# Out:
#        parc_name                                        parcel_name  \
# 0  17Networks_17  gmd_17Networks_17zReHo_17Networks_17zfALFF_17N...
# 1  17Networks_16  gmd_17Networks_16zReHo_17Networks_16zfALFF_17N...
# 2  17Networks_15  gmd_17Networks_15zReHo_17Networks_15zfALFF_17N...
# 3  17Networks_14  gmd_17Networks_14zReHo_17Networks_14zfALFF_17N...
# 4  17Networks_13  gmd_17Networks_13zReHo_17Networks_13zfALFF_17N...
#
#    zALFF_sws_gb_r  zDCbin_sws_gb_r  zDCwei_sws_gb_r  zfALFF_sws_gb_r  \
# 0       -0.084314         0.021328         0.027930         0.005906
# 1       -0.056554         0.043758         0.038428         0.036527
# 2       -0.064141         0.073994         0.061589         0.107159
# 3       -0.057892        -0.014148        -0.012942         0.006864
# 4        0.068312         0.023997         0.029364         0.056889
#
#    zReHo_sws_gb_r  gmd_sws_gb_r    sws_gb  zALFF_sws_gb_p  ...  \
# 0       -0.075312      0.051392 -0.053070        0.366094  ...
# ...

# %%
df2 = df.reindex(sorted(df.columns), axis=1)

# %%
df2 = df2.replace({'0':np.nan, 0:np.nan})

# %%
df2
# Out:
#      gmd_sws_gb_fdr  gmd_sws_gb_p  gmd_sws_gb_r  \
# 0               NaN      0.582126      0.051392
# 1               NaN      0.703188      0.035596
# 2               NaN      0.773109      0.026939
# 3               NaN      0.410975     -0.076722
# 4               NaN      0.968948     -0.003638
# ..              ...           ...           ...
# 448             NaN      0.252092      0.106725
# 449             NaN      0.925293     -0.008763
# 450             NaN      0.991644      0.000979
# 451             NaN      0.294497     -0.097733
# 452             NaN      0.856380     -0.016912
#
#                          parc_name  \
# 0                    17Networks_17
# 1                    17Networks_16
# 2                    17Networks_15
# 3                    17Networks_14
# 4                    17Networks_13
# ..                             ...
# 448  17Networks_LH_VisCent_ExStr_5
# 449  17Networks_LH_VisCent_ExStr_4
# 450  17Networks_LH_VisCent_ExStr_3
# ...

# %%
for colnames in df2.columns:
    print(colnames)
# Out:
# gmd_sws_gb_fdr
# gmd_sws_gb_p
# gmd_sws_gb_r
# parc_name
# parcel_name
# sws_gb
# zALFF_sws_gb_fdr
# zALFF_sws_gb_p
# zALFF_sws_gb_r
# zDCbin_sws_gb_fdr
# zDCbin_sws_gb_p
# zDCbin_sws_gb_r
# zDCwei_sws_gb_fdr
# zDCwei_sws_gb_p
# zDCwei_sws_gb_r
# zReHo_sws_gb_fdr
# zReHo_sws_gb_p
# zReHo_sws_gb_r
# zfALFF_sws_gb_fdr
# zfALFF_sws_gb_p
# zfALFF_sws_gb_r

# %%
df2.to_csv('SWSgb_finaldf_reformed.csv')

# %%
sum(df["gmd_sws_total_fdr"].value_counts())
# Out:
# 15
