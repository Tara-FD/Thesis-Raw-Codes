# %%
import pandas as pd
import shutil, os
import numpy as np

# %%
df = pd.read_csv('df_to_reform.csv')

# %%
df = df[['parcel_name' ,'sws_total']]
df.head()
# Out:
#     parcel_name  sws_total
# 0  gmd_lPFtha_R   0.024897
# 1   gmd_cTtha_R        NaN
# 2   gmd_cTtha_L        NaN
# 3    gmd_Stha_L        NaN
# 4    gmd_dlPu_L   0.039122

# %%
df = df.dropna()
df.head()
df.to_csv('x.csv')

# %%
a = pd.read_csv('x.csv')
a.head()
a.drop('Unnamed: 0', axis = 1)
# Out:
#                                   parcel_name  sws_total
# 0                                gmd_lPFtha_R   0.024897
# 1                                  gmd_dlPu_L   0.039122
# 2              gmd_17Networks_RH_ContC_pCun_2   0.045455
# 3               gmd_17Networks_RH_ContB_IPL_1   0.043395
# 4                gmd_17Networks_RH_SomMotA_11   0.031546
# ..                                        ...        ...
# 229                           zDCbin_mPMtha_L   0.033066
# 230  zReHo_17Networks_RH_SalVentAttnB_PFCmp_2   0.034363
# 231    zReHo_17Networks_RH_SalVentAttnB_Ins_1   0.047550
# 232  zReHo_17Networks_RH_SalVentAttnA_FrMed_1   0.038851
# 233     zReHo_17Networks_RH_DorsAttnB_PostC_2   0.026329
#
# [234 rows x 2 columns]

# %%
a.insert(2, 'parc_name', np.nan)
a.head()
# Out:
#    Unnamed: 0                     parcel_name  parc_name  sws_total
# 0           0                    gmd_lPFtha_R        NaN   0.024897
# 1           4                      gmd_dlPu_L        NaN   0.039122
# 2          19  gmd_17Networks_RH_ContC_pCun_2        NaN   0.045455
# 3          23   gmd_17Networks_RH_ContB_IPL_1        NaN   0.043395
# 4          35    gmd_17Networks_RH_SomMotA_11        NaN   0.031546

# %%
df = a.drop('Unnamed: 0', axis = 1)

# %%
df.head()
# Out:
#                       parcel_name  parc_name  sws_total
# 0                    gmd_lPFtha_R        NaN   0.024897
# 1                      gmd_dlPu_L        NaN   0.039122
# 2  gmd_17Networks_RH_ContC_pCun_2        NaN   0.045455
# 3   gmd_17Networks_RH_ContB_IPL_1        NaN   0.043395
# 4    gmd_17Networks_RH_SomMotA_11        NaN   0.031546

# %%
markers = ['gmd_', 'zALFF_', 'zfALFF_', 'zReHo_', 'zDCwei_', 'zDCbin_']
for i,parc in enumerate(df["parcel_name"]):
    #for i in range(df.shape[0]):
    for marker in markers:
        if parc.find(marker)==0:
            df["parc_name"][i] = df["parcel_name"][i][len(marker):]
            #print(df["sws_total"][i])
            col = marker + "sws_total_fdr" 
            if col not in df:
                df.insert(2, col, np.nan)
            df.iloc[i, df.columns.get_loc(col)] = df["sws_total"][i]
# Out:
# <ipython-input-20-591d7bc8125c>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["parc_name"][i] = df["parcel_name"][i][len(marker):]

# %%
df
# Out:
#                                   parcel_name  \
# 0                                gmd_lPFtha_R
# 1                                  gmd_dlPu_L
# 2              gmd_17Networks_RH_ContC_pCun_2
# 3               gmd_17Networks_RH_ContB_IPL_1
# 4                gmd_17Networks_RH_SomMotA_11
# ..                                        ...
# 229                           zDCbin_mPMtha_L
# 230  zReHo_17Networks_RH_SalVentAttnB_PFCmp_2
# 231    zReHo_17Networks_RH_SalVentAttnB_Ins_1
# 232  zReHo_17Networks_RH_SalVentAttnA_FrMed_1
# 233     zReHo_17Networks_RH_DorsAttnB_PostC_2
#
#                               parc_name  zDCbin_sws_total_fdr  \
# 0                              lPFtha_R                   NaN
# 1                                dlPu_L                   NaN
# 2            17Networks_RH_ContC_pCun_2                   NaN
# 3             17Networks_RH_ContB_IPL_1                   NaN
# 4              17Networks_RH_SomMotA_11                   NaN
# ..                                  ...                   ...
# 229                            mPMtha_L              0.033066
# 230  17Networks_RH_SalVentAttnB_PFCmp_2                   NaN
# 231    17Networks_RH_SalVentAttnB_Ins_1                   NaN
# 232  17Networks_RH_SalVentAttnA_FrMed_1                   NaN
# 233     17Networks_RH_DorsAttnB_PostC_2                   NaN
#
#      zDCwei_sws_total_fdr  zALFF_sws_total_fdr  zfALFF_sws_total_fdr  \
# 0                     NaN                  NaN                   NaN
# 1                     NaN                  NaN                   NaN
# 2                     NaN                  NaN                   NaN
# 3                     NaN                  NaN                   NaN
# 4                     NaN                  NaN                   NaN
# ..                    ...                  ...                   ...
# 229                   NaN                  NaN                   NaN
# 230                   NaN                  NaN                   NaN
# 231                   NaN                  NaN                   NaN
# 232                   NaN                  NaN                   NaN
# 233                   NaN                  NaN                   NaN
#
#      zReHo_sws_total_fdr  gmd_sws_total_fdr  zDCbin_sws_total  \
# 0                    NaN           0.024897               NaN
# 1                    NaN           0.039122               NaN
# 2                    NaN           0.045455               NaN
# 3                    NaN           0.043395               NaN
# 4                    NaN           0.031546               NaN
# ..                   ...                ...               ...
# 229                  NaN                NaN          0.033066
# 230             0.034363                NaN               NaN
# 231             0.047550                NaN               NaN
# 232             0.038851                NaN               NaN
# 233             0.026329                NaN               NaN
#
#      zDCwei_sws_total  zALFF_sws_total  zfALFF_sws_total  zReHo_sws_total  \
# 0                 NaN              NaN               NaN              NaN
# 1                 NaN              NaN               NaN              NaN
# 2                 NaN              NaN               NaN              NaN
# 3                 NaN              NaN               NaN              NaN
# 4                 NaN              NaN               NaN              NaN
# ..                ...              ...               ...              ...
# 229               NaN              NaN               NaN              NaN
# 230               NaN              NaN               NaN         0.034363
# 231               NaN              NaN               NaN         0.047550
# 232               NaN              NaN               NaN         0.038851
# 233               NaN              NaN               NaN         0.026329
#
#      gmd_sws_total  sws_total
# 0         0.024897   0.024897
# 1         0.039122   0.039122
# 2         0.045455   0.045455
# 3         0.043395   0.043395
# 4         0.031546   0.031546
# ..             ...        ...
# 229            NaN   0.033066
# 230            NaN   0.034363
# 231            NaN   0.047550
# 232            NaN   0.038851
# 233            NaN   0.026329
#
# [234 rows x 15 columns]

# %%
df.to_csv('reformed_fdr_gmd_Schaefer100.csv')

# %%
df2 = df.copy()
inds = df2['parc_name'].drop_duplicates().reset_index(drop=True)
df2.set_index('parc_name', inplace=True)
df3 = pd.DataFrame(columns = df2.columns)
for ind in inds:
    region = df2.loc[[ind]]
    if region.shape[0] > 1 :
        reg = region
        cols = reg.columns
        for col in cols:
            reg[col] = reg[col].sum()
        reg = reg.drop_duplicates()
        df3 = pd.concat([df3, reg])
        continue
    df3 = pd.concat([df3, region])

# %%
df3
# Out:
#                                                                          parcel_name  \
# lPFtha_R                                                                gmd_lPFtha_R
# dlPu_L                                                       gmd_dlPu_LzDCwei_dlPu_L
# 17Networks_RH_ContC_pCun_2         gmd_17Networks_RH_ContC_pCun_2zfALFF_17Network...
# 17Networks_RH_ContB_IPL_1          gmd_17Networks_RH_ContB_IPL_1zfALFF_17Networks...
# 17Networks_RH_SomMotA_11                                gmd_17Networks_RH_SomMotA_11
# ...                                                                              ...
# 17Networks_LH_DorsAttnB_PostC_1    zDCwei_17Networks_LH_DorsAttnB_PostC_1zDCbin_1...
# 17Networks_LH_DorsAttnA_TempOcc_2  zDCwei_17Networks_LH_DorsAttnA_TempOcc_2zDCbin...
# 17Networks_RH_ContC_Cingp_2                       zDCbin_17Networks_RH_ContC_Cingp_2
# 17Networks_LH_DorsAttnB_PostC_4               zDCbin_17Networks_LH_DorsAttnB_PostC_4
# 17Networks_RH_SalVentAttnB_Ins_1              zReHo_17Networks_RH_SalVentAttnB_Ins_1
#
#                                    zDCbin_sws_total_fdr  zDCwei_sws_total_fdr  \
# lPFtha_R                                            NaN                   NaN
# dlPu_L                                         0.000000              0.036824
# 17Networks_RH_ContC_pCun_2                     0.000000              0.000000
# 17Networks_RH_ContB_IPL_1                      0.000000              0.000000
# 17Networks_RH_SomMotA_11                            NaN                   NaN
# ...                                                 ...                   ...
# 17Networks_LH_DorsAttnB_PostC_1                0.026329              0.033160
# 17Networks_LH_DorsAttnA_TempOcc_2              0.044576              0.040842
# 17Networks_RH_ContC_Cingp_2                    0.048261                   NaN
# 17Networks_LH_DorsAttnB_PostC_4                0.038851                   NaN
# 17Networks_RH_SalVentAttnB_Ins_1                    NaN                   NaN
#
#                                    zALFF_sws_total_fdr  zfALFF_sws_total_fdr  \
# lPFtha_R                                           NaN                   NaN
# dlPu_L                                             0.0              0.000000
# 17Networks_RH_ContC_pCun_2                         0.0              0.038851
# 17Networks_RH_ContB_IPL_1                          0.0              0.025425
# 17Networks_RH_SomMotA_11                           NaN                   NaN
# ...                                                ...                   ...
# 17Networks_LH_DorsAttnB_PostC_1                    0.0              0.000000
# 17Networks_LH_DorsAttnA_TempOcc_2                  0.0              0.000000
# 17Networks_RH_ContC_Cingp_2                        NaN                   NaN
# 17Networks_LH_DorsAttnB_PostC_4                    NaN                   NaN
# 17Networks_RH_SalVentAttnB_Ins_1                   NaN                   NaN
#
#                                    zReHo_sws_total_fdr  gmd_sws_total_fdr  \
# lPFtha_R                                           NaN           0.024897
# dlPu_L                                         0.00000           0.039122
# 17Networks_RH_ContC_pCun_2                     0.00000           0.045455
# 17Networks_RH_ContB_IPL_1                      0.00000           0.043395
# 17Networks_RH_SomMotA_11                           NaN           0.031546
# ...                                                ...                ...
# 17Networks_LH_DorsAttnB_PostC_1                0.00000           0.000000
# 17Networks_LH_DorsAttnA_TempOcc_2              0.00000           0.000000
# 17Networks_RH_ContC_Cingp_2                        NaN                NaN
# 17Networks_LH_DorsAttnB_PostC_4                    NaN                NaN
# 17Networks_RH_SalVentAttnB_Ins_1               0.04755                NaN
#
#                                    zDCbin_sws_total  zDCwei_sws_total  \
# lPFtha_R                                        NaN               NaN
# dlPu_L                                     0.000000          0.036824
# 17Networks_RH_ContC_pCun_2                 0.000000          0.000000
# 17Networks_RH_ContB_IPL_1                  0.000000          0.000000
# 17Networks_RH_SomMotA_11                        NaN               NaN
# ...                                             ...               ...
# 17Networks_LH_DorsAttnB_PostC_1            0.026329          0.033160
# 17Networks_LH_DorsAttnA_TempOcc_2          0.044576          0.040842
# 17Networks_RH_ContC_Cingp_2                0.048261               NaN
# 17Networks_LH_DorsAttnB_PostC_4            0.038851               NaN
# 17Networks_RH_SalVentAttnB_Ins_1                NaN               NaN
#
#                                    zALFF_sws_total  zfALFF_sws_total  \
# lPFtha_R                                       NaN               NaN
# dlPu_L                                         0.0          0.000000
# 17Networks_RH_ContC_pCun_2                     0.0          0.038851
# 17Networks_RH_ContB_IPL_1                      0.0          0.025425
# 17Networks_RH_SomMotA_11                       NaN               NaN
# ...                                            ...               ...
# 17Networks_LH_DorsAttnB_PostC_1                0.0          0.000000
# 17Networks_LH_DorsAttnA_TempOcc_2              0.0          0.000000
# 17Networks_RH_ContC_Cingp_2                    NaN               NaN
# 17Networks_LH_DorsAttnB_PostC_4                NaN               NaN
# 17Networks_RH_SalVentAttnB_Ins_1               NaN               NaN
#
#                                    zReHo_sws_total  gmd_sws_total  sws_total
# lPFtha_R                                       NaN       0.024897   0.024897
# dlPu_L                                     0.00000       0.039122   0.075946
# 17Networks_RH_ContC_pCun_2                 0.00000       0.045455   0.084305
# 17Networks_RH_ContB_IPL_1                  0.00000       0.043395   0.068820
# 17Networks_RH_SomMotA_11                       NaN       0.031546   0.031546
# ...                                            ...            ...        ...
# 17Networks_LH_DorsAttnB_PostC_1            0.00000       0.000000   0.059489
# 17Networks_LH_DorsAttnA_TempOcc_2          0.00000       0.000000   0.085418
# 17Networks_RH_ContC_Cingp_2                    NaN            NaN   0.048261
# 17Networks_LH_DorsAttnB_PostC_4                NaN            NaN   0.038851
# 17Networks_RH_SalVentAttnB_Ins_1           0.04755            NaN   0.047550
#
# [177 rows x 14 columns]
