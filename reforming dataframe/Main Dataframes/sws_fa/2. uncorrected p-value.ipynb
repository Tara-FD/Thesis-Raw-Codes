# %%
import pandas as pd
import shutil, os
import numpy as np

# %%
df = pd.read_csv('p.csv')
df.head()
# Out:
#          parcel_name    sws_rs    sws_gb    sws_ms    sws_fa    sws_rw  \
# 0  gmd_17Networks_17  0.071966  0.582126  0.248658  0.455413  0.046039
# 1  gmd_17Networks_16  0.201671  0.703188  0.776469  0.457278  0.285506
# 2  gmd_17Networks_15  0.665409  0.773109  0.810119  0.239218  0.956343
# 3  gmd_17Networks_14  0.635989  0.410975  0.438266  0.596597  0.562483
# 4  gmd_17Networks_13  0.212942  0.968948  0.120675  0.291418  0.113960
#
#    sws_total
# 0   0.231128
# 1   0.323083
# 2   0.521962
# 3   0.666003
# 4   0.360521

# %%
df1 = df[['parcel_name' ,'sws_fa']]
df1.head()
# Out:
#          parcel_name    sws_fa
# 0  gmd_17Networks_17  0.455413
# 1  gmd_17Networks_16  0.457278
# 2  gmd_17Networks_15  0.239218
# 3  gmd_17Networks_14  0.596597
# 4  gmd_17Networks_13  0.291418

# %%
df1.shape
# Out:
# (2718, 2)

# %%
df2 = df1.dropna()

# %%
df2.shape
# Out:
# (2718, 2)

# %%
df2.insert(1, 'parc_name', np.nan)

# %%
df2.head()
# Out:
#          parcel_name  parc_name    sws_fa
# 0  gmd_17Networks_17        NaN  0.455413
# 1  gmd_17Networks_16        NaN  0.457278
# 2  gmd_17Networks_15        NaN  0.239218
# 3  gmd_17Networks_14        NaN  0.596597
# 4  gmd_17Networks_13        NaN  0.291418

# %%
#df2 = df2.reset_index()

# %%
#df2.head()
# Out:
#    index        parcel_name  parc_name  sws_total
# 0      0  gmd_17Networks_17        NaN   0.231128
# 1      1  gmd_17Networks_16        NaN   0.323083
# 2      2  gmd_17Networks_15        NaN   0.521962
# 3      3  gmd_17Networks_14        NaN   0.666003
# 4      4  gmd_17Networks_13        NaN   0.360521

# %%
#df = df2.drop('index', axis = 1)

# %%
df = df2

# %%
df.head()
# Out:
#          parcel_name  parc_name    sws_fa
# 0  gmd_17Networks_17        NaN  0.455413
# 1  gmd_17Networks_16        NaN  0.457278
# 2  gmd_17Networks_15        NaN  0.239218
# 3  gmd_17Networks_14        NaN  0.596597
# 4  gmd_17Networks_13        NaN  0.291418

# %%
markers = ['gmd_', 'zALFF_', 'zfALFF_', 'zReHo_', 'zDCwei_', 'zDCbin_']
for i,parc in enumerate(df["parcel_name"]):
    #for i in range(df.shape[0]):
    for marker in markers:
        if parc.find(marker)==0:
            df["parc_name"][i] = df["parcel_name"][i][len(marker):]
            #print(df["sws_total"][i])
            col = marker + "sws_fa_p" 
            if col not in df:
                df.insert(2, col, np.nan)
            df.iloc[i, df.columns.get_loc(col)] = df["sws_fa"][i]
# Out:
# <ipython-input-11-16103eb28e11>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["parc_name"][i] = df["parcel_name"][i][len(marker):]
# /home/tara/Programming/env/lib/python3.8/site-packages/pandas/core/indexing.py:1636: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
df
# Out:
#             parcel_name      parc_name  zALFF_sws_fa_p  zDCbin_sws_fa_p  \
# 0     gmd_17Networks_17  17Networks_17             NaN              NaN
# 1     gmd_17Networks_16  17Networks_16             NaN              NaN
# 2     gmd_17Networks_15  17Networks_15             NaN              NaN
# 3     gmd_17Networks_14  17Networks_14             NaN              NaN
# 4     gmd_17Networks_13  17Networks_13             NaN              NaN
# ...                 ...            ...             ...              ...
# 2713     zDCbin_rHipp_L        rHipp_L             NaN         0.704381
# 2714     zDCbin_lAmyg_R        lAmyg_R             NaN         0.707781
# 2715     zDCbin_lAmyg_L        lAmyg_L             NaN         0.682554
# 2716     zDCbin_mAmyg_R        mAmyg_R             NaN         0.628168
# 2717     zDCbin_mAmyg_L        mAmyg_L             NaN         0.729202
#
#       zDCwei_sws_fa_p  zfALFF_sws_fa_p  zReHo_sws_fa_p  gmd_sws_fa_p    sws_fa
# 0                 NaN              NaN             NaN      0.455413  0.455413
# 1                 NaN              NaN             NaN      0.457278  0.457278
# 2                 NaN              NaN             NaN      0.239218  0.239218
# 3                 NaN              NaN             NaN      0.596597  0.596597
# 4                 NaN              NaN             NaN      0.291418  0.291418
# ...               ...              ...             ...           ...       ...
# 2713              NaN              NaN             NaN           NaN  0.704381
# 2714              NaN              NaN             NaN           NaN  0.707781
# 2715              NaN              NaN             NaN           NaN  0.682554
# 2716              NaN              NaN             NaN           NaN  0.628168
# 2717              NaN              NaN             NaN           NaN  0.729202
#
# [2718 rows x 9 columns]

# %%
#df.to_csv('p_reformed.csv')

# %% [markdown]
# ### merging duplicates

# %%
#df = pd.read_csv('p_reformed.csv')
#df.head()
# Out:
#    Unnamed: 0        parcel_name      parc_name  zALFF_sws_total_p  \
# 0           0  gmd_17Networks_17  17Networks_17                NaN
# 1           1  gmd_17Networks_16  17Networks_16                NaN
# 2           2  gmd_17Networks_15  17Networks_15                NaN
# 3           3  gmd_17Networks_14  17Networks_14                NaN
# 4           4  gmd_17Networks_13  17Networks_13                NaN
#
#    zDCbin_sws_total_p  zDCwei_sws_total_p  zfALFF_sws_total_p  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN                 NaN                 NaN
# 4                 NaN                 NaN                 NaN
#
#    zReHo_sws_total_p  gmd_sws_total_p  sws_total
# 0                NaN         0.231128   0.231128
# 1                NaN         0.323083   0.323083
# 2                NaN         0.521962   0.521962
# 3                NaN         0.666003   0.666003
# 4                NaN         0.360521   0.360521

# %%
df.shape
# Out:
# (2718, 9)

# %%
df2 = df.copy()
inds = df2['parc_name'].drop_duplicates().reset_index(drop=True)
df2.set_index('parc_name', inplace=True)
df3 = pd.DataFrame(columns = df2.columns)
for ind in inds:
    region = df2.loc[[ind]]
    if region.shape[0] > 1 :
        reg = region
        cols = reg.columns
        for col in cols:
            reg[col] = reg[col].sum()
        reg = reg.drop_duplicates()
        df3 = pd.concat([df3, reg])
        continue
    df3 = pd.concat([df3, region])

# %%
df3.to_csv('SWSfa_p_reformed.csv')

# %%
df3.shape
# Out:
# (453, 8)
