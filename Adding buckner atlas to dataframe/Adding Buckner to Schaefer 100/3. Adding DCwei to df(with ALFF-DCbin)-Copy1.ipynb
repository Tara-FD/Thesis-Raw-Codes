# %%
import numpy as np
import pandas as pd
import os, shutil

# %%
df = pd.read_csv('finaldf(100).csv')
df.head()
# Out:
#    Unnamed: 0 Subject_ID  sws_rw    sws_rs  sws_gb    sws_ms    sws_fa  \
# 0           0   sub-0015     3.4  1.666667     1.4  1.833333  1.000000
# 1           1   sub-0085     2.8  2.166667     2.8  3.500000  2.166667
# 2           2   sub-0134     3.8  2.000000     3.4  2.166667  2.166667
# 3           3   sub-0152     4.0  1.666667     3.0  1.500000  2.500000
# 4           4   sub-0260     3.8  2.500000     4.0  3.600000  3.000000
#
#    sws_total  gmd_17Networks_RH_TempPar_3  gmd_lPFtha_R  ...  zDCbin_vCa_R  \
# 0   1.513333                     0.577379      0.069225  ...     -0.126716
# 1   2.560000                     0.776652      0.039463  ...     -0.535545
# 2   2.346667                     0.797153      0.072332  ...      0.372329
# 3   2.066667                     0.740820      0.043507  ...      0.101284
# 4   3.120000                     0.741721      0.040795  ...      0.399932
#
#    zDCbin_vCa_L  zDCbin_cHipp_R  zDCbin_cHipp_L  zDCbin_rHipp_R  \
# 0     -0.123496       -0.409045       -0.675619        0.039336
# 1     -0.536867       -0.761581       -0.759640       -0.570934
# 2     -0.051257        0.083118       -0.473267       -0.057132
# 3      0.145131       -0.003692        0.266627        0.181125
# 4      0.302701       -0.616848       -0.627955       -0.255518
#
#    zDCbin_rHipp_L  zDCbin_lAmyg_R  zDCbin_lAmyg_L  zDCbin_mAmyg_R  \
# 0       -0.151689       -0.286752       -0.646560       -0.480622
# 1       -0.476561       -0.741962       -0.697915       -0.607798
# 2       -0.511497       -0.595767       -0.543238       -0.744308
# 3        0.110153        0.209645       -0.008773       -0.316225
# 4       -0.601781       -0.660429       -0.659524       -0.505692
#
#    zDCbin_mAmyg_L
# 0        0.130468
# 1       -0.388198
# 2       -0.652683
# 3       -0.015972
# 4       -0.210058
#
# [5 rows x 824 columns]

# %%
#df = df.drop('Unnamed: 0', axis = 1)
df.head()
# Out:
#   Subject_ID  sws_rw    sws_rs  sws_gb    sws_ms    sws_fa  sws_total  \
# 0   sub-0015     3.4  1.666667     1.4  1.833333  1.000000   1.513333
# 1   sub-0085     2.8  2.166667     2.8  3.500000  2.166667   2.560000
# 2   sub-0134     3.8  2.000000     3.4  2.166667  2.166667   2.346667
# 3   sub-0152     4.0  1.666667     3.0  1.500000  2.500000   2.066667
# 4   sub-0260     3.8  2.500000     4.0  3.600000  3.000000   3.120000
#
#    gmd_17Networks_RH_TempPar_3  gmd_lPFtha_R  gmd_lPFtha_L  ...  zDCbin_vCa_R  \
# 0                     0.577379      0.069225      0.052117  ...     -0.126716
# 1                     0.776652      0.039463      0.037065  ...     -0.535545
# 2                     0.797153      0.072332      0.052926  ...      0.372329
# 3                     0.740820      0.043507      0.039716  ...      0.101284
# 4                     0.741721      0.040795      0.033931  ...      0.399932
#
#    zDCbin_vCa_L  zDCbin_cHipp_R  zDCbin_cHipp_L  zDCbin_rHipp_R  \
# 0     -0.123496       -0.409045       -0.675619        0.039336
# 1     -0.536867       -0.761581       -0.759640       -0.570934
# 2     -0.051257        0.083118       -0.473267       -0.057132
# 3      0.145131       -0.003692        0.266627        0.181125
# 4      0.302701       -0.616848       -0.627955       -0.255518
#
#    zDCbin_rHipp_L  zDCbin_lAmyg_R  zDCbin_lAmyg_L  zDCbin_mAmyg_R  \
# 0       -0.151689       -0.286752       -0.646560       -0.480622
# 1       -0.476561       -0.741962       -0.697915       -0.607798
# 2       -0.511497       -0.595767       -0.543238       -0.744308
# 3        0.110153        0.209645       -0.008773       -0.316225
# 4       -0.601781       -0.660429       -0.659524       -0.505692
#
#    zDCbin_mAmyg_L
# 0        0.130468
# 1       -0.388198
# 2       -0.652683
# 3       -0.015972
# 4       -0.210058
#
# [5 rows x 823 columns]

# %% [markdown]
# ### list of DCwei

# %%
# opening the text file
lis = []
with open('DCwei_Buckner_meants.txt','r') as ALFFout:
   
    # reading each line    
    for line in ALFFout:
   
        # reading each word        
        for ALFF in line.split():
            lis.append(float(ALFF))
            # displaying the words           
            #print(ALFF)

# %%
len(lis)
# Out:
# 1989

# %%
117*17
# Out:
# 1989

# %% [markdown]
# ### list of region names in Buckner Atlas (17 parc)

# %%
token = open('atl-Buckner17.txt','r')
linestoken=token.readlines()
tokens_column_number = 1
parname=[]
for x in linestoken:
    parname.append(x.split()[tokens_column_number])
token.close()
print(parname)
# Out:
# ['17Networks_1', '17Networks_2', '17Networks_3', '17Networks_4', '17Networks_5', '17Networks_6', '17Networks_7', '17Networks_8', '17Networks_9', '17Networks_10', '17Networks_11', '17Networks_12', '17Networks_13', '17Networks_14', '17Networks_15', '17Networks_16', '17Networks_17']

# %%
len(parname)
# Out:
# 17

# %%
test = df.set_index('Subject_ID')
inds = test.index

# %%
df = pd.DataFrame()
for j, ind in enumerate(inds):
    sub = test.loc[[ind]]
    for i, pars in enumerate(parname):
        col_name = 'zDCwei_'+str(pars)
        if col_name not in sub:
            sub.insert(2, col_name, np.nan, True)
        sub[col_name] = lis[i+j*17]
    df = pd.concat([df, sub])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-15-c86087a1d269> in <module>
#       6         if col_name not in sub:
#       7             sub.insert(2, col_name, np.nan, True)
# ----> 8         sub[col_name] = lis[i+j*17]
#       9     df = pd.concat([df, sub])
#
# IndexError: list index out of range

# %%
df.head()
# Out:
#             sws_rw    sws_rs  zDCwei_17Networks_17  zDCwei_17Networks_16  \
# Subject_ID
# sub-0015       3.4  1.666667             -0.220214             -0.286151
# sub-0085       2.8  2.166667              0.702476              0.295299
# sub-0134       3.8  2.000000              0.432764              0.098492
# sub-0152       4.0  1.666667              0.034481              0.017936
# sub-0260       3.8  2.500000              0.115727             -0.017387
#
#             zDCwei_17Networks_15  zDCwei_17Networks_14  zDCwei_17Networks_13  \
# Subject_ID
# sub-0015               -0.413253             -0.181720             -0.413302
# sub-0085                0.191969              0.274737              0.473989
# sub-0134               -0.026741              0.196412              0.354527
# sub-0152               -0.147460              0.008133              0.184188
# sub-0260               -0.045134             -0.041334              0.204763
#
#             zDCwei_17Networks_12  zDCwei_17Networks_11  zDCwei_17Networks_10  \
# Subject_ID
# sub-0015               -0.209712             -0.564842             -0.338808
# sub-0085                0.305587             -0.270800              0.353899
# sub-0134                0.373415             -0.094553              0.146054
# sub-0152                0.253594              0.146984              0.193318
# sub-0260               -0.042948             -0.396276             -0.047486
#
#             ...  zDCbin_vCa_R  zDCbin_vCa_L  zDCbin_cHipp_R  zDCbin_cHipp_L  \
# Subject_ID  ...
# sub-0015    ...     -0.126716     -0.123496       -0.409045       -0.675619
# sub-0085    ...     -0.535545     -0.536867       -0.761581       -0.759640
# sub-0134    ...      0.372329     -0.051257        0.083118       -0.473267
# sub-0152    ...      0.101284      0.145131       -0.003692        0.266627
# sub-0260    ...      0.399932      0.302701       -0.616848       -0.627955
#
#             zDCbin_rHipp_R  zDCbin_rHipp_L  zDCbin_lAmyg_R  zDCbin_lAmyg_L  \
# Subject_ID
# sub-0015          0.039336       -0.151689       -0.286752       -0.646560
# sub-0085         -0.570934       -0.476561       -0.741962       -0.697915
# sub-0134         -0.057132       -0.511497       -0.595767       -0.543238
# sub-0152          0.181125        0.110153        0.209645       -0.008773
# sub-0260         -0.255518       -0.601781       -0.660429       -0.659524
#
#             zDCbin_mAmyg_R  zDCbin_mAmyg_L
# Subject_ID
# sub-0015         -0.480622        0.130468
# sub-0085         -0.607798       -0.388198
# sub-0134         -0.744308       -0.652683
# sub-0152         -0.316225       -0.015972
# sub-0260         -0.505692       -0.210058
#
# [5 rows x 839 columns]

# %%
df.to_csv('DCweiofBuncker.csv')

# %%
839-823
# Out:
# 16
