# %%
import pandas as pd

# %%
# %config Completer.use_jedi = False

# %%
df = pd.read_excel('finaldf_vbm2(100) - Copy.xlsx')

# %%
df.head()
# Out:
#   Subject_ID  sws_rw    sws_rs  sws_gb    sws_ms    sws_fa  sws_total  \
# 0   sub-0015     3.4  1.666667     1.4  1.833333  1.000000   1.513333
# 1   sub-0085     2.8  2.166667     2.8  3.500000  2.166667   2.560000
# 2   sub-0134     3.8  2.000000     3.4  2.166667  2.166667   2.346667
# 3   sub-0152     4.0  1.666667     3.0  1.500000  2.500000   2.066667
# 4   sub-0260     3.8  2.500000     4.0  3.600000  3.000000   3.120000
#
#    gmd_17Networks_RH_TempPar_3  gmd_lPFtha_R  gmd_lPFtha_L  ...  zDCbin_vCa_L  \
# 0                     0.577379      0.069225      0.052117  ...     -0.123496
# 1                     0.776652      0.039463      0.037065  ...     -0.536867
# 2                     0.797153      0.072332      0.052926  ...     -0.051257
# 3                     0.740820      0.043507      0.039716  ...      0.145131
# 4                     0.741721      0.040795      0.033931  ...      0.302701
#
#    zDCbin_cHipp_R  zDCbin_cHipp_L  zDCbin_rHipp_R  zDCbin_rHipp_L  \
# ...

# %%
for col in df.columns:
    #print(col)
    of df.
# Out:
# Subject_ID
# sws_rw
# sws_rs
# sws_gb
# sws_ms
# sws_fa
# sws_total
# gmd_17Networks_RH_TempPar_3
# gmd_lPFtha_R
# gmd_lPFtha_L
# gmd_cTtha_R
# gmd_cTtha_L
# gmd_Otha_R
# gmd_Otha_L
# gmd_PPtha_R
# gmd_PPtha_L
# gmd_rTtha_R
# gmd_rTtha_L
# gmd_Stha_R
# gmd_Stha_L
# gmd_mPMtha_R
# gmd_mPMtha_L
# gmd_mPFtha_R
# gmd_mPFtha_L
# gmd_dlPu_R
# gmd_dlPu_L
# gmd_dCa_R
# gmd_dCa_L
# gmd_vmPu_R
# gmd_vmPu_L
# gmd_NAC_R
# gmd_NAC_L
# gmd_GP_R
# gmd_GP_L
# gmd_vCa_R
# gmd_vCa_L
# gmd_cHipp_R
# gmd_cHipp_L
# gmd_rHipp_R
# gmd_rHipp_L
# gmd_lAmyg_R
# gmd_lAmyg_L
# gmd_mAmyg_R
# gmd_mAmyg_L
# gmd_17Networks_RH_TempPar_2
# gmd_17Networks_RH_TempPar_1
# gmd_17Networks_RH_DefaultC_PHC_1
# gmd_17Networks_RH_DefaultC_Rsp_1
# gmd_17Networks_RH_DefaultB_PFCv_2
# gmd_17Networks_RH_DefaultB_PFCv_1
# gmd_17Networks_RH_DefaultB_PFCd_1
# gmd_17Networks_RH_DefaultA_PFCm_1
# gmd_17Networks_RH_DefaultA_pCunPCC_1
# gmd_17Networks_RH_DefaultA_PFCd_1
# gmd_17Networks_RH_DefaultA_IPL_1
# ...

# %%
df.columns.get_loc('zfALFF_A8m_L')
# Out:
# 716

# %%
df.columns.get_loc('zALFF_A8m_L')
# Out:
# 753

# %%
df.columns.get_loc('zDCbin_A8m_L')
# Out:
# 827

# %%
df.columns.get_loc('zDCwei_A8m_L')
# Out:
# 790

# %%
df.columns.get_loc('zReHo_A8m_L')
# Out:
# 679

# %%
df = df.drop(df.columns[[716,753,827,790,679]], axis = 1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-52-b81842fdc5ac> in <module>
# ----> 1 df = df.drop(df.columns[[716,753,827,790,679]], axis = 1, inplace = True)
#
# ~/Programming/env/lib/python3.8/site-packages/pandas/core/indexes/base.py in __getitem__(self, key)
#    4305             key = np.asarray(key, dtype=bool)
#    4306
# -> 4307         result = getitem(key)
#    4308         if not is_scalar(result):
#    4309             if np.ndim(result) > 1:
#
# IndexError: index 827 is out of bounds for axis 0 with size 823

# %%
df.head()
# Out:
#   Subject_ID  sws_rw    sws_rs  sws_gb    sws_ms    sws_fa  sws_total  \
# 0   sub-0015     3.4  1.666667     1.4  1.833333  1.000000   1.513333
# 1   sub-0085     2.8  2.166667     2.8  3.500000  2.166667   2.560000
# 2   sub-0134     3.8  2.000000     3.4  2.166667  2.166667   2.346667
# 3   sub-0152     4.0  1.666667     3.0  1.500000  2.500000   2.066667
# 4   sub-0260     3.8  2.500000     4.0  3.600000  3.000000   3.120000
#
#    gmd_17Networks_RH_TempPar_3  gmd_lPFtha_R  gmd_lPFtha_L  ...  zDCbin_vCa_R  \
# 0                     0.577379      0.069225      0.052117  ...     -0.126716
# 1                     0.776652      0.039463      0.037065  ...     -0.535545
# 2                     0.797153      0.072332      0.052926  ...      0.372329
# 3                     0.740820      0.043507      0.039716  ...      0.101284
# 4                     0.741721      0.040795      0.033931  ...      0.399932
#
#    zDCbin_vCa_L  zDCbin_cHipp_R  zDCbin_cHipp_L  zDCbin_rHipp_R  \
# ...

# %%
df.to_csv('finaldf(100).csv')
