# %%
import pandas as pd
import numpy as np
import shutil,os

# %%
df = pd.read_csv('final(All).csv')
df.head()
# Out:
#   Subject_ID  sws_rw    sws_rs  gmd_17Networks_17  gmd_17Networks_16  \
# 0   sub-0015     3.4  1.666667           0.882492           0.685056
# 1   sub-0085     2.8  2.166667           0.454889           0.506906
# 2   sub-0134     3.8  2.000000           0.771742           0.560614
# 3   sub-0152     4.0  1.666667           0.462843           0.496591
# 4   sub-0260     3.8  2.500000           0.560632           0.457217
#
#    gmd_17Networks_15  gmd_17Networks_14  gmd_17Networks_13  gmd_17Networks_12  \
# 0           0.434501           0.467727           0.745194           0.665437
# 1           0.465330           0.339073           0.648572           0.523868
# 2           0.392883           0.350696           0.623390           0.634853
# 3           0.394914           0.292389           0.578818           0.491259
# 4           0.358596           0.336924           0.557239           0.490245
#
#    gmd_17Networks_11  ...  zDCbin_vCa_R  zDCbin_vCa_L  zDCbin_cHipp_R  \
# 0           0.405931  ...     -0.126716     -0.123496       -0.409045
# 1           0.574304  ...     -0.535545     -0.536867       -0.761581
# 2           0.431066  ...      0.372329     -0.051257        0.083118
# 3           0.463228  ...      0.101284      0.145131       -0.003692
# 4           0.423506  ...      0.399932      0.302701       -0.616848
#
#    zDCbin_cHipp_L  zDCbin_rHipp_R  zDCbin_rHipp_L  zDCbin_lAmyg_R  \
# 0       -0.675619        0.039336       -0.151689       -0.286752
# 1       -0.759640       -0.570934       -0.476561       -0.741962
# 2       -0.473267       -0.057132       -0.511497       -0.595767
# 3        0.266627        0.181125        0.110153        0.209645
# 4       -0.627955       -0.255518       -0.601781       -0.660429
#
#    zDCbin_lAmyg_L  zDCbin_mAmyg_R  zDCbin_mAmyg_L
# 0       -0.646560       -0.480622        0.130468
# 1       -0.697915       -0.607798       -0.388198
# 2       -0.543238       -0.744308       -0.652683
# 3       -0.008773       -0.316225       -0.015972
# 4       -0.659524       -0.505692       -0.210058
#
# [5 rows x 2725 columns]

# %%
i = 0
for colname in df.columns:
    if colname.find('fALFF_')==0:
        i = i+1
print(i)
# Out:
# 17

# %%
400+36+17
# Out:
# 453

# %%
gmd,zALFF

# %%
453-436
# Out:
# 17

# %%
df.head()
# Out:
#   Subject_ID  sws_rw    sws_rs  gmd_17Networks_17  gmd_17Networks_16  \
# 0   sub-0015     3.4  1.666667           0.882492           0.685056
# 1   sub-0085     2.8  2.166667           0.454889           0.506906
# 2   sub-0134     3.8  2.000000           0.771742           0.560614
# 3   sub-0152     4.0  1.666667           0.462843           0.496591
# 4   sub-0260     3.8  2.500000           0.560632           0.457217
#
#    gmd_17Networks_15  gmd_17Networks_14  gmd_17Networks_13  gmd_17Networks_12  \
# 0           0.434501           0.467727           0.745194           0.665437
# 1           0.465330           0.339073           0.648572           0.523868
# 2           0.392883           0.350696           0.623390           0.634853
# 3           0.394914           0.292389           0.578818           0.491259
# 4           0.358596           0.336924           0.557239           0.490245
#
#    gmd_17Networks_11  ...  zDCbin_vCa_R  zDCbin_vCa_L  zDCbin_cHipp_R  \
# 0           0.405931  ...     -0.126716     -0.123496       -0.409045
# 1           0.574304  ...     -0.535545     -0.536867       -0.761581
# 2           0.431066  ...      0.372329     -0.051257        0.083118
# 3           0.463228  ...      0.101284      0.145131       -0.003692
# 4           0.423506  ...      0.399932      0.302701       -0.616848
#
#    zDCbin_cHipp_L  zDCbin_rHipp_R  zDCbin_rHipp_L  zDCbin_lAmyg_R  \
# 0       -0.675619        0.039336       -0.151689       -0.286752
# 1       -0.759640       -0.570934       -0.476561       -0.741962
# 2       -0.473267       -0.057132       -0.511497       -0.595767
# 3        0.266627        0.181125        0.110153        0.209645
# 4       -0.627955       -0.255518       -0.601781       -0.660429
#
#    zDCbin_lAmyg_L  zDCbin_mAmyg_R  zDCbin_mAmyg_L
# 0       -0.646560       -0.480622        0.130468
# 1       -0.697915       -0.607798       -0.388198
# 2       -0.543238       -0.744308       -0.652683
# 3       -0.008773       -0.316225       -0.015972
# 4       -0.659524       -0.505692       -0.210058
#
# [5 rows x 2725 columns]

# %%
df.columns = df.columns.str.replace('zzfALFF', 'zfALFF')

# %%
i = 0
for colname in df.columns:
    if colname.find('gmd_')==0:
        i = i+1
print(i)
# Out:
# 453

# %%
df.shape
# Out:
# (117, 2725)

# %%
453*6
# Out:
# 2718

# %%
2718+7
# Out:
# 2725

# %%
df.head()
# Out:
#   Subject_ID  sws_rw    sws_rs  gmd_17Networks_17  gmd_17Networks_16  \
# 0   sub-0015     3.4  1.666667           0.882492           0.685056
# 1   sub-0085     2.8  2.166667           0.454889           0.506906
# 2   sub-0134     3.8  2.000000           0.771742           0.560614
# 3   sub-0152     4.0  1.666667           0.462843           0.496591
# 4   sub-0260     3.8  2.500000           0.560632           0.457217
#
#    gmd_17Networks_15  gmd_17Networks_14  gmd_17Networks_13  gmd_17Networks_12  \
# 0           0.434501           0.467727           0.745194           0.665437
# 1           0.465330           0.339073           0.648572           0.523868
# 2           0.392883           0.350696           0.623390           0.634853
# 3           0.394914           0.292389           0.578818           0.491259
# 4           0.358596           0.336924           0.557239           0.490245
#
#    gmd_17Networks_11  ...  zDCbin_vCa_R  zDCbin_vCa_L  zDCbin_cHipp_R  \
# 0           0.405931  ...     -0.126716     -0.123496       -0.409045
# 1           0.574304  ...     -0.535545     -0.536867       -0.761581
# 2           0.431066  ...      0.372329     -0.051257        0.083118
# 3           0.463228  ...      0.101284      0.145131       -0.003692
# 4           0.423506  ...      0.399932      0.302701       -0.616848
#
#    zDCbin_cHipp_L  zDCbin_rHipp_R  zDCbin_rHipp_L  zDCbin_lAmyg_R  \
# 0       -0.675619        0.039336       -0.151689       -0.286752
# 1       -0.759640       -0.570934       -0.476561       -0.741962
# 2       -0.473267       -0.057132       -0.511497       -0.595767
# 3        0.266627        0.181125        0.110153        0.209645
# 4       -0.627955       -0.255518       -0.601781       -0.660429
#
#    zDCbin_lAmyg_L  zDCbin_mAmyg_R  zDCbin_mAmyg_L
# 0       -0.646560       -0.480622        0.130468
# 1       -0.697915       -0.607798       -0.388198
# 2       -0.543238       -0.744308       -0.652683
# 3       -0.008773       -0.316225       -0.015972
# 4       -0.659524       -0.505692       -0.210058
#
# [5 rows x 2725 columns]

# %%
column_to_move = df.pop("sws_fa")
df.insert(1, "sws_fa", column_to_move)
df.head()
# Out:
#   Subject_ID    sws_fa  sws_rw    sws_rs  gmd_17Networks_17  \
# 0   sub-0015  1.000000     3.4  1.666667           0.882492
# 1   sub-0085  2.166667     2.8  2.166667           0.454889
# 2   sub-0134  2.166667     3.8  2.000000           0.771742
# 3   sub-0152  2.500000     4.0  1.666667           0.462843
# 4   sub-0260  3.000000     3.8  2.500000           0.560632
#
#    gmd_17Networks_16  gmd_17Networks_15  gmd_17Networks_14  gmd_17Networks_13  \
# 0           0.685056           0.434501           0.467727           0.745194
# 1           0.506906           0.465330           0.339073           0.648572
# 2           0.560614           0.392883           0.350696           0.623390
# 3           0.496591           0.394914           0.292389           0.578818
# 4           0.457217           0.358596           0.336924           0.557239
#
#    gmd_17Networks_12  ...  zDCbin_vCa_R  zDCbin_vCa_L  zDCbin_cHipp_R  \
# 0           0.665437  ...     -0.126716     -0.123496       -0.409045
# 1           0.523868  ...     -0.535545     -0.536867       -0.761581
# 2           0.634853  ...      0.372329     -0.051257        0.083118
# 3           0.491259  ...      0.101284      0.145131       -0.003692
# 4           0.490245  ...      0.399932      0.302701       -0.616848
#
#    zDCbin_cHipp_L  zDCbin_rHipp_R  zDCbin_rHipp_L  zDCbin_lAmyg_R  \
# 0       -0.675619        0.039336       -0.151689       -0.286752
# 1       -0.759640       -0.570934       -0.476561       -0.741962
# 2       -0.473267       -0.057132       -0.511497       -0.595767
# 3        0.266627        0.181125        0.110153        0.209645
# 4       -0.627955       -0.255518       -0.601781       -0.660429
#
#    zDCbin_lAmyg_L  zDCbin_mAmyg_R  zDCbin_mAmyg_L
# 0       -0.646560       -0.480622        0.130468
# 1       -0.697915       -0.607798       -0.388198
# 2       -0.543238       -0.744308       -0.652683
# 3       -0.008773       -0.316225       -0.015972
# 4       -0.659524       -0.505692       -0.210058
#
# [5 rows x 2725 columns]

# %%
column_to_move = df.pop("sws_ms")
df.insert(1, "sws_ms", column_to_move)

# %%
column_to_move = df.pop("sws_gb")
df.insert(1, "sws_gb", column_to_move)

# %%
column_to_move = df.pop("sws_rs")
df.insert(1, "sws_rs", column_to_move)
df.head()
# Out:
#   Subject_ID    sws_rs  sws_gb    sws_ms    sws_fa  sws_rw  gmd_17Networks_17  \
# 0   sub-0015  1.666667     1.4  1.833333  1.000000     3.4           0.882492
# 1   sub-0085  2.166667     2.8  3.500000  2.166667     2.8           0.454889
# 2   sub-0134  2.000000     3.4  2.166667  2.166667     3.8           0.771742
# 3   sub-0152  1.666667     3.0  1.500000  2.500000     4.0           0.462843
# 4   sub-0260  2.500000     4.0  3.600000  3.000000     3.8           0.560632
#
#    gmd_17Networks_16  gmd_17Networks_15  gmd_17Networks_14  ...  zDCbin_vCa_R  \
# 0           0.685056           0.434501           0.467727  ...     -0.126716
# 1           0.506906           0.465330           0.339073  ...     -0.535545
# 2           0.560614           0.392883           0.350696  ...      0.372329
# 3           0.496591           0.394914           0.292389  ...      0.101284
# 4           0.457217           0.358596           0.336924  ...      0.399932
#
#    zDCbin_vCa_L  zDCbin_cHipp_R  zDCbin_cHipp_L  zDCbin_rHipp_R  \
# 0     -0.123496       -0.409045       -0.675619        0.039336
# 1     -0.536867       -0.761581       -0.759640       -0.570934
# 2     -0.051257        0.083118       -0.473267       -0.057132
# 3      0.145131       -0.003692        0.266627        0.181125
# 4      0.302701       -0.616848       -0.627955       -0.255518
#
#    zDCbin_rHipp_L  zDCbin_lAmyg_R  zDCbin_lAmyg_L  zDCbin_mAmyg_R  \
# 0       -0.151689       -0.286752       -0.646560       -0.480622
# 1       -0.476561       -0.741962       -0.697915       -0.607798
# 2       -0.511497       -0.595767       -0.543238       -0.744308
# 3        0.110153        0.209645       -0.008773       -0.316225
# 4       -0.601781       -0.660429       -0.659524       -0.505692
#
#    zDCbin_mAmyg_L
# 0        0.130468
# 1       -0.388198
# 2       -0.652683
# 3       -0.015972
# 4       -0.210058
#
# [5 rows x 2725 columns]

# %%
column_to_move = df.pop("sws_total")
df.insert(6, "sws_total", column_to_move)
df.head()
# Out:
#   Subject_ID    sws_rs  sws_gb    sws_ms    sws_fa  sws_rw  sws_total  \
# 0   sub-0015  1.666667     1.4  1.833333  1.000000     3.4   1.513333
# 1   sub-0085  2.166667     2.8  3.500000  2.166667     2.8   2.560000
# 2   sub-0134  2.000000     3.4  2.166667  2.166667     3.8   2.346667
# 3   sub-0152  1.666667     3.0  1.500000  2.500000     4.0   2.066667
# 4   sub-0260  2.500000     4.0  3.600000  3.000000     3.8   3.120000
#
#    gmd_17Networks_17  gmd_17Networks_16  gmd_17Networks_15  ...  zDCbin_vCa_R  \
# 0           0.882492           0.685056           0.434501  ...     -0.126716
# 1           0.454889           0.506906           0.465330  ...     -0.535545
# 2           0.771742           0.560614           0.392883  ...      0.372329
# 3           0.462843           0.496591           0.394914  ...      0.101284
# 4           0.560632           0.457217           0.358596  ...      0.399932
#
#    zDCbin_vCa_L  zDCbin_cHipp_R  zDCbin_cHipp_L  zDCbin_rHipp_R  \
# 0     -0.123496       -0.409045       -0.675619        0.039336
# 1     -0.536867       -0.761581       -0.759640       -0.570934
# 2     -0.051257        0.083118       -0.473267       -0.057132
# 3      0.145131       -0.003692        0.266627        0.181125
# 4      0.302701       -0.616848       -0.627955       -0.255518
#
#    zDCbin_rHipp_L  zDCbin_lAmyg_R  zDCbin_lAmyg_L  zDCbin_mAmyg_R  \
# 0       -0.151689       -0.286752       -0.646560       -0.480622
# 1       -0.476561       -0.741962       -0.697915       -0.607798
# 2       -0.511497       -0.595767       -0.543238       -0.744308
# 3        0.110153        0.209645       -0.008773       -0.316225
# 4       -0.601781       -0.660429       -0.659524       -0.505692
#
#    zDCbin_mAmyg_L
# 0        0.130468
# 1       -0.388198
# 2       -0.652683
# 3       -0.015972
# 4       -0.210058
#
# [5 rows x 2725 columns]

# %%
df.to_csv('ALL_DF_400.csv')
