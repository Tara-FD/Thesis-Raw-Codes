# %%
import numpy as np
import pandas as pd
import os, shutil

# %%
df = pd.read_csv('ALFFofBuncker.csv')
df.head()
# Out:
#   Subject_ID  sws_rw    sws_rs  zALFF_17Networks_17  zALFF_17Networks_16  \
# 0   sub-0015     3.4  1.666667            -0.097784             0.211779
# 1   sub-0085     2.8  2.166667            -0.301372            -0.076308
# 2   sub-0134     3.8  2.000000             0.115714             0.070625
# 3   sub-0152     4.0  1.666667             0.000605            -0.102927
# 4   sub-0260     3.8  2.500000             0.245353             0.131997
#
#    zALFF_17Networks_15  zALFF_17Networks_14  zALFF_17Networks_13  \
# 0             0.188552             0.058041            -0.159292
# 1            -0.023100            -0.130313            -0.265542
# 2             0.007440            -0.078399             0.026199
# 3            -0.207762            -0.203204            -0.048553
# 4            -0.046195            -0.023717             0.029221
#
#    zALFF_17Networks_12  zALFF_17Networks_11  ...  zDCbin_vCa_R  zDCbin_vCa_L  \
# 0             0.043830             0.132247  ...     -0.126716     -0.123496
# 1            -0.212049            -0.020326  ...     -0.535545     -0.536867
# 2             0.165447            -0.167020  ...      0.372329     -0.051257
# 3            -0.072884            -0.141654  ...      0.101284      0.145131
# 4             0.239261            -0.197322  ...      0.399932      0.302701
#
#    zDCbin_cHipp_R  zDCbin_cHipp_L  zDCbin_rHipp_R  zDCbin_rHipp_L  \
# 0       -0.409045       -0.675619        0.039336       -0.151689
# 1       -0.761581       -0.759640       -0.570934       -0.476561
# 2        0.083118       -0.473267       -0.057132       -0.511497
# 3       -0.003692        0.266627        0.181125        0.110153
# 4       -0.616848       -0.627955       -0.255518       -0.601781
#
#    zDCbin_lAmyg_R  zDCbin_lAmyg_L  zDCbin_mAmyg_R  zDCbin_mAmyg_L
# 0       -0.286752       -0.646560       -0.480622        0.130468
# 1       -0.741962       -0.697915       -0.607798       -0.388198
# 2       -0.595767       -0.543238       -0.744308       -0.652683
# 3        0.209645       -0.008773       -0.316225       -0.015972
# 4       -0.660429       -0.659524       -0.505692       -0.210058
#
# [5 rows x 2640 columns]

# %% [markdown]
# ### list of DCbin

# %%
# opening the text file
lis = []
with open('DCbin_Buckner_meants.txt','r') as ALFFout:
   
    # reading each line    
    for line in ALFFout:
   
        # reading each word        
        for ALFF in line.split():
            lis.append(float(ALFF))
            # displaying the words           
            #print(ALFF)

# %%
len(lis)
# Out:
# 1989

# %%
117*17
# Out:
# 1989

# %% [markdown]
# ### list of region names in Buckner Atlas (17 parc)

# %%
token = open('atl-Buckner17.txt','r')
linestoken=token.readlines()
tokens_column_number = 1
parname=[]
for x in linestoken:
    parname.append(x.split()[tokens_column_number])
token.close()
print(parname)
# Out:
# ['17Networks_1', '17Networks_2', '17Networks_3', '17Networks_4', '17Networks_5', '17Networks_6', '17Networks_7', '17Networks_8', '17Networks_9', '17Networks_10', '17Networks_11', '17Networks_12', '17Networks_13', '17Networks_14', '17Networks_15', '17Networks_16', '17Networks_17']

# %%
len(parname)
# Out:
# 17

# %%
test = df.set_index('Subject_ID')
inds = test.index

# %%
df = pd.DataFrame()
for j, ind in enumerate(inds):
    sub = test.loc[[ind]]
    for i, pars in enumerate(parname):
        col_name = 'zDCbin_'+str(pars)
        if col_name not in sub:
            sub.insert(2, col_name, np.nan, True)
        sub[col_name] = lis[i+j*17]
    df = pd.concat([df, sub])

# %%
df.head()
# Out:
#             sws_rw    sws_rs  zDCbin_17Networks_17  zDCbin_17Networks_16  \
# Subject_ID
# sub-0015       3.4  1.666667             -0.161382             -0.232800
# sub-0085       2.8  2.166667              0.694123              0.276264
# sub-0134       3.8  2.000000              0.437858              0.094201
# sub-0152       4.0  1.666667              0.044142             -0.038012
# sub-0260       3.8  2.500000              0.165082              0.013119
#
#             zDCbin_17Networks_15  zDCbin_17Networks_14  zDCbin_17Networks_13  \
# Subject_ID
# sub-0015               -0.388095             -0.116418             -0.382984
# sub-0085                0.204003              0.285649              0.480551
# sub-0134               -0.010428              0.206620              0.335777
# sub-0152               -0.082216             -0.056246              0.118469
# sub-0260               -0.004315              0.000788              0.228392
#
#             zDCbin_17Networks_12  zDCbin_17Networks_11  zDCbin_17Networks_10  \
# Subject_ID
# sub-0015               -0.157808             -0.576179             -0.312096
# sub-0085                0.311183             -0.271593              0.349831
# sub-0134                0.327011             -0.053063              0.126386
# sub-0152                0.190549              0.062036              0.145226
# sub-0260               -0.033524             -0.378453             -0.071097
#
#             ...  zDCbin_vCa_R  zDCbin_vCa_L  zDCbin_cHipp_R  zDCbin_cHipp_L  \
# Subject_ID  ...
# sub-0015    ...     -0.126716     -0.123496       -0.409045       -0.675619
# sub-0085    ...     -0.535545     -0.536867       -0.761581       -0.759640
# sub-0134    ...      0.372329     -0.051257        0.083118       -0.473267
# sub-0152    ...      0.101284      0.145131       -0.003692        0.266627
# sub-0260    ...      0.399932      0.302701       -0.616848       -0.627955
#
#             zDCbin_rHipp_R  zDCbin_rHipp_L  zDCbin_lAmyg_R  zDCbin_lAmyg_L  \
# Subject_ID
# sub-0015          0.039336       -0.151689       -0.286752       -0.646560
# sub-0085         -0.570934       -0.476561       -0.741962       -0.697915
# sub-0134         -0.057132       -0.511497       -0.595767       -0.543238
# sub-0152          0.181125        0.110153        0.209645       -0.008773
# sub-0260         -0.255518       -0.601781       -0.660429       -0.659524
#
#             zDCbin_mAmyg_R  zDCbin_mAmyg_L
# Subject_ID
# sub-0015         -0.480622        0.130468
# sub-0085         -0.607798       -0.388198
# sub-0134         -0.744308       -0.652683
# sub-0152         -0.316225       -0.015972
# sub-0260         -0.505692       -0.210058
#
# [5 rows x 2656 columns]

# %%
df.to_csv('ALFF-DCbinofBuncker.csv')

# %%
2656-2640
# Out:
# 16
