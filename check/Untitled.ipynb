# %%
import pandas as pd

# %%
# %config Completer.use_jedi = False

# %%
df = pd.read_csv('df_forR_toCorrect.csv')

# %%
df.head()
# Out:
#   Subject_ID  sws_total  zfALFF_17Networks_15  zfALFF_17Networks_9  \
# 0   sub-0015   1.513333             -0.347018            -0.787030
# 1   sub-0085   2.560000             -0.298331            -0.601078
# 2   sub-0134   2.346667             -0.390213            -0.799635
# 3   sub-0152   2.066667             -0.516628            -0.485006
# 4   sub-0260   3.120000             -0.314693            -0.853856
#
#    zfALFF_17Networks_2  zfALFF_lPFtha_R  zfALFF_lPFtha_L  zfALFF_cTtha_L  \
# 0            -0.445804        -0.760500        -0.929277       -0.743303
# 1            -0.304966        -0.234355        -0.397031       -0.381863
# 2            -0.231216        -1.012589        -0.840667       -0.901478
# 3            -0.223685        -0.682773        -0.294288       -0.634390
# 4            -0.356149        -0.814174        -0.863769       -0.617213
#
#    zfALFF_Otha_L  zfALFF_rTtha_R  ...  zDCwei_17Networks_LH_SomMotB_Aud_1  \
# ...

# %%
fdr = pd.read_csv('all_correlation_results(fdr).csv')
fdr.head()
# Out:
#        parc_name  gmd_sws_total_fdr  zfALFF_sws_total_fdr  \
# 0  17Networks_17                NaN                   NaN
# 1  17Networks_16                NaN                   NaN
# 2  17Networks_15                NaN                   NaN
# 3  17Networks_14                NaN                   NaN
# 4  17Networks_13                NaN                   NaN
#
#    zDCwei_sws_total_fdr  zReHo_sws_total_fdr
# 0                   NaN                  NaN
# 1                   NaN                  NaN
# 2                   NaN              0.04454
# 3                   NaN                  NaN
# 4                   NaN                  NaN

# %%
df['gmd_17Networks_15']
# Out:
# 0      0.434501
# 1      0.465330
# 2      0.392883
# 3      0.394914
# 4      0.358596
#          ...
# 112    0.434187
# 113    0.442561
# 114    0.418928
# 115    0.469685
# 116    0.408682
# Name: gmd_17Networks_15, Length: 117, dtype: float64
