# %%
import pandas as pd
import numpy as np
import shutil,os

# %%
df = pd.read_excel('finaldf_vbm2(400).xlsx')
df.head()
# Out:
#    Unnamed: 0 Subject_ID  sws_rw    sws_rs  sws_gb    sws_ms    sws_fa  \
# 0           0   sub-0015     3.4  1.666667     1.4  1.833333  1.000000
# 1           1   sub-0085     2.8  2.166667     2.8  3.500000  2.166667
# 2           2   sub-0134     3.8  2.000000     3.4  2.166667  2.166667
# 3           3   sub-0152     4.0  1.666667     3.0  1.500000  2.500000
# 4           4   sub-0260     3.8  2.500000     4.0  3.600000  3.000000
#
#    sws_total  gmd_lPFtha_R  gmd_lPFtha_L  ...  \
# 0   1.513333      0.495450      0.659972  ...
# 1   2.560000      0.660543      0.746694  ...
# 2   2.346667      0.686642      0.740850  ...
# 3   2.066667      0.647427      0.684694  ...
# 4   3.120000      0.703034      0.406097  ...
#
#    zReHo_17Networks_RH_DorsAttnA_SPL_3  zReHo_17Networks_RH_DorsAttnA_SPL_2  \
# 0                             0.632937                             0.484317
# 1                             1.272547                             0.551014
# ...

# %%
df = df.drop('Unnamed: 0', axis =1)

# %%
df.head()
# Out:
#   Subject_ID  sws_rw    sws_rs  sws_gb    sws_ms    sws_fa  sws_total  \
# 0   sub-0015     3.4  1.666667     1.4  1.833333  1.000000   1.513333
# 1   sub-0085     2.8  2.166667     2.8  3.500000  2.166667   2.560000
# 2   sub-0134     3.8  2.000000     3.4  2.166667  2.166667   2.346667
# 3   sub-0152     4.0  1.666667     3.0  1.500000  2.500000   2.066667
# 4   sub-0260     3.8  2.500000     4.0  3.600000  3.000000   3.120000
#
#    gmd_lPFtha_R  gmd_lPFtha_L  gmd_cTtha_R  ...  \
# 0      0.495450      0.659972     0.619111  ...
# 1      0.660543      0.746694     0.768806  ...
# 2      0.686642      0.740850     0.756562  ...
# 3      0.647427      0.684694     0.620015  ...
# 4      0.703034      0.406097     0.338473  ...
#
#    zReHo_17Networks_RH_DorsAttnA_SPL_3  zReHo_17Networks_RH_DorsAttnA_SPL_2  \
# 0                             0.632937                             0.484317
# 1                             1.272547                             0.551014
# ...

# %%
df.to_csv('df_400_vbm2.csv')

# %%
df = pd.read_csv('df_400_vbm2.csv')
df.head()
# Out:
#    Unnamed: 0 Subject_ID  sws_rw    sws_rs  sws_gb    sws_ms    sws_fa  \
# 0           0   sub-0015     3.4  1.666667     1.4  1.833333  1.000000
# 1           1   sub-0085     2.8  2.166667     2.8  3.500000  2.166667
# 2           2   sub-0134     3.8  2.000000     3.4  2.166667  2.166667
# 3           3   sub-0152     4.0  1.666667     3.0  1.500000  2.500000
# 4           4   sub-0260     3.8  2.500000     4.0  3.600000  3.000000
#
#    sws_total  gmd_lPFtha_R  gmd_lPFtha_L  ...  \
# 0   1.513333      0.495450      0.659972  ...
# 1   2.560000      0.660543      0.746694  ...
# 2   2.346667      0.686642      0.740850  ...
# 3   2.066667      0.647427      0.684694  ...
# 4   3.120000      0.703034      0.406097  ...
#
#    zReHo_17Networks_RH_DorsAttnA_SPL_3  zReHo_17Networks_RH_DorsAttnA_SPL_2  \
# 0                             0.632937                             0.484317
# 1                             1.272547                             0.551014
# ...

# %% [markdown]
# ### removing ReHo100 and adding ReHo400

# %%
for colname in df.columns:
    if colname.find('zDCbin_A8')==0:
        print(colname)

# %%
gmd = 436

# %%
zALFF = 436

# %%
zfALFF = 436

# %%
zDCbin = 436

# %%
zDCwei = 436

# %%
zReHo = 0

# %%
df = df[df.columns.drop(list(df.filter(regex='A8m')))]

# %%
df = df[df.columns.drop(list(df.filter(regex='zReHo')))]

# %%
i = 0
for colname in df.columns:
    if colname.find('zReHo_')==0:
        i = i+1  
print(i)
# Out:
# 0

# %%
df = df.drop('Unnamed: 0', axis =1)

# %%
df.head()
# Out:
#   Subject_ID  sws_rw    sws_rs  sws_gb    sws_ms    sws_fa  sws_total  \
# 0   sub-0015     3.4  1.666667     1.4  1.833333  1.000000   1.513333
# 1   sub-0085     2.8  2.166667     2.8  3.500000  2.166667   2.560000
# 2   sub-0134     3.8  2.000000     3.4  2.166667  2.166667   2.346667
# 3   sub-0152     4.0  1.666667     3.0  1.500000  2.500000   2.066667
# 4   sub-0260     3.8  2.500000     4.0  3.600000  3.000000   3.120000
#
#    gmd_lPFtha_R  gmd_lPFtha_L  gmd_cTtha_R  ...  zDCbin_vCa_R  zDCbin_vCa_L  \
# 0      0.495450      0.659972     0.619111  ...     -0.126716     -0.123496
# 1      0.660543      0.746694     0.768806  ...     -0.535545     -0.536867
# 2      0.686642      0.740850     0.756562  ...      0.372329     -0.051257
# 3      0.647427      0.684694     0.620015  ...      0.101284      0.145131
# 4      0.703034      0.406097     0.338473  ...      0.399932      0.302701
#
#    zDCbin_cHipp_R  zDCbin_cHipp_L  zDCbin_rHipp_R  zDCbin_rHipp_L  \
# ...

# %%
436*5
# Out:
# 2180

# %% [markdown]
# ### adding ReHo 400

# %% [markdown]
# ### zReHo Schaefer meants

# %%
# opening the text file
lis = []
with open('zReHo_Schaefer_meants.txt','r') as ALFFout:
   
    # reading each line    
    for line in ALFFout:
   
        # reading each word        
        for ALFF in line.split():
            lis.append(float(ALFF))
            # displaying the words           
            #print(ALFF)

# %%
len(lis)
# Out:
# 47200

# %%
118*400
# Out:
# 47200

# %%
token = open('Schaefer2018_400Parcels_17Networks_order.txt','r')
linestoken=token.readlines()
tokens_column_number = 1
parname=[]
for x in linestoken:
    parname.append(x.split()[tokens_column_number])
token.close()
print(parname)
# Out:
# ['17Networks_LH_VisCent_ExStr_1', '17Networks_LH_VisCent_ExStr_2', '17Networks_LH_VisCent_ExStr_3', '17Networks_LH_VisCent_ExStr_4', '17Networks_LH_VisCent_ExStr_5', '17Networks_LH_VisCent_ExStr_6', '17Networks_LH_VisCent_Striate_1', '17Networks_LH_VisCent_ExStr_7', '17Networks_LH_VisCent_ExStr_8', '17Networks_LH_VisCent_ExStr_9', '17Networks_LH_VisCent_ExStr_10', '17Networks_LH_VisCent_ExStr_11', '17Networks_LH_VisPeri_ExStrInf_1', '17Networks_LH_VisPeri_ExStrInf_2', '17Networks_LH_VisPeri_ExStrInf_3', '17Networks_LH_VisPeri_ExStrInf_4', '17Networks_LH_VisPeri_ExStrInf_5', '17Networks_LH_VisPeri_StriCal_1', '17Networks_LH_VisPeri_StriCal_2', '17Networks_LH_VisPeri_ExStrSup_1', '17Networks_LH_VisPeri_ExStrSup_2', '17Networks_LH_VisPeri_ExStrSup_3', '17Networks_LH_VisPeri_ExStrSup_4', '17Networks_LH_VisPeri_ExStrSup_5', '17Networks_LH_SomMotA_1', '17Networks_LH_SomMotA_2', '17Networks_LH_SomMotA_3', '17Networks_LH_SomMotA_4', '17Networks_LH_SomMotA_5', '17Networks_LH_SomMotA_6', '17Ne
# ...

# %%
len(parname)
# Out:
# 400

# %%
test = df.set_index('Subject_ID')
inds = test.index

# %%
df = pd.DataFrame()
for j, ind in enumerate(inds):
    sub = test.loc[[ind]]
    for i, pars in enumerate(parname):
        col_name = 'zReHo_'+str(pars)
        if col_name not in sub:
            sub.insert(2, col_name, np.nan, True)
        sub[col_name] = lis[i+j*246]
    df = pd.concat([df, sub])

# %%
df.head()
# Out:
#             sws_rw    sws_rs  zReHo_17Networks_RH_TempPar_10  \
# Subject_ID
# sub-0015       3.4  1.666667                        0.566731
# sub-0085       2.8  2.166667                        0.005804
# sub-0134       3.8  2.000000                        0.101947
# sub-0152       4.0  1.666667                        0.225426
# sub-0260       3.8  2.500000                       -0.300899
#
#             zReHo_17Networks_RH_TempPar_9  zReHo_17Networks_RH_TempPar_8  \
# Subject_ID
# sub-0015                         0.103034                      -0.110347
# sub-0085                        -0.534427                      -0.259701
# sub-0134                         0.103791                       0.049305
# sub-0152                         0.908961                       2.485820
# sub-0260                        -0.599829                      -0.567175
#
#             zReHo_17Networks_RH_TempPar_7  zReHo_17Networks_RH_TempPar_6  \
# Subject_ID
# ...

# %%
df.to_csv('zreho_Schaefer.csv')
