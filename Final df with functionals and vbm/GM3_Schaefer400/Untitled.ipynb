# %%
import pandas as pd
import numpy as np
import shutil,os

# %%
df = pd.read_csv('all_functionals_with_vbm3(Schaefer400).csv')
df.head()
# Out:
#   Subject_ID  sws_rw    sws_rs  gmd_17Networks_RH_TempPar_10  \
# 0   sub-0015     3.4  1.666667                      0.401275
# 1   sub-0085     2.8  2.166667                      0.686243
# 2   sub-0134     3.8  2.000000                      0.635847
# 3   sub-0152     4.0  1.666667                      0.589705
# 4   sub-0260     3.8  2.500000                      0.615708
#
#    gmd_17Networks_RH_TempPar_9  gmd_17Networks_RH_TempPar_8  \
# 0                     0.510950                     0.564636
# 1                     0.742444                     0.690634
# 2                     0.631465                     0.845116
# 3                     0.660531                     0.719917
# 4                     0.734735                     0.586852
#
#    gmd_17Networks_RH_TempPar_7  gmd_17Networks_RH_TempPar_6  \
# 0                     0.635488                     0.672819
# 1                     0.796358                     0.807794
# ...

# %%
i = 0
for colname in df.columns:
    if colname.find('zReHo_')==0:
        i = i+1
print(i)
# Out:
# 180
