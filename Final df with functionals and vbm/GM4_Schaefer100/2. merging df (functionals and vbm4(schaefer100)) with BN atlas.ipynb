# %%
import numpy as np
import pandas as pd
import os,shutil

# %%
df = pd.read_csv('all_functionals_with_vbm4(Schaefer100).csv')
df.head()
# Out:
#   Subject_ID  sws_rw  gmd_17Networks_RH_TempPar_3  \
# 0   sub-0015     3.4                     0.555566
# 1   sub-0085     2.8                     0.724094
# 2   sub-0134     3.8                     0.740686
# 3   sub-0152     4.0                     0.698556
# 4   sub-0260     3.8                     0.686526
#
#    gmd_17Networks_RH_TempPar_2  gmd_17Networks_RH_TempPar_1  \
# 0                     0.642824                     0.523248
# 1                     0.719831                     0.597436
# 2                     0.718050                     0.551426
# 3                     0.686941                     0.561782
# 4                     0.637535                     0.588754
#
#    gmd_17Networks_RH_DefaultC_PHC_1  gmd_17Networks_RH_DefaultC_Rsp_1  \
# 0                          0.674498                          0.603287
# 1                          0.526730                          0.532123
# 2                          0.564090                          0.475704
# ...

# %%
# opening the text file
lis = []
with open('GM4_BN_meants.txt','r') as ALFFout:
   
    # reading each line    
    for line in ALFFout:
   
        # reading each word        
        for ALFF in line.split():
            lis.append(float(ALFF))
            # displaying the words           
            #print(ALFF)

# %%
len(lis)
# Out:
# 29028

# %% [markdown]
# ### list of region names in BN Atlas(246 parc)

# %%
token = open('BN_Atlas_246_LUT.txt','r')
linestoken=token.readlines()
tokens_column_number = 1
parname=[]
for x in linestoken:
    parname.append(x.split()[tokens_column_number])
token.close()
print(parname)
# Out:
# ['A8m_L', 'A8m_R', 'A8dl_L', 'A8dl_R', 'A9l_L', 'A9l_R', 'A6dl_L', 'A6dl_R', 'A6m_L', 'A6m_R', 'A9m_L', 'A9m_R', 'A10m_L', 'A10m_R', 'A9/46d_L', 'A9/46d_R', 'IFJ_L', 'IFJ_R', 'A46_L', 'A46_R', 'A9/46v_L', 'A9/46v_R', 'A8vl_L', 'A8vl_R', 'A6vl_L', 'A6vl_R', 'A10l_L', 'A10l_R', 'A44d_L', 'A44d_R', 'IFS_L', 'IFS_R', 'A45c_L', 'A45c_R', 'A45r_L', 'A45r_R', 'A44op_L', 'A44op_R', 'A44v_L', 'A44v_R', 'A14m_L', 'A14m_R', 'A12/47o_L', 'A12/47o_R', 'A11l_L', 'A11l_R', 'A11m_L', 'A11m_R', 'A13_L', 'A13_R', 'A12/47l_L', 'A12/47l_R', 'A4hf_L', 'A4hf_R', 'A6cdl_L', 'A6cdl_R', 'A4ul_L', 'A4ul_R', 'A4t_L', 'A4t_R', 'A4tl_L', 'A4tl_R', 'A6cvl_L', 'A6cvl_R', 'A1/2/3ll_L', 'A1/2/3ll_R', 'A4ll_L', 'A4ll_R', 'A38m_L', 'A38m_R', 'A41/42_L', 'A41/42_R', 'TE1.0/TE1.2_L', 'TE1.0/TE1.2_R', 'A22c_L', 'A22c_R', 'A38l_L', 'A38l_R', 'A22r_L', 'A22r_R', 'A21c_L', 'A21c_R', 'A21r_L', 'A21r_R', 'A37dl_L', 'A37dl_R', 'aSTS_L', 'aSTS_R', 'A20iv_L', 'A20iv_R', 'A37elv_L', 'A37elv_R', 'A20r_L', 'A20r_R', 'A20il_L', 'A20
# ...

# %%
len(parname)
# Out:
# 246

# %%
test = df.set_index('Subject_ID')
inds = test.index

# %%
df = pd.DataFrame()
for j, ind in enumerate(inds):
    sub = test.loc[[ind]]
    for i, pars in enumerate(parname):
        col_name = 'gmd_'+str(pars)
        if col_name not in sub:
            sub.insert(2, col_name, np.nan, True)
        sub[col_name] = lis[i+j*246]
    df = pd.concat([df, sub])

# %%
df.head()
# Out:
#             sws_rw  gmd_17Networks_RH_TempPar_3  gmd_lPFtha_R  gmd_lPFtha_L  \
# Subject_ID
# sub-0015       3.4                     0.555566      0.125858      0.089637
# sub-0085       2.8                     0.724094      0.080036      0.061758
# sub-0134       3.8                     0.740686      0.128877      0.093620
# sub-0152       4.0                     0.698556      0.080214      0.063089
# sub-0260       3.8                     0.686526      0.067391      0.051215
#
#             gmd_cTtha_R  gmd_cTtha_L  gmd_Otha_R  gmd_Otha_L  gmd_PPtha_R  \
# Subject_ID
# sub-0015       0.287892     0.323202    0.377764    0.331775     0.243676
# sub-0085       0.230677     0.237424    0.260661    0.250345     0.162335
# sub-0134       0.330090     0.365143    0.334302    0.340875     0.221608
# sub-0152       0.218066     0.245544    0.238987    0.233015     0.156658
# sub-0260       0.154175     0.189219    0.201918    0.186314     0.136170
#
# ...

# %%
df.columns.get_loc("gmd_lsOccG_R")
# Out:
# 38

# %%
df.columns.get_loc("gmd_A8m_L")
# Out:
# 247

# %%
df.drop(df.columns[38:247], axis = 1, inplace = True)

# %%
df.drop(['gmd_A8m_L'], axis = 1, inplace = True)

# %%
df.head()
# Out:
#             sws_rw  gmd_17Networks_RH_TempPar_3  gmd_lPFtha_R  gmd_lPFtha_L  \
# Subject_ID
# sub-0015       3.4                     0.555566      0.125858      0.089637
# sub-0085       2.8                     0.724094      0.080036      0.061758
# sub-0134       3.8                     0.740686      0.128877      0.093620
# sub-0152       4.0                     0.698556      0.080214      0.063089
# sub-0260       3.8                     0.686526      0.067391      0.051215
#
#             gmd_cTtha_R  gmd_cTtha_L  gmd_Otha_R  gmd_Otha_L  gmd_PPtha_R  \
# Subject_ID
# sub-0015       0.287892     0.323202    0.377764    0.331775     0.243676
# sub-0085       0.230677     0.237424    0.260661    0.250345     0.162335
# sub-0134       0.330090     0.365143    0.334302    0.340875     0.221608
# sub-0152       0.218066     0.245544    0.238987    0.233015     0.156658
# sub-0260       0.154175     0.189219    0.201918    0.186314     0.136170
#
# ...

# %%
column_to_move = df.pop("sws_fa")
df.insert(1, "sws_fa", column_to_move)
df.head()
# Out:
#             sws_rw    sws_fa  gmd_17Networks_RH_TempPar_3  gmd_lPFtha_R  \
# Subject_ID
# sub-0015       3.4  1.000000                     0.555566      0.125858
# sub-0085       2.8  2.166667                     0.724094      0.080036
# sub-0134       3.8  2.166667                     0.740686      0.128877
# sub-0152       4.0  2.500000                     0.698556      0.080214
# sub-0260       3.8  3.000000                     0.686526      0.067391
#
#             gmd_lPFtha_L  gmd_cTtha_R  gmd_cTtha_L  gmd_Otha_R  gmd_Otha_L  \
# Subject_ID
# sub-0015        0.089637     0.287892     0.323202    0.377764    0.331775
# sub-0085        0.061758     0.230677     0.237424    0.260661    0.250345
# sub-0134        0.093620     0.330090     0.365143    0.334302    0.340875
# sub-0152        0.063089     0.218066     0.245544    0.238987    0.233015
# sub-0260        0.051215     0.154175     0.189219    0.201918    0.186314
#
# ...

# %%
column_to_move = df.pop("sws_ms")
df.insert(1, "sws_ms", column_to_move)

# %%
column_to_move = df.pop("sws_gb")
df.insert(1, "sws_gb", column_to_move)

# %%
column_to_move = df.pop("sws_rs")
df.insert(1, "sws_rs", column_to_move)
df.head()
# Out:
#             sws_rw    sws_rs  sws_gb    sws_ms    sws_fa  \
# Subject_ID
# sub-0015       3.4  1.666667     1.4  1.833333  1.000000
# sub-0085       2.8  2.166667     2.8  3.500000  2.166667
# sub-0134       3.8  2.000000     3.4  2.166667  2.166667
# sub-0152       4.0  1.666667     3.0  1.500000  2.500000
# sub-0260       3.8  2.500000     4.0  3.600000  3.000000
#
#             gmd_17Networks_RH_TempPar_3  gmd_lPFtha_R  gmd_lPFtha_L  \
# Subject_ID
# sub-0015                       0.555566      0.125858      0.089637
# sub-0085                       0.724094      0.080036      0.061758
# sub-0134                       0.740686      0.128877      0.093620
# sub-0152                       0.698556      0.080214      0.063089
# sub-0260                       0.686526      0.067391      0.051215
#
#             gmd_cTtha_R  gmd_cTtha_L  ...  zDCbin_vCa_L  zDCbin_cHipp_R  \
# Subject_ID                            ...
# ...

# %%
column_to_move = df.pop("sws_total")
df.insert(5, "sws_total", column_to_move)
df.head()
# Out:
#             sws_rw    sws_rs  sws_gb    sws_ms    sws_fa  sws_total  \
# Subject_ID
# sub-0015       3.4  1.666667     1.4  1.833333  1.000000   1.513333
# sub-0085       2.8  2.166667     2.8  3.500000  2.166667   2.560000
# sub-0134       3.8  2.000000     3.4  2.166667  2.166667   2.346667
# sub-0152       4.0  1.666667     3.0  1.500000  2.500000   2.066667
# sub-0260       3.8  2.500000     4.0  3.600000  3.000000   3.120000
#
#             gmd_17Networks_RH_TempPar_3  gmd_lPFtha_R  gmd_lPFtha_L  \
# Subject_ID
# sub-0015                       0.555566      0.125858      0.089637
# sub-0085                       0.724094      0.080036      0.061758
# sub-0134                       0.740686      0.128877      0.093620
# sub-0152                       0.698556      0.080214      0.063089
# sub-0260                       0.686526      0.067391      0.051215
#
#             gmd_cTtha_R  ...  zDCbin_vCa_L  zDCbin_cHipp_R  zDCbin_cHipp_L  \
# Subject_ID               ...
# ...

# %%
df = df.reset_index()
#df = df.drop('Unnamed: 0', axis = 1)

# %%
df = df.drop('index', axis = 1)

# %%
df.head()
# Out:
#   Subject_ID  sws_rw    sws_rs  sws_gb    sws_ms    sws_fa  sws_total  \
# 0   sub-0015     3.4  1.666667     1.4  1.833333  1.000000   1.513333
# 1   sub-0085     2.8  2.166667     2.8  3.500000  2.166667   2.560000
# 2   sub-0134     3.8  2.000000     3.4  2.166667  2.166667   2.346667
# 3   sub-0152     4.0  1.666667     3.0  1.500000  2.500000   2.066667
# 4   sub-0260     3.8  2.500000     4.0  3.600000  3.000000   3.120000
#
#    gmd_17Networks_RH_TempPar_3  gmd_lPFtha_R  gmd_lPFtha_L  ...  zDCbin_vCa_L  \
# 0                     0.555566      0.125858      0.089637  ...     -0.123496
# 1                     0.724094      0.080036      0.061758  ...     -0.536867
# 2                     0.740686      0.128877      0.093620  ...     -0.051257
# 3                     0.698556      0.080214      0.063089  ...      0.145131
# 4                     0.686526      0.067391      0.051215  ...      0.302701
#
#    zDCbin_cHipp_R  zDCbin_cHipp_L  zDCbin_rHipp_R  zDCbin_rHipp_L  \
# ...

# %%
df = df.reset_index()

# %%
df.to_csv('finaldf_vbm(100).csv')

# %%
df.to_excel('finaldf_vbm4(100).xlsx')

# %%
`
