# %%
import numpy as np
import pandas as pd
import os,shutil

# %%
df = pd.read_csv('all_functionals_with_vbm(Schaefer400).csv')
df.head()
# Out:
#   Subject_ID  sws_rw    sws_rs  gmd_17Networks_RH_TempPar_10  \
# 0   sub-0015     3.4  1.666667                      0.406196
# 1   sub-0085     2.8  2.166667                      0.680933
# 2   sub-0134     3.8  2.000000                      0.686962
# 3   sub-0152     4.0  1.666667                      0.579344
# 4   sub-0260     3.8  2.500000                      0.644922
#
#    gmd_17Networks_RH_TempPar_9  gmd_17Networks_RH_TempPar_8  \
# 0                     0.516836                     0.611151
# 1                     0.786033                     0.760991
# 2                     0.605134                     0.995417
# 3                     0.679027                     0.824373
# 4                     0.721620                     0.653764
#
#    gmd_17Networks_RH_TempPar_7  gmd_17Networks_RH_TempPar_6  \
# 0                     0.688367                     0.682649
# 1                     0.876159                     0.891865
# 2                     0.883345                     0.964239
# 3                     0.858588                     0.874854
# 4                     0.953406                     0.754395
#
#    gmd_17Networks_RH_TempPar_5  gmd_17Networks_RH_TempPar_4  ...  \
# 0                     0.934097                     0.700679  ...
# 1                     0.987021                     0.813122  ...
# 2                     0.949331                     0.711556  ...
# 3                     0.978689                     0.759136  ...
# 4                     0.707826                     0.717452  ...
#
#    zReHo_17Networks_RH_DorsAttnA_SPL_3  zReHo_17Networks_RH_DorsAttnA_SPL_2  \
# 0                             0.632937                             0.484317
# 1                             1.272547                             0.551014
# 2                             0.510567                             0.323151
# 3                            -0.357383                            -0.159408
# 4                             0.387290                             0.171799
#
#    zReHo_17Networks_RH_DorsAttnA_SPL_1  \
# 0                             0.878408
# 1                             1.482868
# 2                             0.741446
# 3                             0.082269
# 4                             0.892404
#
#    zReHo_17Networks_RH_DorsAttnA_ParOcc_3  \
# 0                                0.776844
# 1                                1.110642
# 2                                0.395507
# 3                                0.183071
# 4                                0.532177
#
#    zReHo_17Networks_RH_DorsAttnA_ParOcc_2  \
# 0                                0.120077
# 1                                0.290340
# 2                                0.640683
# 3                               -0.415082
# 4                                0.216433
#
#    zReHo_17Networks_RH_DorsAttnA_ParOcc_1  \
# 0                                0.906160
# 1                                0.240267
# 2                                0.381234
# 3                               -0.233840
# 4                                0.554115
#
#    zReHo_17Networks_RH_DorsAttnA_TempOcc_3  \
# 0                                 1.010050
# 1                                 0.374478
# 2                                 0.707233
# 3                                -0.117080
# 4                                 0.634269
#
#    zReHo_17Networks_RH_DorsAttnA_TempOcc_2  \
# 0                                 0.325154
# 1                                -0.029872
# 2                                 0.149791
# 3                                 0.584565
# 4                                 0.389356
#
#    zReHo_17Networks_RH_DorsAttnA_TempOcc_1  zReHo_17Networks_RH_SomMotB_Cent_3
# 0                                 0.070342                            0.635567
# 1                                -0.361664                            0.516531
# 2                                -0.279489                            0.050742
# 3                                 0.458543                            0.246564
# 4                                -0.211930                            0.565683
#
# [5 rows x 2335 columns]

# %%
# opening the text file
lis = []
with open('GM_BN_meants.txt','r') as ALFFout:
   
    # reading each line    
    for line in ALFFout:
   
        # reading each word        
        for ALFF in line.split():
            lis.append(float(ALFF))
            # displaying the words           
            #print(ALFF)

# %%
token = open('BN_Atlas_246_LUT.txt','r')
linestoken=token.readlines()
tokens_column_number = 1
parname=[]
for x in linestoken:
    parname.append(x.split()[tokens_column_number])
token.close()
print(parname)
# Out:
# ['A8m_L', 'A8m_R', 'A8dl_L', 'A8dl_R', 'A9l_L', 'A9l_R', 'A6dl_L', 'A6dl_R', 'A6m_L', 'A6m_R', 'A9m_L', 'A9m_R', 'A10m_L', 'A10m_R', 'A9/46d_L', 'A9/46d_R', 'IFJ_L', 'IFJ_R', 'A46_L', 'A46_R', 'A9/46v_L', 'A9/46v_R', 'A8vl_L', 'A8vl_R', 'A6vl_L', 'A6vl_R', 'A10l_L', 'A10l_R', 'A44d_L', 'A44d_R', 'IFS_L', 'IFS_R', 'A45c_L', 'A45c_R', 'A45r_L', 'A45r_R', 'A44op_L', 'A44op_R', 'A44v_L', 'A44v_R', 'A14m_L', 'A14m_R', 'A12/47o_L', 'A12/47o_R', 'A11l_L', 'A11l_R', 'A11m_L', 'A11m_R', 'A13_L', 'A13_R', 'A12/47l_L', 'A12/47l_R', 'A4hf_L', 'A4hf_R', 'A6cdl_L', 'A6cdl_R', 'A4ul_L', 'A4ul_R', 'A4t_L', 'A4t_R', 'A4tl_L', 'A4tl_R', 'A6cvl_L', 'A6cvl_R', 'A1/2/3ll_L', 'A1/2/3ll_R', 'A4ll_L', 'A4ll_R', 'A38m_L', 'A38m_R', 'A41/42_L', 'A41/42_R', 'TE1.0/TE1.2_L', 'TE1.0/TE1.2_R', 'A22c_L', 'A22c_R', 'A38l_L', 'A38l_R', 'A22r_L', 'A22r_R', 'A21c_L', 'A21c_R', 'A21r_L', 'A21r_R', 'A37dl_L', 'A37dl_R', 'aSTS_L', 'aSTS_R', 'A20iv_L', 'A20iv_R', 'A37elv_L', 'A37elv_R', 'A20r_L', 'A20r_R', 'A20il_L', 'A20il_R', 'A37vl_L', 'A37vl_R', 'A20cl_L', 'A20cl_R', 'A20cv_L', 'A20cv_R', 'A20rv_L', 'A20rv_R', 'A37mv_L', 'A37mv_R', 'A37lv_L', 'A37lv_R', 'A35/36r_L', 'A35/36r_R', 'A35/36c_L', 'A35/36c_R', 'TL_L', 'TL_R', 'A28/34_L', 'A28/34_R', 'TI_L', 'TI_R', 'TH_L', 'TH_R', 'rpSTS_L', 'rpSTS_R', 'cpSTS_L', 'cpSTS_R', 'A7r_L', 'A7r_R', 'A7c_L', 'A7c_R', 'A5l_L', 'A5l_R', 'A7pc_L', 'A7pc_R', 'A7ip_L', 'A7ip_R', 'A39c_L', 'A39c_R', 'A39rd_L', 'A39rd_R', 'A40rd_L', 'A40rd_R', 'A40c_L', 'A40c_R', 'A39rv_L', 'A39rv_R', 'A40rv_L', 'A40rv_R', 'A7m_L', 'A7m_R', 'A5m_L', 'A5m_R', 'dmPOS_L', 'dmPOS_R', 'A31_L', 'A31_R', 'A1/2/3ulhf_L', 'A1/2/3ulhf_R', 'A1/2/3tonIa_L', 'A1/2/3tonIa_R', 'A2_L', 'A2_R', 'A1/2/3tru_L', 'A1/2/3tru_R', 'G_L', 'G_R', 'vIa_L', 'vIa_R', 'dIa_L', 'dIa_R', 'vId/vIg_L', 'vId/vIg_R', 'dIg_L', 'dIg_R', 'dId_L', 'dId_R', 'A23d_L', 'A23d_R', 'A24rv_L', 'A24rv_R', 'A32p_L', 'A32p_R', 'A23v_L', 'A23v_R', 'A24cd_L', 'A24cd_R', 'A23c_L', 'A23c_R', 'A32sg_L', 'A32sg_R', 'cLinG_L', 'cLinG_R', 'rCunG_L', 'rCunG_R', 'cCunG_L', 'cCunG_R', 'rLinG_L', 'rLinG_R', 'vmPOS_L', 'vmPOS_R', 'mOccG_L', 'mOccG_R', 'V5/MT+_L', 'V5/MT+_R', 'OPC_L', 'OPC_R', 'iOccG_L', 'iOccG_R', 'msOccG_L', 'msOccG_R', 'lsOccG_L', 'lsOccG_R', 'mAmyg_L', 'mAmyg_R', 'lAmyg_L', 'lAmyg_R', 'rHipp_L', 'rHipp_R', 'cHipp_L', 'cHipp_R', 'vCa_L', 'vCa_R', 'GP_L', 'GP_R', 'NAC_L', 'NAC_R', 'vmPu_L', 'vmPu_R', 'dCa_L', 'dCa_R', 'dlPu_L', 'dlPu_R', 'mPFtha_L', 'mPFtha_R', 'mPMtha_L', 'mPMtha_R', 'Stha_L', 'Stha_R', 'rTtha_L', 'rTtha_R', 'PPtha_L', 'PPtha_R', 'Otha_L', 'Otha_R', 'cTtha_L', 'cTtha_R', 'lPFtha_L', 'lPFtha_R']

# %%
len(parname)
# Out:
# 246

# %%
test = df.set_index('Subject_ID')
inds = test.index

# %%
df = pd.DataFrame()
for j, ind in enumerate(inds):
    sub = test.loc[[ind]]
    for i, pars in enumerate(parname):
        col_name = 'gmd_'+str(pars)
        if col_name not in sub:
            sub.insert(2, col_name, np.nan, True)
        sub[col_name] = lis[i+j*246]
    df = pd.concat([df, sub])

# %%
df.head()
# Out:
#             sws_rw    sws_rs  gmd_lPFtha_R  gmd_lPFtha_L  gmd_cTtha_R  \
# Subject_ID
# sub-0015       3.4  1.666667      0.031400      0.038295     0.335250
# sub-0085       2.8  2.166667      0.017522      0.024786     0.278105
# sub-0134       3.8  2.000000      0.036207      0.048955     0.414081
# sub-0152       4.0  1.666667      0.025111      0.037640     0.217765
# sub-0260       3.8  2.500000      0.023175      0.031572     0.147285
#
#             gmd_cTtha_L  gmd_Otha_R  gmd_Otha_L  gmd_PPtha_R  gmd_PPtha_L  \
# Subject_ID
# sub-0015       0.430265    0.495533    0.375955     0.222229     0.122080
# sub-0085       0.270634    0.241951    0.232068     0.120601     0.079272
# sub-0134       0.482258    0.381218    0.390225     0.202268     0.123018
# sub-0152       0.293916    0.216731    0.213116     0.139438     0.084063
# sub-0260       0.252381    0.200662    0.176200     0.133007     0.067884
#
#             ...  zReHo_17Networks_RH_DorsAttnA_SPL_3  \
# Subject_ID  ...
# sub-0015    ...                             0.632937
# sub-0085    ...                             1.272547
# sub-0134    ...                             0.510567
# sub-0152    ...                            -0.357383
# sub-0260    ...                             0.387290
#
#             zReHo_17Networks_RH_DorsAttnA_SPL_2  \
# Subject_ID
# sub-0015                               0.484317
# sub-0085                               0.551014
# sub-0134                               0.323151
# sub-0152                              -0.159408
# sub-0260                               0.171799
#
#             zReHo_17Networks_RH_DorsAttnA_SPL_1  \
# Subject_ID
# sub-0015                               0.878408
# sub-0085                               1.482868
# sub-0134                               0.741446
# sub-0152                               0.082269
# sub-0260                               0.892404
#
#             zReHo_17Networks_RH_DorsAttnA_ParOcc_3  \
# Subject_ID
# sub-0015                                  0.776844
# sub-0085                                  1.110642
# sub-0134                                  0.395507
# sub-0152                                  0.183071
# sub-0260                                  0.532177
#
#             zReHo_17Networks_RH_DorsAttnA_ParOcc_2  \
# Subject_ID
# sub-0015                                  0.120077
# sub-0085                                  0.290340
# sub-0134                                  0.640683
# sub-0152                                 -0.415082
# sub-0260                                  0.216433
#
#             zReHo_17Networks_RH_DorsAttnA_ParOcc_1  \
# Subject_ID
# sub-0015                                  0.906160
# sub-0085                                  0.240267
# sub-0134                                  0.381234
# sub-0152                                 -0.233840
# sub-0260                                  0.554115
#
#             zReHo_17Networks_RH_DorsAttnA_TempOcc_3  \
# Subject_ID
# sub-0015                                   1.010050
# sub-0085                                   0.374478
# sub-0134                                   0.707233
# sub-0152                                  -0.117080
# sub-0260                                   0.634269
#
#             zReHo_17Networks_RH_DorsAttnA_TempOcc_2  \
# Subject_ID
# sub-0015                                   0.325154
# sub-0085                                  -0.029872
# sub-0134                                   0.149791
# sub-0152                                   0.584565
# sub-0260                                   0.389356
#
#             zReHo_17Networks_RH_DorsAttnA_TempOcc_1  \
# Subject_ID
# sub-0015                                   0.070342
# sub-0085                                  -0.361664
# sub-0134                                  -0.279489
# sub-0152                                   0.458543
# sub-0260                                  -0.211930
#
#             zReHo_17Networks_RH_SomMotB_Cent_3
# Subject_ID
# sub-0015                              0.635567
# sub-0085                              0.516531
# sub-0134                              0.050742
# sub-0152                              0.246564
# sub-0260                              0.565683
#
# [5 rows x 2580 columns]

# %%
df.columns.get_loc("gmd_lsOccG_R")
# Out:
# 38

# %%
df.columns.get_loc("gmd_A8m_L")
# Out:
# 247

# %%
df.drop(df.columns[38:247], axis = 1, inplace = True)

# %%
df.head()
# Out:
#             sws_rw    sws_rs  gmd_lPFtha_R  gmd_lPFtha_L  gmd_cTtha_R  \
# Subject_ID
# sub-0015       3.4  1.666667      0.031400      0.038295     0.335250
# sub-0085       2.8  2.166667      0.017522      0.024786     0.278105
# sub-0134       3.8  2.000000      0.036207      0.048955     0.414081
# sub-0152       4.0  1.666667      0.025111      0.037640     0.217765
# sub-0260       3.8  2.500000      0.023175      0.031572     0.147285
#
#             gmd_cTtha_L  gmd_Otha_R  gmd_Otha_L  gmd_PPtha_R  gmd_PPtha_L  \
# Subject_ID
# sub-0015       0.430265    0.495533    0.375955     0.222229     0.122080
# sub-0085       0.270634    0.241951    0.232068     0.120601     0.079272
# sub-0134       0.482258    0.381218    0.390225     0.202268     0.123018
# sub-0152       0.293916    0.216731    0.213116     0.139438     0.084063
# sub-0260       0.252381    0.200662    0.176200     0.133007     0.067884
#
#             ...  zReHo_17Networks_RH_DorsAttnA_SPL_3  \
# Subject_ID  ...
# sub-0015    ...                             0.632937
# sub-0085    ...                             1.272547
# sub-0134    ...                             0.510567
# sub-0152    ...                            -0.357383
# sub-0260    ...                             0.387290
#
#             zReHo_17Networks_RH_DorsAttnA_SPL_2  \
# Subject_ID
# sub-0015                               0.484317
# sub-0085                               0.551014
# sub-0134                               0.323151
# sub-0152                              -0.159408
# sub-0260                               0.171799
#
#             zReHo_17Networks_RH_DorsAttnA_SPL_1  \
# Subject_ID
# sub-0015                               0.878408
# sub-0085                               1.482868
# sub-0134                               0.741446
# sub-0152                               0.082269
# sub-0260                               0.892404
#
#             zReHo_17Networks_RH_DorsAttnA_ParOcc_3  \
# Subject_ID
# sub-0015                                  0.776844
# sub-0085                                  1.110642
# sub-0134                                  0.395507
# sub-0152                                  0.183071
# sub-0260                                  0.532177
#
#             zReHo_17Networks_RH_DorsAttnA_ParOcc_2  \
# Subject_ID
# sub-0015                                  0.120077
# sub-0085                                  0.290340
# sub-0134                                  0.640683
# sub-0152                                 -0.415082
# sub-0260                                  0.216433
#
#             zReHo_17Networks_RH_DorsAttnA_ParOcc_1  \
# Subject_ID
# sub-0015                                  0.906160
# sub-0085                                  0.240267
# sub-0134                                  0.381234
# sub-0152                                 -0.233840
# sub-0260                                  0.554115
#
#             zReHo_17Networks_RH_DorsAttnA_TempOcc_3  \
# Subject_ID
# sub-0015                                   1.010050
# sub-0085                                   0.374478
# sub-0134                                   0.707233
# sub-0152                                  -0.117080
# sub-0260                                   0.634269
#
#             zReHo_17Networks_RH_DorsAttnA_TempOcc_2  \
# Subject_ID
# sub-0015                                   0.325154
# sub-0085                                  -0.029872
# sub-0134                                   0.149791
# sub-0152                                   0.584565
# sub-0260                                   0.389356
#
#             zReHo_17Networks_RH_DorsAttnA_TempOcc_1  \
# Subject_ID
# sub-0015                                   0.070342
# sub-0085                                  -0.361664
# sub-0134                                  -0.279489
# sub-0152                                   0.458543
# sub-0260                                  -0.211930
#
#             zReHo_17Networks_RH_SomMotB_Cent_3
# Subject_ID
# sub-0015                              0.635567
# sub-0085                              0.516531
# sub-0134                              0.050742
# sub-0152                              0.246564
# sub-0260                              0.565683
#
# [5 rows x 2371 columns]

# %%
df.drop(['gmd_A8m_L'], axis = 1, inplace = True)

# %%
df.head()
# Out:
#             sws_rw    sws_rs  gmd_lPFtha_R  gmd_lPFtha_L  gmd_cTtha_R  \
# Subject_ID
# sub-0015       3.4  1.666667      0.031400      0.038295     0.335250
# sub-0085       2.8  2.166667      0.017522      0.024786     0.278105
# sub-0134       3.8  2.000000      0.036207      0.048955     0.414081
# sub-0152       4.0  1.666667      0.025111      0.037640     0.217765
# sub-0260       3.8  2.500000      0.023175      0.031572     0.147285
#
#             gmd_cTtha_L  gmd_Otha_R  gmd_Otha_L  gmd_PPtha_R  gmd_PPtha_L  \
# Subject_ID
# sub-0015       0.430265    0.495533    0.375955     0.222229     0.122080
# sub-0085       0.270634    0.241951    0.232068     0.120601     0.079272
# sub-0134       0.482258    0.381218    0.390225     0.202268     0.123018
# sub-0152       0.293916    0.216731    0.213116     0.139438     0.084063
# sub-0260       0.252381    0.200662    0.176200     0.133007     0.067884
#
#             ...  zReHo_17Networks_RH_DorsAttnA_SPL_3  \
# Subject_ID  ...
# sub-0015    ...                             0.632937
# sub-0085    ...                             1.272547
# sub-0134    ...                             0.510567
# sub-0152    ...                            -0.357383
# sub-0260    ...                             0.387290
#
#             zReHo_17Networks_RH_DorsAttnA_SPL_2  \
# Subject_ID
# sub-0015                               0.484317
# sub-0085                               0.551014
# sub-0134                               0.323151
# sub-0152                              -0.159408
# sub-0260                               0.171799
#
#             zReHo_17Networks_RH_DorsAttnA_SPL_1  \
# Subject_ID
# sub-0015                               0.878408
# sub-0085                               1.482868
# sub-0134                               0.741446
# sub-0152                               0.082269
# sub-0260                               0.892404
#
#             zReHo_17Networks_RH_DorsAttnA_ParOcc_3  \
# Subject_ID
# sub-0015                                  0.776844
# sub-0085                                  1.110642
# sub-0134                                  0.395507
# sub-0152                                  0.183071
# sub-0260                                  0.532177
#
#             zReHo_17Networks_RH_DorsAttnA_ParOcc_2  \
# Subject_ID
# sub-0015                                  0.120077
# sub-0085                                  0.290340
# sub-0134                                  0.640683
# sub-0152                                 -0.415082
# sub-0260                                  0.216433
#
#             zReHo_17Networks_RH_DorsAttnA_ParOcc_1  \
# Subject_ID
# sub-0015                                  0.906160
# sub-0085                                  0.240267
# sub-0134                                  0.381234
# sub-0152                                 -0.233840
# sub-0260                                  0.554115
#
#             zReHo_17Networks_RH_DorsAttnA_TempOcc_3  \
# Subject_ID
# sub-0015                                   1.010050
# sub-0085                                   0.374478
# sub-0134                                   0.707233
# sub-0152                                  -0.117080
# sub-0260                                   0.634269
#
#             zReHo_17Networks_RH_DorsAttnA_TempOcc_2  \
# Subject_ID
# sub-0015                                   0.325154
# sub-0085                                  -0.029872
# sub-0134                                   0.149791
# sub-0152                                   0.584565
# sub-0260                                   0.389356
#
#             zReHo_17Networks_RH_DorsAttnA_TempOcc_1  \
# Subject_ID
# sub-0015                                   0.070342
# sub-0085                                  -0.361664
# sub-0134                                  -0.279489
# sub-0152                                   0.458543
# sub-0260                                  -0.211930
#
#             zReHo_17Networks_RH_SomMotB_Cent_3
# Subject_ID
# sub-0015                              0.635567
# sub-0085                              0.516531
# sub-0134                              0.050742
# sub-0152                              0.246564
# sub-0260                              0.565683
#
# [5 rows x 2370 columns]

# %%
column_to_move = df.pop("sws_fa")
df.insert(1, "sws_fa", column_to_move)
df.head()
# Out:
#             sws_rw    sws_fa    sws_rs  gmd_lPFtha_R  gmd_lPFtha_L  \
# Subject_ID
# sub-0015       3.4  1.000000  1.666667      0.031400      0.038295
# sub-0085       2.8  2.166667  2.166667      0.017522      0.024786
# sub-0134       3.8  2.166667  2.000000      0.036207      0.048955
# sub-0152       4.0  2.500000  1.666667      0.025111      0.037640
# sub-0260       3.8  3.000000  2.500000      0.023175      0.031572
#
#             gmd_cTtha_R  gmd_cTtha_L  gmd_Otha_R  gmd_Otha_L  gmd_PPtha_R  \
# Subject_ID
# sub-0015       0.335250     0.430265    0.495533    0.375955     0.222229
# sub-0085       0.278105     0.270634    0.241951    0.232068     0.120601
# sub-0134       0.414081     0.482258    0.381218    0.390225     0.202268
# sub-0152       0.217765     0.293916    0.216731    0.213116     0.139438
# sub-0260       0.147285     0.252381    0.200662    0.176200     0.133007
#
#             ...  zReHo_17Networks_RH_DorsAttnA_SPL_3  \
# Subject_ID  ...
# sub-0015    ...                             0.632937
# sub-0085    ...                             1.272547
# sub-0134    ...                             0.510567
# sub-0152    ...                            -0.357383
# sub-0260    ...                             0.387290
#
#             zReHo_17Networks_RH_DorsAttnA_SPL_2  \
# Subject_ID
# sub-0015                               0.484317
# sub-0085                               0.551014
# sub-0134                               0.323151
# sub-0152                              -0.159408
# sub-0260                               0.171799
#
#             zReHo_17Networks_RH_DorsAttnA_SPL_1  \
# Subject_ID
# sub-0015                               0.878408
# sub-0085                               1.482868
# sub-0134                               0.741446
# sub-0152                               0.082269
# sub-0260                               0.892404
#
#             zReHo_17Networks_RH_DorsAttnA_ParOcc_3  \
# Subject_ID
# sub-0015                                  0.776844
# sub-0085                                  1.110642
# sub-0134                                  0.395507
# sub-0152                                  0.183071
# sub-0260                                  0.532177
#
#             zReHo_17Networks_RH_DorsAttnA_ParOcc_2  \
# Subject_ID
# sub-0015                                  0.120077
# sub-0085                                  0.290340
# sub-0134                                  0.640683
# sub-0152                                 -0.415082
# sub-0260                                  0.216433
#
#             zReHo_17Networks_RH_DorsAttnA_ParOcc_1  \
# Subject_ID
# sub-0015                                  0.906160
# sub-0085                                  0.240267
# sub-0134                                  0.381234
# sub-0152                                 -0.233840
# sub-0260                                  0.554115
#
#             zReHo_17Networks_RH_DorsAttnA_TempOcc_3  \
# Subject_ID
# sub-0015                                   1.010050
# sub-0085                                   0.374478
# sub-0134                                   0.707233
# sub-0152                                  -0.117080
# sub-0260                                   0.634269
#
#             zReHo_17Networks_RH_DorsAttnA_TempOcc_2  \
# Subject_ID
# sub-0015                                   0.325154
# sub-0085                                  -0.029872
# sub-0134                                   0.149791
# sub-0152                                   0.584565
# sub-0260                                   0.389356
#
#             zReHo_17Networks_RH_DorsAttnA_TempOcc_1  \
# Subject_ID
# sub-0015                                   0.070342
# sub-0085                                  -0.361664
# sub-0134                                  -0.279489
# sub-0152                                   0.458543
# sub-0260                                  -0.211930
#
#             zReHo_17Networks_RH_SomMotB_Cent_3
# Subject_ID
# sub-0015                              0.635567
# sub-0085                              0.516531
# sub-0134                              0.050742
# sub-0152                              0.246564
# sub-0260                              0.565683
#
# [5 rows x 2370 columns]

# %%
column_to_move = df.pop("sws_ms")
df.insert(1, "sws_ms", column_to_move)

# %%
column_to_move = df.pop("sws_gb")
df.insert(1, "sws_gb", column_to_move)

# %%
column_to_move = df.pop("sws_rs")
df.insert(1, "sws_rs", column_to_move)
df.head()
# Out:
#             sws_rw    sws_rs  sws_gb    sws_ms    sws_fa  gmd_lPFtha_R  \
# Subject_ID
# sub-0015       3.4  1.666667     1.4  1.833333  1.000000      0.031400
# sub-0085       2.8  2.166667     2.8  3.500000  2.166667      0.017522
# sub-0134       3.8  2.000000     3.4  2.166667  2.166667      0.036207
# sub-0152       4.0  1.666667     3.0  1.500000  2.500000      0.025111
# sub-0260       3.8  2.500000     4.0  3.600000  3.000000      0.023175
#
#             gmd_lPFtha_L  gmd_cTtha_R  gmd_cTtha_L  gmd_Otha_R  ...  \
# Subject_ID                                                      ...
# sub-0015        0.038295     0.335250     0.430265    0.495533  ...
# sub-0085        0.024786     0.278105     0.270634    0.241951  ...
# sub-0134        0.048955     0.414081     0.482258    0.381218  ...
# sub-0152        0.037640     0.217765     0.293916    0.216731  ...
# sub-0260        0.031572     0.147285     0.252381    0.200662  ...
#
#             zReHo_17Networks_RH_DorsAttnA_SPL_3  \
# Subject_ID
# sub-0015                               0.632937
# sub-0085                               1.272547
# sub-0134                               0.510567
# sub-0152                              -0.357383
# sub-0260                               0.387290
#
#             zReHo_17Networks_RH_DorsAttnA_SPL_2  \
# Subject_ID
# sub-0015                               0.484317
# sub-0085                               0.551014
# sub-0134                               0.323151
# sub-0152                              -0.159408
# sub-0260                               0.171799
#
#             zReHo_17Networks_RH_DorsAttnA_SPL_1  \
# Subject_ID
# sub-0015                               0.878408
# sub-0085                               1.482868
# sub-0134                               0.741446
# sub-0152                               0.082269
# sub-0260                               0.892404
#
#             zReHo_17Networks_RH_DorsAttnA_ParOcc_3  \
# Subject_ID
# sub-0015                                  0.776844
# sub-0085                                  1.110642
# sub-0134                                  0.395507
# sub-0152                                  0.183071
# sub-0260                                  0.532177
#
#             zReHo_17Networks_RH_DorsAttnA_ParOcc_2  \
# Subject_ID
# sub-0015                                  0.120077
# sub-0085                                  0.290340
# sub-0134                                  0.640683
# sub-0152                                 -0.415082
# sub-0260                                  0.216433
#
#             zReHo_17Networks_RH_DorsAttnA_ParOcc_1  \
# Subject_ID
# sub-0015                                  0.906160
# sub-0085                                  0.240267
# sub-0134                                  0.381234
# sub-0152                                 -0.233840
# sub-0260                                  0.554115
#
#             zReHo_17Networks_RH_DorsAttnA_TempOcc_3  \
# Subject_ID
# sub-0015                                   1.010050
# sub-0085                                   0.374478
# sub-0134                                   0.707233
# sub-0152                                  -0.117080
# sub-0260                                   0.634269
#
#             zReHo_17Networks_RH_DorsAttnA_TempOcc_2  \
# Subject_ID
# sub-0015                                   0.325154
# sub-0085                                  -0.029872
# sub-0134                                   0.149791
# sub-0152                                   0.584565
# sub-0260                                   0.389356
#
#             zReHo_17Networks_RH_DorsAttnA_TempOcc_1  \
# Subject_ID
# sub-0015                                   0.070342
# sub-0085                                  -0.361664
# sub-0134                                  -0.279489
# sub-0152                                   0.458543
# sub-0260                                  -0.211930
#
#             zReHo_17Networks_RH_SomMotB_Cent_3
# Subject_ID
# sub-0015                              0.635567
# sub-0085                              0.516531
# sub-0134                              0.050742
# sub-0152                              0.246564
# sub-0260                              0.565683
#
# [5 rows x 2370 columns]

# %%
column_to_move = df.pop("sws_total")
df.insert(5, "sws_total", column_to_move)
df.head()
# Out:
#             sws_rw    sws_rs  sws_gb    sws_ms    sws_fa  sws_total  \
# Subject_ID
# sub-0015       3.4  1.666667     1.4  1.833333  1.000000   1.513333
# sub-0085       2.8  2.166667     2.8  3.500000  2.166667   2.560000
# sub-0134       3.8  2.000000     3.4  2.166667  2.166667   2.346667
# sub-0152       4.0  1.666667     3.0  1.500000  2.500000   2.066667
# sub-0260       3.8  2.500000     4.0  3.600000  3.000000   3.120000
#
#             gmd_lPFtha_R  gmd_lPFtha_L  gmd_cTtha_R  gmd_cTtha_L  ...  \
# Subject_ID                                                        ...
# sub-0015        0.031400      0.038295     0.335250     0.430265  ...
# sub-0085        0.017522      0.024786     0.278105     0.270634  ...
# sub-0134        0.036207      0.048955     0.414081     0.482258  ...
# sub-0152        0.025111      0.037640     0.217765     0.293916  ...
# sub-0260        0.023175      0.031572     0.147285     0.252381  ...
#
#             zReHo_17Networks_RH_DorsAttnA_SPL_3  \
# Subject_ID
# sub-0015                               0.632937
# sub-0085                               1.272547
# sub-0134                               0.510567
# sub-0152                              -0.357383
# sub-0260                               0.387290
#
#             zReHo_17Networks_RH_DorsAttnA_SPL_2  \
# Subject_ID
# sub-0015                               0.484317
# sub-0085                               0.551014
# sub-0134                               0.323151
# sub-0152                              -0.159408
# sub-0260                               0.171799
#
#             zReHo_17Networks_RH_DorsAttnA_SPL_1  \
# Subject_ID
# sub-0015                               0.878408
# sub-0085                               1.482868
# sub-0134                               0.741446
# sub-0152                               0.082269
# sub-0260                               0.892404
#
#             zReHo_17Networks_RH_DorsAttnA_ParOcc_3  \
# Subject_ID
# sub-0015                                  0.776844
# sub-0085                                  1.110642
# sub-0134                                  0.395507
# sub-0152                                  0.183071
# sub-0260                                  0.532177
#
#             zReHo_17Networks_RH_DorsAttnA_ParOcc_2  \
# Subject_ID
# sub-0015                                  0.120077
# sub-0085                                  0.290340
# sub-0134                                  0.640683
# sub-0152                                 -0.415082
# sub-0260                                  0.216433
#
#             zReHo_17Networks_RH_DorsAttnA_ParOcc_1  \
# Subject_ID
# sub-0015                                  0.906160
# sub-0085                                  0.240267
# sub-0134                                  0.381234
# sub-0152                                 -0.233840
# sub-0260                                  0.554115
#
#             zReHo_17Networks_RH_DorsAttnA_TempOcc_3  \
# Subject_ID
# sub-0015                                   1.010050
# sub-0085                                   0.374478
# sub-0134                                   0.707233
# sub-0152                                  -0.117080
# sub-0260                                   0.634269
#
#             zReHo_17Networks_RH_DorsAttnA_TempOcc_2  \
# Subject_ID
# sub-0015                                   0.325154
# sub-0085                                  -0.029872
# sub-0134                                   0.149791
# sub-0152                                   0.584565
# sub-0260                                   0.389356
#
#             zReHo_17Networks_RH_DorsAttnA_TempOcc_1  \
# Subject_ID
# sub-0015                                   0.070342
# sub-0085                                  -0.361664
# sub-0134                                  -0.279489
# sub-0152                                   0.458543
# sub-0260                                  -0.211930
#
#             zReHo_17Networks_RH_SomMotB_Cent_3
# Subject_ID
# sub-0015                              0.635567
# sub-0085                              0.516531
# sub-0134                              0.050742
# sub-0152                              0.246564
# sub-0260                              0.565683
#
# [5 rows x 2370 columns]

# %%
df = df.reset_index()
df.head()
# Out:
#    index Subject_ID  sws_rw    sws_rs  sws_gb    sws_ms    sws_fa  sws_total  \
# 0      0   sub-0015     3.4  1.666667     1.4  1.833333  1.000000   1.513333
# 1      1   sub-0085     2.8  2.166667     2.8  3.500000  2.166667   2.560000
# 2      2   sub-0134     3.8  2.000000     3.4  2.166667  2.166667   2.346667
# 3      3   sub-0152     4.0  1.666667     3.0  1.500000  2.500000   2.066667
# 4      4   sub-0260     3.8  2.500000     4.0  3.600000  3.000000   3.120000
#
#    gmd_lPFtha_R  gmd_lPFtha_L  ...  zReHo_17Networks_RH_DorsAttnA_SPL_3  \
# 0      0.031400      0.038295  ...                             0.632937
# 1      0.017522      0.024786  ...                             1.272547
# 2      0.036207      0.048955  ...                             0.510567
# 3      0.025111      0.037640  ...                            -0.357383
# 4      0.023175      0.031572  ...                             0.387290
#
#    zReHo_17Networks_RH_DorsAttnA_SPL_2  zReHo_17Networks_RH_DorsAttnA_SPL_1  \
# 0                             0.484317                             0.878408
# 1                             0.551014                             1.482868
# 2                             0.323151                             0.741446
# 3                            -0.159408                             0.082269
# 4                             0.171799                             0.892404
#
#    zReHo_17Networks_RH_DorsAttnA_ParOcc_3  \
# 0                                0.776844
# 1                                1.110642
# 2                                0.395507
# 3                                0.183071
# 4                                0.532177
#
#    zReHo_17Networks_RH_DorsAttnA_ParOcc_2  \
# 0                                0.120077
# 1                                0.290340
# 2                                0.640683
# 3                               -0.415082
# 4                                0.216433
#
#    zReHo_17Networks_RH_DorsAttnA_ParOcc_1  \
# 0                                0.906160
# 1                                0.240267
# 2                                0.381234
# 3                               -0.233840
# 4                                0.554115
#
#    zReHo_17Networks_RH_DorsAttnA_TempOcc_3  \
# 0                                 1.010050
# 1                                 0.374478
# 2                                 0.707233
# 3                                -0.117080
# 4                                 0.634269
#
#    zReHo_17Networks_RH_DorsAttnA_TempOcc_2  \
# 0                                 0.325154
# 1                                -0.029872
# 2                                 0.149791
# 3                                 0.584565
# 4                                 0.389356
#
#    zReHo_17Networks_RH_DorsAttnA_TempOcc_1  zReHo_17Networks_RH_SomMotB_Cent_3
# 0                                 0.070342                            0.635567
# 1                                -0.361664                            0.516531
# 2                                -0.279489                            0.050742
# 3                                 0.458543                            0.246564
# 4                                -0.211930                            0.565683
#
# [5 rows x 2372 columns]

# %%
df = df.drop('index', axis = 1)

# %%
df.head()
# Out:
#   Subject_ID  sws_rw    sws_rs  sws_gb    sws_ms    sws_fa  sws_total  \
# 0   sub-0015     3.4  1.666667     1.4  1.833333  1.000000   1.513333
# 1   sub-0085     2.8  2.166667     2.8  3.500000  2.166667   2.560000
# 2   sub-0134     3.8  2.000000     3.4  2.166667  2.166667   2.346667
# 3   sub-0152     4.0  1.666667     3.0  1.500000  2.500000   2.066667
# 4   sub-0260     3.8  2.500000     4.0  3.600000  3.000000   3.120000
#
#    gmd_lPFtha_R  gmd_lPFtha_L  gmd_cTtha_R  ...  \
# 0      0.031400      0.038295     0.335250  ...
# 1      0.017522      0.024786     0.278105  ...
# 2      0.036207      0.048955     0.414081  ...
# 3      0.025111      0.037640     0.217765  ...
# 4      0.023175      0.031572     0.147285  ...
#
#    zReHo_17Networks_RH_DorsAttnA_SPL_3  zReHo_17Networks_RH_DorsAttnA_SPL_2  \
# 0                             0.632937                             0.484317
# 1                             1.272547                             0.551014
# 2                             0.510567                             0.323151
# 3                            -0.357383                            -0.159408
# 4                             0.387290                             0.171799
#
#    zReHo_17Networks_RH_DorsAttnA_SPL_1  \
# 0                             0.878408
# 1                             1.482868
# 2                             0.741446
# 3                             0.082269
# 4                             0.892404
#
#    zReHo_17Networks_RH_DorsAttnA_ParOcc_3  \
# 0                                0.776844
# 1                                1.110642
# 2                                0.395507
# 3                                0.183071
# 4                                0.532177
#
#    zReHo_17Networks_RH_DorsAttnA_ParOcc_2  \
# 0                                0.120077
# 1                                0.290340
# 2                                0.640683
# 3                               -0.415082
# 4                                0.216433
#
#    zReHo_17Networks_RH_DorsAttnA_ParOcc_1  \
# 0                                0.906160
# 1                                0.240267
# 2                                0.381234
# 3                               -0.233840
# 4                                0.554115
#
#    zReHo_17Networks_RH_DorsAttnA_TempOcc_3  \
# 0                                 1.010050
# 1                                 0.374478
# 2                                 0.707233
# 3                                -0.117080
# 4                                 0.634269
#
#    zReHo_17Networks_RH_DorsAttnA_TempOcc_2  \
# 0                                 0.325154
# 1                                -0.029872
# 2                                 0.149791
# 3                                 0.584565
# 4                                 0.389356
#
#    zReHo_17Networks_RH_DorsAttnA_TempOcc_1  zReHo_17Networks_RH_SomMotB_Cent_3
# 0                                 0.070342                            0.635567
# 1                                -0.361664                            0.516531
# 2                                -0.279489                            0.050742
# 3                                 0.458543                            0.246564
# 4                                -0.211930                            0.565683
#
# [5 rows x 2371 columns]

# %%
df.to_excel('finaldf_vbm(400).xlsx')
