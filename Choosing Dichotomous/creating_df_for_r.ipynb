# %%
import pandas as pd
import os
import shutil

# %%
df = pd.read_csv('dich.csv')
df.head()
# Out:
#   Subject_ID imaging waves  d3_diagadhd_dich  d5_diagadhd_dich
# 0   sub-0015     ses-wave3                 0               0.0
# 1   sub-0085     ses-wave2                 0               0.0
# 2   sub-0134     ses-wave3                 0               0.0
# 3   sub-0152     ses-wave2                 0               1.0
# 4   sub-0260     ses-wave2                 1               NaN

# %%
for wave in df["imaging waves"]:
    if wave == "ses-wave2":
        df["diagadhd"] = df["d3_diagadhd_dich"]
    elif wave == "ses-wave3":
        df["diagadhd"] = df["d5_diagadhd_dich"]

# %%
df["diagadhd"].isnull().values
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False])

# %%
ID = pd.read_csv('ID_gender.csv')
ID.head()
# Out:
#   Subject_ID  CHILDgender
# 0   sub-0015            1
# 1   sub-0085            0
# 2   sub-0134            1
# 3   sub-0152            0
# 4   sub-0260            1

# %%
newdf = pd.merge(ID, df, how = "left", on = 'Subject_ID')
newdf.head()
# Out:
#   Subject_ID  CHILDgender imaging waves  d3_diagadhd_dich  d5_diagadhd_dich  \
# 0   sub-0015            1     ses-wave3                 0               0.0
# 1   sub-0085            0     ses-wave2                 0               0.0
# 2   sub-0134            1     ses-wave3                 0               0.0
# 3   sub-0152            0     ses-wave2                 0               1.0
# 4   sub-0260            1     ses-wave2                 1               NaN
#
#    diagadhd
# 0         0
# 1         0
# 2         0
# 3         0
# 4         1

# %%
len(newdf)
# Out:
# 117

# %%
rdf = pd.read_csv('finaldf_vbm2(100).csv')
rdf
# Out:
#      Unnamed: 0 Subject_ID  sws_rw    sws_rs  sws_gb    sws_ms    sws_fa  \
# 0             0   sub-0015     3.4  1.666667    1.40  1.833333  1.000000
# 1             1   sub-0085     2.8  2.166667    2.80  3.500000  2.166667
# 2             2   sub-0134     3.8  2.000000    3.40  2.166667  2.166667
# 3             3   sub-0152     4.0  1.666667    3.00  1.500000  2.500000
# 4             4   sub-0260     3.8  2.500000    4.00  3.600000  3.000000
# ..          ...        ...     ...       ...     ...       ...       ...
# 113         113   sub-6989     2.4  4.333333    3.20  2.666667  1.666667
# 114         114   sub-7019     3.2  2.000000    3.80  2.666667  2.666667
# 115         115   sub-7020     3.4  1.666667    3.20  3.000000  2.500000
# 116         116   sub-7031     3.0  1.166667    3.25  1.666667  2.000000
# 117         117   sub-7130     3.6  3.333333    3.00  3.000000  2.666667
#
#      sws_total  gmd_17Networks_RH_TempPar_3  gmd_lPFtha_R  ...  zDCbin_vCa_L  \
# 0     1.513333                     0.577379      0.069225  ...     -0.123496
# 1     2.560000                     0.776652      0.039463  ...     -0.536867
# 2     2.346667                     0.797153      0.072332  ...     -0.051257
# 3     2.066667                     0.740820      0.043507  ...      0.145131
# 4     3.120000                     0.741721      0.040795  ...      0.302701
# ..         ...                          ...           ...  ...           ...
# 113   3.240000                     0.576791      0.045106  ...      0.147294
# 114   2.626667                     0.730341      0.041832  ...     -0.315773
# 115   2.406667                     0.639307      0.038168  ...      0.210992
# 116   1.850000                     0.672270      0.043791  ...     -0.716313
# 117   3.066667                     0.827350      0.050201  ...     -0.653111
#
#      zDCbin_cHipp_R  zDCbin_cHipp_L  zDCbin_rHipp_R  zDCbin_rHipp_L  \
# 0         -0.409045       -0.675619        0.039336       -0.151689
# 1         -0.761581       -0.759640       -0.570934       -0.476561
# 2          0.083118       -0.473267       -0.057132       -0.511497
# 3         -0.003692        0.266627        0.181125        0.110153
# 4         -0.616848       -0.627955       -0.255518       -0.601781
# ..              ...             ...             ...             ...
# 113       -0.267082       -0.711906        0.089639       -0.582658
# 114       -0.790008       -0.695328       -0.464126       -0.253519
# 115       -0.996212       -1.075164       -0.877881       -0.841141
# 116        0.388904        0.093001        0.501574        0.283033
# 117       -0.782063       -0.995099       -0.822843       -0.797897
#
#      zDCbin_lAmyg_R  zDCbin_lAmyg_L  zDCbin_mAmyg_R  zDCbin_mAmyg_L  \
# 0         -0.286752       -0.646560       -0.480622        0.130468
# 1         -0.741962       -0.697915       -0.607798       -0.388198
# 2         -0.595767       -0.543238       -0.744308       -0.652683
# 3          0.209645       -0.008773       -0.316225       -0.015972
# 4         -0.660429       -0.659524       -0.505692       -0.210058
# ..              ...             ...             ...             ...
# 113       -0.528224       -0.168748        0.062812       -0.205505
# 114       -0.438166       -0.423226       -0.217975       -0.318583
# 115       -0.748227       -0.693116       -0.411432       -0.548595
# 116        0.257477        0.209041        0.037866       -0.087639
# 117       -0.855177       -0.821736       -0.410169       -0.533719
#
#      zDCbin_A8m_L
# 0        0.366193
# 1        0.172785
# 2        0.164491
# 3       -0.196272
# 4        0.132615
# ..            ...
# 113      0.339511
# 114      0.185787
# 115      0.819578
# 116     -0.262485
# 117      0.277392
#
# [118 rows x 829 columns]

# %%
feature = pd.read_csv('features.csv')
feature
# Out:
#                                    Unnamed: 0  sws_rw  sws_gb  sws_ms  \
# 0           zfALFF_17Networks_RH_ContA_PFCl_2     NaN     NaN     NaN
# 1           zfALFF_17Networks_RH_ContA_PFCl_1     NaN     NaN     NaN
# 2   zfALFF_17Networks_RH_SalVentAttnB_PFCmp_1     NaN     NaN     NaN
# 3   zfALFF_17Networks_RH_SalVentAttnA_FrMed_1     NaN     NaN     NaN
# 4      zfALFF_17Networks_RH_DorsAttnB_PostC_1     NaN     NaN     NaN
# 5         zfALFF_17Networks_RH_SomMotB_Cent_1     NaN     NaN     NaN
# 6           zfALFF_17Networks_RH_SomMotB_S2_2     NaN     NaN     NaN
# 7              zfALFF_17Networks_RH_SomMotA_1     NaN     NaN     NaN
# 8     zfALFF_17Networks_LH_SalVentAttnA_Ins_1     NaN     NaN     NaN
# 9               zALFF_17Networks_RH_TempPar_2     NaN     NaN     NaN
# 10           zALFF_17Networks_RH_ContA_PFCl_2     NaN     NaN     NaN
# 11           zALFF_17Networks_RH_SomMotB_S2_1     NaN     NaN     NaN
# 12                             zfALFF_rHipp_L     NaN     NaN     NaN
# 13                             zfALFF_mAmyg_L     NaN     NaN     NaN
#
#       sws_fa    sws_rs  sws_total
# 0        NaN  0.010599        NaN
# 1        NaN  0.004869   0.033928
# 2        NaN  0.003944   0.023167
# 3        NaN  0.011268        NaN
# 4   0.035299  0.007691   0.006586
# 5        NaN  0.029143        NaN
# 6        NaN  0.024110        NaN
# 7        NaN       NaN   0.035632
# 8   0.003320  0.012994   0.000363
# 9        NaN  0.002164   0.042667
# 10       NaN  0.036897        NaN
# 11       NaN  0.012202        NaN
# 12       NaN  0.019789   0.006771
# 13       NaN       NaN   0.012655

# %%
df = pd.DataFrame()
df = pd.concat([df, rdf['Subject_ID']])
for feat in feature["Unnamed: 0"]:
    for i,column in enumerate(rdf.columns):
        if feat == column:        
            #print(feat)
            df = pd.concat([df, rdf[[column]]], axis=1)
            break

# %%
df
# Out:
#             0  zfALFF_17Networks_RH_ContA_PFCl_2  \
# 0    sub-0015                           0.510408
# 1    sub-0085                           0.639438
# 2    sub-0134                           0.702157
# 3    sub-0152                           0.130369
# 4    sub-0260                           0.610739
# ..        ...                                ...
# 113  sub-6989                           0.603902
# 114  sub-7019                           0.535390
# 115  sub-7020                           0.711260
# 116  sub-7031                           0.543206
# 117  sub-7130                           0.071743
#
#      zfALFF_17Networks_RH_ContA_PFCl_1  \
# 0                             0.567429
# 1                             0.417361
# 2                             0.773058
# 3                             0.332433
# 4                             0.498258
# ..                                 ...
# 113                           0.256670
# 114                           0.602319
# 115                           0.353432
# 116                           0.550442
# 117                           0.490667
#
#      zfALFF_17Networks_RH_SalVentAttnB_PFCmp_1  \
# 0                                    -0.031283
# 1                                     0.137881
# 2                                     0.140849
# 3                                     0.011349
# 4                                     0.011990
# ..                                         ...
# 113                                   0.006749
# 114                                   0.022241
# 115                                   0.058207
# 116                                   0.016879
# 117                                  -0.143423
#
#      zfALFF_17Networks_RH_SalVentAttnA_FrMed_1  \
# 0                                     0.066221
# 1                                     0.105251
# 2                                     0.341539
# 3                                    -0.071125
# 4                                     0.033176
# ..                                         ...
# 113                                   0.129950
# 114                                   0.021801
# 115                                   0.191492
# 116                                   0.163263
# 117                                  -0.040951
#
#      zfALFF_17Networks_RH_DorsAttnB_PostC_1  \
# 0                                  0.717954
# 1                                  0.332246
# 2                                  0.491910
# 3                                  0.004836
# 4                                  0.180243
# ..                                      ...
# 113                                0.493410
# 114                                0.107081
# 115                                0.994800
# 116                                0.550986
# 117                                0.329682
#
#      zfALFF_17Networks_RH_SomMotB_Cent_1  zfALFF_17Networks_RH_SomMotB_S2_2  \
# 0                               0.918783                           0.226442
# 1                               0.468277                           0.123427
# 2                               0.583437                           0.569018
# 3                               0.109585                          -0.156932
# 4                               0.688405                           0.091987
# ..                                   ...                                ...
# 113                             0.452326                           0.274684
# 114                             0.563671                           0.450798
# 115                             0.786557                           0.355907
# 116                             0.456928                           0.333404
# 117                             0.510775                           0.123566
#
#      zfALFF_17Networks_RH_SomMotA_1  zfALFF_17Networks_LH_SalVentAttnA_Ins_1  \
# 0                          0.699415                                -0.376734
# 1                          0.446309                                -0.059265
# 2                          0.668127                                -0.151490
# 3                          0.147098                                -0.098148
# 4                          0.227425                                -0.157932
# ..                              ...                                      ...
# 113                        0.536971                                 0.007231
# 114                        0.088870                                 0.095550
# 115                        0.631709                                -0.281231
# 116                        0.454977                                -0.116728
# 117                        0.429381                                -0.278132
#
#      zALFF_17Networks_RH_TempPar_2  zALFF_17Networks_RH_ContA_PFCl_2  \
# 0                        -0.106550                         -0.100569
# 1                         0.021657                          0.016016
# 2                        -0.002664                         -0.044268
# 3                        -0.273843                         -0.058646
# 4                         0.153276                          0.063670
# ..                             ...                               ...
# 113                      -0.277269                         -0.009132
# 114                       0.150484                         -0.128878
# 115                      -0.033251                         -0.073992
# 116                       0.139188                         -0.096538
# 117                      -0.062926                         -0.264515
#
#      zALFF_17Networks_RH_SomMotB_S2_1  zfALFF_rHipp_L  zfALFF_mAmyg_L
# 0                           -0.003077       -0.643343       -0.795787
# 1                            0.059938       -0.521729       -0.558171
# 2                            0.306965       -0.757014       -0.761522
# 3                            0.007054       -0.227366       -0.194898
# 4                            0.175148       -0.608427       -0.532710
# ..                                ...             ...             ...
# 113                          0.055180       -0.653534       -0.564537
# 114                         -0.033793       -0.444963       -0.413061
# 115                          0.055084       -0.673356       -0.545997
# 116                          0.142782       -0.494660       -0.343199
# 117                         -0.071110       -0.740215       -0.481282
#
# [118 rows x 15 columns]

# %%
df.to_csv("edit.csv")

# %%
df = pd.read_csv("edit.csv")
df.head()
# Out:
#   Subject_ID  zfALFF_17Networks_RH_ContA_PFCl_2  \
# 0   sub-0015                           0.510408
# 1   sub-0085                           0.639438
# 2   sub-0134                           0.702157
# 3   sub-0152                           0.130369
# 4   sub-0260                           0.610739
#
#    zfALFF_17Networks_RH_ContA_PFCl_1  \
# 0                           0.567429
# 1                           0.417361
# 2                           0.773058
# 3                           0.332433
# 4                           0.498258
#
#    zfALFF_17Networks_RH_SalVentAttnB_PFCmp_1  \
# 0                                  -0.031283
# 1                                   0.137881
# 2                                   0.140849
# 3                                   0.011349
# 4                                   0.011990
#
#    zfALFF_17Networks_RH_SalVentAttnA_FrMed_1  \
# 0                                   0.066221
# 1                                   0.105251
# 2                                   0.341539
# 3                                  -0.071125
# 4                                   0.033176
#
#    zfALFF_17Networks_RH_DorsAttnB_PostC_1  \
# 0                                0.717954
# 1                                0.332246
# 2                                0.491910
# 3                                0.004836
# 4                                0.180243
#
#    zfALFF_17Networks_RH_SomMotB_Cent_1  zfALFF_17Networks_RH_SomMotB_S2_2  \
# 0                             0.918783                           0.226442
# 1                             0.468277                           0.123427
# 2                             0.583437                           0.569018
# 3                             0.109585                          -0.156932
# 4                             0.688405                           0.091987
#
#    zfALFF_17Networks_RH_SomMotA_1  zfALFF_17Networks_LH_SalVentAttnA_Ins_1  \
# 0                        0.699415                                -0.376734
# 1                        0.446309                                -0.059265
# 2                        0.668127                                -0.151490
# 3                        0.147098                                -0.098148
# 4                        0.227425                                -0.157932
#
#    zALFF_17Networks_RH_TempPar_2  zALFF_17Networks_RH_ContA_PFCl_2  \
# 0                      -0.106550                         -0.100569
# 1                       0.021657                          0.016016
# 2                      -0.002664                         -0.044268
# 3                      -0.273843                         -0.058646
# 4                       0.153276                          0.063670
#
#    zALFF_17Networks_RH_SomMotB_S2_1  zfALFF_rHipp_L  zfALFF_mAmyg_L
# 0                         -0.003077       -0.643343       -0.795787
# 1                          0.059938       -0.521729       -0.558171
# 2                          0.306965       -0.757014       -0.761522
# 3                          0.007054       -0.227366       -0.194898
# 4                          0.175148       -0.608427       -0.532710

# %%
final = newdf.merge(df, how = "left", on = 'Subject_ID')

# %%
final.to_csv('')
# Out:
#           0  zfALFF_17Networks_RH_ContA_PFCl_2  \
# 0  sub-0015                           0.510408
# 1  sub-0085                           0.639438
# 2  sub-0134                           0.702157
# 3  sub-0152                           0.130369
# 4  sub-0260                           0.610739
#
#    zfALFF_17Networks_RH_ContA_PFCl_1  \
# 0                           0.567429
# 1                           0.417361
# 2                           0.773058
# 3                           0.332433
# 4                           0.498258
#
#    zfALFF_17Networks_RH_SalVentAttnB_PFCmp_1  \
# 0                                  -0.031283
# 1                                   0.137881
# 2                                   0.140849
# 3                                   0.011349
# 4                                   0.011990
#
#    zfALFF_17Networks_RH_SalVentAttnA_FrMed_1  \
# 0                                   0.066221
# 1                                   0.105251
# 2                                   0.341539
# 3                                  -0.071125
# 4                                   0.033176
#
#    zfALFF_17Networks_RH_DorsAttnB_PostC_1  \
# 0                                0.717954
# 1                                0.332246
# 2                                0.491910
# 3                                0.004836
# 4                                0.180243
#
#    zfALFF_17Networks_RH_SomMotB_Cent_1  zfALFF_17Networks_RH_SomMotB_S2_2  \
# 0                             0.918783                           0.226442
# 1                             0.468277                           0.123427
# 2                             0.583437                           0.569018
# 3                             0.109585                          -0.156932
# 4                             0.688405                           0.091987
#
#    zfALFF_17Networks_RH_SomMotA_1  zfALFF_17Networks_LH_SalVentAttnA_Ins_1  \
# 0                        0.699415                                -0.376734
# 1                        0.446309                                -0.059265
# 2                        0.668127                                -0.151490
# 3                        0.147098                                -0.098148
# 4                        0.227425                                -0.157932
#
#    zALFF_17Networks_RH_TempPar_2  zALFF_17Networks_RH_ContA_PFCl_2  \
# 0                      -0.106550                         -0.100569
# 1                       0.021657                          0.016016
# 2                      -0.002664                         -0.044268
# 3                      -0.273843                         -0.058646
# 4                       0.153276                          0.063670
#
#    zALFF_17Networks_RH_SomMotB_S2_1  zfALFF_rHipp_L  zfALFF_mAmyg_L
# 0                         -0.003077       -0.643343       -0.795787
# 1                          0.059938       -0.521729       -0.558171
# 2                          0.306965       -0.757014       -0.761522
# 3                          0.007054       -0.227366       -0.194898
# 4                          0.175148       -0.608427       -0.532710
