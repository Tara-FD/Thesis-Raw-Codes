# %%
import numpy as np
import pandas as pd
import os, shutil

# %%
df = pd.read_excel("finaldf.xlsx")
df.head()
# Out:
#    Unnamed: 0 Subject_ID  sws_rw  sws_gb    sws_ms    sws_fa    sws_rs  \
# 0           0   sub-0015     3.4     1.4  1.833333  1.000000  1.666667
# 1           1   sub-0085     2.8     2.8  3.500000  2.166667  2.166667
# 2           2   sub-0134     3.8     3.4  2.166667  2.166667  2.000000
# 3           3   sub-0152     4.0     3.0  1.500000  2.500000  1.666667
# 4           4   sub-0260     3.8     4.0  3.600000  3.000000  2.500000
#
#    sws_total  zReHo_lPFtha_R  zReHo_lPFtha_L  ...  \
# 0   1.513333       -0.680650       -0.740437  ...
# 1   2.560000       -0.607122       -0.614975  ...
# 2   2.346667       -0.263834       -0.493474  ...
# 3   2.066667        0.258873        0.978757  ...
# 4   3.120000       -0.338928       -0.980045  ...
#
#    zReHo_17Networks_RH_DorsAttnA_SPL_3  zReHo_17Networks_RH_DorsAttnA_SPL_2  \
# 0                             0.632937                             0.484317
# 1                             1.272547                             0.551014
# ...
