# %%
import numpy as np
import pandas as pd
import os, shutil

# %%
df = pd.read_csv("df_with_BN_Sch(ALFF-fALFF).csv")
df.head()
# Out:
#   Subject_ID  Unnamed: 0  sws_rw  zfALFF_17Networks_RH_TempPar_3  \
# 0   sub-0015           0     3.4                        0.289362
# 1   sub-0085           1     2.8                        0.295488
# 2   sub-0134           2     3.8                        0.212425
# 3   sub-0152           3     4.0                       -0.260903
# 4   sub-0260           4     3.8                        0.357506
#
#    zfALFF_17Networks_RH_TempPar_2  zfALFF_17Networks_RH_TempPar_1  \
# 0                        0.387219                       -0.499674
# 1                       -0.021376                       -0.451423
# 2                        0.300717                       -0.118058
# 3                       -0.808337                       -0.152748
# 4                        0.304339                       -0.279130
#
#    zfALFF_17Networks_RH_DefaultC_PHC_1  zfALFF_17Networks_RH_DefaultC_Rsp_1  \
# 0                            -0.268918                             0.243868
# 1                            -0.609456                             0.072843
# 2                             0.009949                            -0.181013
# 3                            -0.146239                            -0.377955
# 4                            -0.315731                             0.367101
#
#    zfALFF_17Networks_RH_DefaultB_PFCv_2  zfALFF_17Networks_RH_DefaultB_PFCv_1  \
# 0                              0.473906                             -0.140602
# 1                              0.478059                             -0.084614
# 2                              0.546214                              0.217111
# 3                              0.298889                              0.084704
# 4                              0.392389                             -0.097484
#
#    ...  zDCbin_vCa_L  zDCbin_cHipp_R  zDCbin_cHipp_L  zDCbin_rHipp_R  \
# 0  ...     -0.123496       -0.409045       -0.675619        0.039336
# 1  ...     -0.536867       -0.761581       -0.759640       -0.570934
# 2  ...     -0.051257        0.083118       -0.473267       -0.057132
# 3  ...      0.145131       -0.003692        0.266627        0.181125
# 4  ...      0.302701       -0.616848       -0.627955       -0.255518
#
#    zDCbin_rHipp_L  zDCbin_lAmyg_R  zDCbin_lAmyg_L  zDCbin_mAmyg_R  \
# 0       -0.151689       -0.286752       -0.646560       -0.480622
# 1       -0.476561       -0.741962       -0.697915       -0.607798
# 2       -0.511497       -0.595767       -0.543238       -0.744308
# 3        0.110153        0.209645       -0.008773       -0.316225
# 4       -0.601781       -0.660429       -0.659524       -0.505692
#
#    zDCbin_mAmyg_L  zDCbin_A8m_L
# 0        0.130468      0.366193
# 1       -0.388198      0.172785
# 2       -0.652683      0.164491
# 3       -0.015972     -0.196272
# 4       -0.210058      0.132615
#
# [5 rows x 393 columns]

# %%
# opening the text file
lis = []
with open('allzReHo_meants_100.txt','r') as ALFFout:
   
    # reading each line    
    for line in ALFFout:
   
        # reading each word        
        for ALFF in line.split():
            lis.append(float(ALFF))
            # displaying the words           
            #print(ALFF)

# %%
token = open('Schaefer2018_100Parcels_17Networks_order.txt','r')
linestoken=token.readlines()
tokens_column_number = 1
parname=[]
for x in linestoken:
    parname.append(x.split()[tokens_column_number])
token.close()
print(parname)
# Out:
# ['17Networks_LH_VisCent_ExStr_1', '17Networks_LH_VisCent_ExStr_2', '17Networks_LH_VisCent_Striate_1', '17Networks_LH_VisCent_ExStr_3', '17Networks_LH_VisPeri_ExStrInf_1', '17Networks_LH_VisPeri_StriCal_1', '17Networks_LH_VisPeri_ExStrSup_1', '17Networks_LH_SomMotA_1', '17Networks_LH_SomMotA_2', '17Networks_LH_SomMotB_Aud_1', '17Networks_LH_SomMotB_S2_1', '17Networks_LH_SomMotB_S2_2', '17Networks_LH_SomMotB_Cent_1', '17Networks_LH_DorsAttnA_TempOcc_1', '17Networks_LH_DorsAttnA_ParOcc_1', '17Networks_LH_D
# %%
test = df.set_index('Subject_ID')
inds = test.index

# %%
df = pd.DataFrame()
for j, ind in enumerate(inds):
    sub = test.loc[[ind]]
    for i, pars in enumerate(parname):
        col_name = 'zReHo_'+str(pars)
        if col_name not in sub:
            sub.insert(2, col_name, np.nan, True)
        sub[col_name] = lis[i+j*100]
    df = pd.concat([df, sub])

# %%
df.head()
# Out:
#             Unnamed: 0  sws_rw  zReHo_17Networks_RH_TempPar_3  \
# Subject_ID
# sub-0015             0     3.4                       0.370217
# sub-0085             1     2.8                       0.430836
# sub-0134             2     3.8                       0.153680
# sub-0152             3     4.0                      -0.716644
# sub-0260             4     3.8                       0.035978
#
#             zReHo_17Networks_RH_TempPar_2  zReHo_17Networks_RH_TempPar_1  \
# Subject_ID
# sub-0015                         0.138971                      -0.311861
# sub-0085                        -0.329841                      -0.646255
# sub-0134                         0.039980                      -0.308133
# sub-0152                        -0.407743                      -0.497096
# sub-0260                        -0.098730                      -0.644450
#
#             zReHo_17Networks_RH_DefaultC_PHC_1  \
# Subject_ID
# sub-0015                              0.159579
# sub-0085                             -0.723025
# sub-0134                             -0.124991
# sub-0152                              0.564838
# sub-0260                             -0.130427
#
#             zReHo_17Networks_RH_DefaultC_Rsp_1  \
# Subject_ID
# sub-0015                              0.187973
# sub-0085                              0.030616
# sub-0134                             -0.275643
# sub-0152                             -0.028023
# sub-0260                              0.271965
#
#             zReHo_17Networks_RH_DefaultB_PFCv_2  \
# Subject_ID
# sub-0015                               0.081294
# sub-0085                               0.317300
# sub-0134                               0.585791
# sub-0152                               0.219048
# sub-0260                               0.545572
#
#             zReHo_17Networks_RH_DefaultB_PFCv_1  \
# Subject_ID
# sub-0015                               0.050014
# sub-0085                              -0.150811
# sub-0134                               0.188040
# sub-0152                              -0.139526
# sub-0260                               0.107915
#
#             zReHo_17Networks_RH_DefaultB_PFCd_1  ...  zDCbin_vCa_L  \
# Subject_ID                                       ...
# sub-0015                              -0.106167  ...     -0.123496
# sub-0085                               0.096718  ...     -0.536867
# sub-0134                               0.269388  ...     -0.051257
# sub-0152                               0.159107  ...      0.145131
# sub-0260                               0.184473  ...      0.302701
#
#             zDCbin_cHipp_R  zDCbin_cHipp_L  zDCbin_rHipp_R  zDCbin_rHipp_L  \
# Subject_ID
# sub-0015         -0.409045       -0.675619        0.039336       -0.151689
# sub-0085         -0.761581       -0.759640       -0.570934       -0.476561
# sub-0134          0.083118       -0.473267       -0.057132       -0.511497
# sub-0152         -0.003692        0.266627        0.181125        0.110153
# sub-0260         -0.616848       -0.627955       -0.255518       -0.601781
#
#             zDCbin_lAmyg_R  zDCbin_lAmyg_L  zDCbin_mAmyg_R  zDCbin_mAmyg_L  \
# Subject_ID
# sub-0015         -0.286752       -0.646560       -0.480622        0.130468
# sub-0085         -0.741962       -0.697915       -0.607798       -0.388198
# sub-0134         -0.595767       -0.543238       -0.744308       -0.652683
# sub-0152          0.209645       -0.008773       -0.316225       -0.015972
# sub-0260         -0.660429       -0.659524       -0.505692       -0.210058
#
#             zDCbin_A8m_L
# Subject_ID
# sub-0015        0.366193
# sub-0085        0.172785
# sub-0134        0.164491
# sub-0152       -0.196272
# sub-0260        0.132615
#
# [5 rows x 492 columns]

# %%
df.to_csv('df_with_BN_Sch(ALFF-fALFF-ReHo).csv')
