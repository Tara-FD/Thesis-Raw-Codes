# %%
import numpy as np
import pandas as pd
import os, shutil

# %%
df = pd.read_csv('df with Schaefer400_DCwei-DCbin-ReHo-ALFF-fALFF_and_BN DCwei-DCbin-ALFF-fALFF.csv')
df.head()
# Out:
#   Subject_ID  sws_rw    sws_rs  zfALFF_lPFtha_R  zfALFF_lPFtha_L  \
# 0   sub-0015     3.4  1.666667        -0.760500        -0.929277
# 1   sub-0085     2.8  2.166667        -0.234355        -0.397031
# 2   sub-0134     3.8  2.000000        -1.012589        -0.840667
# 3   sub-0152     4.0  1.666667        -0.682773        -0.294288
# 4   sub-0260     3.8  2.500000        -0.814174        -0.863769
#
#    zfALFF_cTtha_R  zfALFF_cTtha_L  zfALFF_Otha_R  zfALFF_Otha_L  \
# 0       -0.564227       -0.743303      -0.649522      -0.701746
# 1       -0.182309       -0.381863      -0.308232      -0.449357
# 2       -0.760328       -0.901478      -0.891105      -0.487365
# 3       -0.123090       -0.634390      -0.701496      -0.597999
# 4       -0.709799       -0.617213      -0.775317      -0.475704
#
#    zfALFF_PPtha_R  ...  zReHo_17Networks_RH_DorsAttnA_SPL_3  \
# 0       -0.505629  ...                             0.632937
# 1       -0.218163  ...                             1.272547
# ...

# %%
# opening the text file
lis = []
with open('allzReHo_meants_BN.txt','r') as ALFFout:
   
    # reading each line    
    for line in ALFFout:
   
        # reading each word        
        for ALFF in line.split():
            lis.append(float(ALFF))
            # displaying the words           
            #print(ALFF)

# %%
token = open('BN_Atlas_246_LUT.txt','r')
linestoken=token.readlines()
tokens_column_number = 1
parname=[]
for x in linestoken:
    parname.append(x.split()[tokens_column_number])
token.close()
print(parname)
# Out:
# ['A8m_L', 'A8m_R', 'A8dl_L', 'A8dl_R', 'A9l_L', 'A9l_R', 'A6dl_L', 'A6dl_R', 'A6m_L', 'A6m_R', 'A9m_L', 'A9m_R', 'A10m_L', 'A10m_R', 'A9/46d_L', 'A9/46d_R', 'IFJ_L', 'IFJ_R', 'A46_L', 'A46_R', 'A9/46v_L', 'A9/46v_R', 'A8vl_L', 'A8vl_R', 'A6vl_L', 'A6vl_R', 'A10l_L', 'A10l_R', 'A44d_L', 'A44d_R', 'IFS_L', 'IFS_R', 'A45c_L', 'A45c_R', 'A45r_L', 'A45r_R', 'A44op_L', 'A44op_R', 'A44v_L', 'A44v_R', 'A14m_L', 'A14m_R', 'A12/47o_L', 'A12/47o_R', 'A11l_L', 'A11l_R', 'A11m_L', 'A11m_R', 'A13_L', 'A13_R', 'A12/47l_L', 'A12/47l_R', 'A4hf_L', 'A4hf_R', 'A6cdl_L', 'A6cdl_R', 'A4ul_L', 'A4ul_R', 'A4t_L', 'A4t_R', 'A4tl_L', 'A4tl_R', 'A6cvl_L', 'A6cvl_R', 'A1/2/3ll_L', 'A1/2/3ll_R', 'A4ll_L', 'A4ll_R', 'A38m_L', 'A38m_R', 'A41/42_L', 'A41/42_R', 'TE1.0/TE1.2_L', 'TE1.0/TE1.2_R', 'A22c_L', 'A22c_R', 'A38l_L', 'A38l_R', 'A22r_L', 'A22r_R', 'A21c_L', 'A21c_R', 'A21r_L', 'A21r_R', 'A37dl_L', 'A37dl_R', 'aSTS_L', 'aSTS_R', 'A20iv_L', 'A20iv_R', 'A37elv_L', 'A37elv_R', 'A20r_L', 'A20r_R', 'A20il_L', 'A20
# ...

# %%
test = df.set_index('Subject_ID')
inds = test.index

# %%
df = pd.DataFrame()
for j, ind in enumerate(inds):
    sub = test.loc[[ind]]
    for i, pars in enumerate(parname):
        col_name = 'zReHo_'+str(pars)
        if col_name not in sub:
            sub.insert(2, col_name, np.nan, True)
        sub[col_name] = lis[i+j*246]
    df = pd.concat([df, sub])

# %%
for colnames in df.columns:
    print(colnames)
# Out:
# sws_rw
# sws_rs
# zReHo_lPFtha_R
# zReHo_lPFtha_L
# zReHo_cTtha_R
# zReHo_cTtha_L
# zReHo_Otha_R
# zReHo_Otha_L
# zReHo_PPtha_R
# zReHo_PPtha_L
# zReHo_rTtha_R
# zReHo_rTtha_L
# zReHo_Stha_R
# zReHo_Stha_L
# zReHo_mPMtha_R
# zReHo_mPMtha_L
# zReHo_mPFtha_R
# zReHo_mPFtha_L
# zReHo_dlPu_R
# zReHo_dlPu_L
# zReHo_dCa_R
# zReHo_dCa_L
# zReHo_vmPu_R
# zReHo_vmPu_L
# zReHo_NAC_R
# zReHo_NAC_L
# zReHo_GP_R
# zReHo_GP_L
# zReHo_vCa_R
# zReHo_vCa_L
# zReHo_cHipp_R
# zReHo_cHipp_L
# zReHo_rHipp_R
# zReHo_rHipp_L
# zReHo_lAmyg_R
# zReHo_lAmyg_L
# zReHo_mAmyg_R
# zReHo_mAmyg_L
# zReHo_lsOccG_R
# zReHo_lsOccG_L
# zReHo_msOccG_R
# zReHo_msOccG_L
# zReHo_iOccG_R
# zReHo_iOccG_L
# zReHo_OPC_R
# zReHo_OPC_L
# zReHo_V5/MT+_R
# zReHo_V5/MT+_L
# zReHo_mOccG_R
# zReHo_mOccG_L
# zReHo_vmPOS_R
# zReHo_vmPOS_L
# zReHo_rLinG_R
# zReHo_rLinG_L
# zReHo_cCunG_R
# zReHo_cCunG_L
# zReHo_rCunG_R
# zReHo_rCunG_L
# zReHo_cLinG_R
# zReHo_cLinG_L
# zReHo_A32sg_R
# zReHo_A32sg_L
# zReHo_A23c_R
# zReHo_A23c_L
# ...

# %%
df.columns.get_loc('zReHo_lsOccG_R')
# Out:
# 38

# %%
df.columns.get_loc('zReHo_A8m_L')
# Out:
# 247

# %%
df.drop(df.columns[38:247], axis = 1, inplace = True)

# %%
df.shape
# Out:
# (118, 1934)

# %%
for colnames in df.columns:
    print(colnames)
# Out:
# sws_rw
# sws_rs
# zReHo_lPFtha_R
# zReHo_lPFtha_L
# zReHo_cTtha_R
# zReHo_cTtha_L
# zReHo_Otha_R
# zReHo_Otha_L
# zReHo_PPtha_R
# zReHo_PPtha_L
# zReHo_rTtha_R
# zReHo_rTtha_L
# zReHo_Stha_R
# zReHo_Stha_L
# zReHo_mPMtha_R
# zReHo_mPMtha_L
# zReHo_mPFtha_R
# zReHo_mPFtha_L
# zReHo_dlPu_R
# zReHo_dlPu_L
# zReHo_dCa_R
# zReHo_dCa_L
# zReHo_vmPu_R
# zReHo_vmPu_L
# zReHo_NAC_R
# zReHo_NAC_L
# zReHo_GP_R
# zReHo_GP_L
# zReHo_vCa_R
# zReHo_vCa_L
# zReHo_cHipp_R
# zReHo_cHipp_L
# zReHo_rHipp_R
# zReHo_rHipp_L
# zReHo_lAmyg_R
# zReHo_lAmyg_L
# zReHo_mAmyg_R
# zReHo_mAmyg_L
# zReHo_A8m_L
# zfALFF_lPFtha_R
# zfALFF_lPFtha_L
# zfALFF_cTtha_R
# zfALFF_cTtha_L
# zfALFF_Otha_R
# zfALFF_Otha_L
# zfALFF_PPtha_R
# zfALFF_PPtha_L
# zfALFF_rTtha_R
# zfALFF_rTtha_L
# zfALFF_Stha_R
# zfALFF_Stha_L
# zfALFF_mPMtha_R
# zfALFF_mPMtha_L
# zfALFF_mPFtha_R
# zfALFF_mPFtha_L
# zfALFF_dlPu_R
# zfALFF_dlPu_L
# zfALFF_dCa_R
# zfALFF_dCa_L
# zfALFF_vmPu_R
# zfALFF_vmPu_L
# zfALFF_NAC_R
# zfALFF_NAC_L
# zfALFF_GP_R
# ...

# %%
df.to_csv('df with Schaefer400_DCwei-DCbin-ReHo-ALFF-fALFF_and_BN DCwei-DCbin-ALFF-fALFF-ReHo.csv')

# %%
df.to_csv('df_with_all_Schaefer400_BN.csv')
