# %%
import numpy as np
import pandas as pd
import os, shutil

# %%
df = pd.read_csv("df_with_all_Schaefer400_BN.csv")
df.head()
# Out:
#   Subject_ID  sws_rw    sws_rs  zReHo_lPFtha_R  zReHo_lPFtha_L  zReHo_cTtha_R  \
# 0   sub-0015     3.4  1.666667       -0.680650       -0.740437      -0.698144
# 1   sub-0085     2.8  2.166667       -0.607122       -0.614975      -0.431298
# 2   sub-0134     3.8  2.000000       -0.263834       -0.493474      -0.278857
# 3   sub-0152     4.0  1.666667        0.258873        0.978757       0.155146
# 4   sub-0260     3.8  2.500000       -0.338928       -0.980045      -0.135230
#
#    zReHo_cTtha_L  zReHo_Otha_R  zReHo_Otha_L  zReHo_PPtha_R  ...  \
# 0      -0.650759     -0.733759     -0.700806      -0.594061  ...
# 1      -0.432305     -0.471722     -0.649952      -0.509859  ...
# 2      -0.294843     -0.368193     -0.633978      -0.544125  ...
# 3       0.000891      0.075672     -0.116517      -0.169480  ...
# 4      -0.253972     -0.105502     -0.099361      -0.202247  ...
#
#    zReHo_17Networks_RH_DorsAttnA_SPL_3  zReHo_17Networks_RH_DorsAttnA_SPL_2  \
# ...

# %%
for colname in df.columns:
    print(colname)
# Out:
# Subject_ID
# sws_rw
# sws_rs
# zReHo_lPFtha_R
# zReHo_lPFtha_L
# zReHo_cTtha_R
# zReHo_cTtha_L
# zReHo_Otha_R
# zReHo_Otha_L
# zReHo_PPtha_R
# zReHo_PPtha_L
# zReHo_rTtha_R
# zReHo_rTtha_L
# zReHo_Stha_R
# zReHo_Stha_L
# zReHo_mPMtha_R
# zReHo_mPMtha_L
# zReHo_mPFtha_R
# zReHo_mPFtha_L
# zReHo_dlPu_R
# zReHo_dlPu_L
# zReHo_dCa_R
# zReHo_dCa_L
# zReHo_vmPu_R
# zReHo_vmPu_L
# zReHo_NAC_R
# zReHo_NAC_L
# zReHo_GP_R
# zReHo_GP_L
# zReHo_vCa_R
# zReHo_vCa_L
# zReHo_cHipp_R
# zReHo_cHipp_L
# zReHo_rHipp_R
# zReHo_rHipp_L
# zReHo_lAmyg_R
# zReHo_lAmyg_L
# zReHo_mAmyg_R
# zReHo_mAmyg_L
# zReHo_A8m_L
# zfALFF_lPFtha_R
# zfALFF_lPFtha_L
# zfALFF_cTtha_R
# zfALFF_cTtha_L
# zfALFF_Otha_R
# zfALFF_Otha_L
# zfALFF_PPtha_R
# zfALFF_PPtha_L
# zfALFF_rTtha_R
# zfALFF_rTtha_L
# zfALFF_Stha_R
# zfALFF_Stha_L
# zfALFF_mPMtha_R
# zfALFF_mPMtha_L
# zfALFF_mPFtha_R
# zfALFF_mPFtha_L
# zfALFF_dlPu_R
# zfALFF_dlPu_L
# zfALFF_dCa_R
# zfALFF_dCa_L
# zfALFF_vmPu_R
# zfALFF_vmPu_L
# zfALFF_NAC_R
# zfALFF_NAC_L
# ...

# %%
src = '/media/tara/HD710PRO/Thesis/FreesurferOutput'

# %%
s = os.listdir(src)

# %%
df2 = df.set_index('Subject_ID')
for i,folder1 in enumerate(s):
    path1 = src + '/' + folder1
    ls = os.listdir(path1)
    for folder2 in ls:
        dest = path1 + '/' + folder2
        fso = pd.read_csv(dest + '/' + 'parc_nodes.csv')
        columns = fso.columns[5:7]
        strucIDs = fso['structureID']
        for strucID in strucIDs:
            for col in columns:
                measurement = strucID + '_' + col
                value = fso[fso['structureID'] == strucID][[col]].values[0][0] 
                if measurement not in df2:
                    df2.insert(7, measurement, np.nan, allow_duplicates=False) 
                df2.loc[s[i].split('.')[0],measurement] = value

# %%
df2.head()
# Out:
#             sws_rw    sws_rs  zReHo_lPFtha_R  zReHo_lPFtha_L  zReHo_cTtha_R  \
# Subject_ID
# sub-0015       3.4  1.666667       -0.680650       -0.740437      -0.698144
# sub-0085       2.8  2.166667       -0.607122       -0.614975      -0.431298
# sub-0134       3.8  2.000000       -0.263834       -0.493474      -0.278857
# sub-0152       4.0  1.666667        0.258873        0.978757       0.155146
# sub-0260       3.8  2.500000       -0.338928       -0.980045      -0.135230
#
#             zReHo_cTtha_L  zReHo_Otha_R  \
# Subject_ID
# sub-0015        -0.650759     -0.733759
# sub-0085        -0.432305     -0.471722
# sub-0134        -0.294843     -0.368193
# sub-0152         0.000891      0.075672
# sub-0260        -0.253972     -0.105502
#
#             rh.17Networks_RH_TempPar_10.label_thickness  \
# Subject_ID
# sub-0015                                         3.2153
# sub-0085                                         3.2421
# ...

# %%
df = df2[df2.columns.drop(list(df.filter(regex='A8m_L')))]
df.head()
# Out:
#             sws_rw    sws_rs  zReHo_lPFtha_R  zReHo_lPFtha_L  zReHo_cTtha_R  \
# Subject_ID
# sub-0015       3.4  1.666667       -0.680650       -0.740437      -0.698144
# sub-0085       2.8  2.166667       -0.607122       -0.614975      -0.431298
# sub-0134       3.8  2.000000       -0.263834       -0.493474      -0.278857
# sub-0152       4.0  1.666667        0.258873        0.978757       0.155146
# sub-0260       3.8  2.500000       -0.338928       -0.980045      -0.135230
#
#             zReHo_cTtha_L  zReHo_Otha_R  \
# Subject_ID
# sub-0015        -0.650759     -0.733759
# sub-0085        -0.432305     -0.471722
# sub-0134        -0.294843     -0.368193
# sub-0152         0.000891      0.075672
# sub-0260        -0.253972     -0.105502
#
#             rh.17Networks_RH_TempPar_10.label_thickness  \
# Subject_ID
# sub-0015                                         3.2153
# sub-0085                                         3.2421
# ...

# %%
df.to_csv("finaldf_Sch400_BN_fs.csv")

# %%
df4 = pd.read_csv("df4.csv")
df4.head()
# Out:
#    Unnamed: 0 Subject_ID    sws_ms    sws_fa  sws_gb  sws_total
# 0           0   sub-0015  1.833333  1.000000     1.4   1.513333
# 1           1   sub-0085  3.500000  2.166667     2.8   2.560000
# 2           2   sub-0134  2.166667  2.166667     3.4   2.346667
# 3           3   sub-0152  1.500000  2.500000     3.0   2.066667
# 4           4   sub-0260  3.600000  3.000000     4.0   3.120000

# %%
df = pd.read_csv("finaldf_Sch400_BN_fs.csv")
df.shape
# Out:
# (131, 2734)

# %%
#df.to_excel("~/Desktop/finaldf.xlsx")

# %%
column_to_move = df.pop("sws_fa")

# %%
df.insert(2, "sws_fa", column_to_move)

# %%
column_to_move = df.pop("sws_ms")

# %%
df.insert(2, "sws_ms", column_to_move)

# %%
column_to_move = df.pop("sws_gb")

# %%
df.insert(2, "sws_gb", column_to_move)

# %%
column_to_move = df.pop("sws_total")

# %%
df.head()
# Out:
#   Subject_ID  sws_rw  sws_gb    sws_ms    sws_fa    sws_rs  zReHo_lPFtha_R  \
# 0   sub-0015     3.4     1.4  1.833333  1.000000  1.666667       -0.680650
# 1   sub-0085     2.8     2.8  3.500000  2.166667  2.166667       -0.607122
# 2   sub-0134     3.8     3.4  2.166667  2.166667  2.000000       -0.263834
# 3   sub-0152     4.0     3.0  1.500000  2.500000  1.666667        0.258873
# 4   sub-0260     3.8     4.0  3.600000  3.000000  2.500000       -0.338928
#
#    zReHo_lPFtha_L  zReHo_cTtha_R  zReHo_cTtha_L  ...  \
# 0       -0.740437      -0.698144      -0.650759  ...
# 1       -0.614975      -0.431298      -0.432305  ...
# 2       -0.493474      -0.278857      -0.294843  ...
# 3        0.978757       0.155146       0.000891  ...
# 4       -0.980045      -0.135230      -0.253972  ...
#
#    zReHo_17Networks_RH_DorsAttnA_SPL_3  zReHo_17Networks_RH_DorsAttnA_SPL_2  \
# 0                             0.632937                             0.484317
# ...

# %%
df.insert(6, "sws_total", column_to_move)

# %%
df.head()
# Out:
#   Subject_ID  sws_rw  sws_gb    sws_ms    sws_fa    sws_rs  sws_total  \
# 0   sub-0015     3.4     1.4  1.833333  1.000000  1.666667   1.513333
# 1   sub-0085     2.8     2.8  3.500000  2.166667  2.166667   2.560000
# 2   sub-0134     3.8     3.4  2.166667  2.166667  2.000000   2.346667
# 3   sub-0152     4.0     3.0  1.500000  2.500000  1.666667   2.066667
# 4   sub-0260     3.8     4.0  3.600000  3.000000  2.500000   3.120000
#
#    zReHo_lPFtha_R  zReHo_lPFtha_L  zReHo_cTtha_R  ...  \
# 0       -0.680650       -0.740437      -0.698144  ...
# 1       -0.607122       -0.614975      -0.431298  ...
# 2       -0.263834       -0.493474      -0.278857  ...
# 3        0.258873        0.978757       0.155146  ...
# 4       -0.338928       -0.980045      -0.135230  ...
#
#    zReHo_17Networks_RH_DorsAttnA_SPL_3  zReHo_17Networks_RH_DorsAttnA_SPL_2  \
# 0                             0.632937                             0.484317
# ...

# %%
df.to_excel("~/Desktop/finaldf.xlsx")

# %%
df = pd.read_csv('df with Schaefer400_DCwei-DCbin-ReHo-ALFF-fALFF_and_BN DCwei-DCbin-ALFF-fALFF-ReHo.csv')
df.head()
# Out:
#   Subject_ID  sws_rw    sws_rs  zReHo_lPFtha_R  zReHo_lPFtha_L  zReHo_cTtha_R  \
# 0   sub-0015     3.4  1.666667       -0.680650       -0.740437      -0.698144
# 1   sub-0085     2.8  2.166667       -0.607122       -0.614975      -0.431298
# 2   sub-0134     3.8  2.000000       -0.263834       -0.493474      -0.278857
# 3   sub-0152     4.0  1.666667        0.258873        0.978757       0.155146
# 4   sub-0260     3.8  2.500000       -0.338928       -0.980045      -0.135230
#
#    zReHo_cTtha_L  zReHo_Otha_R  zReHo_Otha_L  zReHo_PPtha_R  ...  \
# 0      -0.650759     -0.733759     -0.700806      -0.594061  ...
# 1      -0.432305     -0.471722     -0.649952      -0.509859  ...
# 2      -0.294843     -0.368193     -0.633978      -0.544125  ...
# 3       0.000891      0.075672     -0.116517      -0.169480  ...
# 4      -0.253972     -0.105502     -0.099361      -0.202247  ...
#
#    zReHo_17Networks_RH_DorsAttnA_SPL_3  zReHo_17Networks_RH_DorsAttnA_SPL_2  \
# ...

# %%
i = 0
for colname in df.columns:
    if colname.find('zReHo_')==0:
        i = i+1
print(i)
# Out:
# 180
