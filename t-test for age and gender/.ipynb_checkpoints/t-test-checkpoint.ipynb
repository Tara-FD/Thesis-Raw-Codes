# %%
# %config Completer.use_jedi = False

# %%
import pandas as pd
import numpy as np
import os
import nilearn
from nilearn import masking
from nilearn import plotting
from nilearn import image
from scipy import stats

# %%
df = pd.read_csv('df_for_RF.csv')
df.drop('Unnamed: 0', axis=1, inplace=True)
df.head()
# Out:
#   Subject_ID  diagadhd  CHILDgender  zfALFF_17Networks_9  zfALFF_17Networks_2  \
# 0   sub-0015         0            1            -0.787030            -0.445804
# 1   sub-0085         0            0            -0.601078            -0.304966
# 2   sub-0134         0            1            -0.799635            -0.231216
# 3   sub-0152         0            0            -0.485006            -0.223685
# 4   sub-0260         1            1            -0.853856            -0.356149
#
#    zfALFF_lPFtha_L  zfALFF_cTtha_L  zfALFF_Otha_L  zfALFF_rTtha_R  \
# 0        -0.929277       -0.743303      -0.701746       -0.843242
# 1        -0.397031       -0.381863      -0.449357       -0.341996
# 2        -0.840667       -0.901478      -0.487365       -0.710494
# 3        -0.294288       -0.634390      -0.597999       -0.640255
# 4        -0.863769       -0.617213      -0.475704       -0.797962
#
#    zfALFF_rTtha_L  ...  zDCwei_17Networks_RH_SomMotA_6  \
# 0       -0.764751  ...                        0.570004
# 1       -0.347692  ...                        0.280915
# 2       -0.512793  ...                        0.631763
# 3       -0.425914  ...                       -0.034122
# 4       -0.641054  ...                       -0.181578
#
#    zDCwei_17Networks_LH_DefaultC_PHC_3  zDCwei_17Networks_LH_DefaultB_Temp_5  \
# 0                            -0.130038                             -0.047269
# 1                            -0.321277                             -0.009029
# 2                             0.249275                              0.492542
# 3                             0.082488                              0.263105
# 4                             0.304288                              0.449225
#
#    zDCwei_17Networks_LH_ContB_Temp_2  \
# 0                           0.388094
# 1                          -0.196261
# 2                           0.465131
# 3                           0.375573
# 4                           0.739805
#
#    zDCwei_17Networks_LH_SalVentAttnA_FrMed_2  \
# 0                                   0.158019
# 1                                   0.080881
# 2                                   0.149572
# 3                                  -0.179384
# 4                                   0.125963
#
#    zDCwei_17Networks_LH_SalVentAttnA_FrMed_1  \
# 0                                   0.257226
# 1                                   0.170051
# 2                                   0.168241
# 3                                   0.009714
# 4                                   0.116520
#
#    zDCwei_17Networks_LH_SalVentAttnA_ParMed_1  \
# 0                                    0.094419
# 1                                    0.153607
# 2                                    0.310641
# 3                                    0.205987
# 4                                    0.293805
#
#    zDCwei_17Networks_LH_SalVentAttnA_ParOper_1  \
# 0                                     0.157887
# 1                                     0.192767
# 2                                     0.219820
# 3                                     0.018744
# 4                                     0.122458
#
#    zDCwei_17Networks_LH_DorsAttnB_PostC_1  \
# 0                                0.042376
# 1                               -0.052853
# 2                                0.148504
# 3                                0.069715
# 4                               -0.000745
#
#    zDCwei_17Networks_LH_DorsAttnA_TempOcc_2
# 0                                 -0.074321
# 1                                  0.049870
# 2                                  0.236822
# 3                                  0.291880
# 4                                  0.174841
#
# [5 rows x 187 columns]

# %%
df_wave = pd.read_csv('finalfinal.csv')
#df_wave.drop('Unnamed: 0', axis=1, inplace=True)
df_wave.head()
# Out:
#   Subject_ID imaging waves  snr_total  cpadhd_raw  z-score_cpadhd  \
# 0   sub-0015     ses-wave3  11.837327           0       -1.388889
# 1   sub-0085     ses-wave2  11.131926           0       -1.388889
# 2   sub-0134     ses-wave3  10.562882           0       -0.866667
# 3   sub-0152     ses-wave2  12.745413           2       -0.200000
# 4   sub-0260     ses-wave2  11.458236          14        3.800000
#
#    t-score_cpadhd  conners_adhd_dich  sws_rw    sws_rs    sws_ms  ...  \
# 0       36.111112                  0     3.4  1.666667  1.833333  ...
# 1       36.111112                  0     2.8  2.166667  3.500000  ...
# 2       41.333334                  0     3.8  2.000000  2.166667  ...
# 3       48.000000                  0     4.0  1.666667  1.500000  ...
# 4       88.000000                  1     3.8  2.500000  3.600000  ...
#
#    zReHo_17Networks_RH_DorsAttnB_TempOcc_1  \
# 0                                 0.670098
# 1                                 0.799444
# 2                                 0.826863
# 3                                -0.160882
# 4                                 0.427443
#
#    zReHo_17Networks_RH_DorsAttnA_SPL_8  zReHo_17Networks_RH_DorsAttnA_SPL_7  \
# 0                             0.428403                             0.606164
# 1                             0.410584                             0.882690
# 2                            -0.042615                             0.413310
# 3                            -0.084407                            -0.048464
# 4                             0.354036                             0.827683
#
#    zReHo_17Networks_RH_DorsAttnA_SPL_6  zReHo_17Networks_RH_DorsAttnA_SPL_5  \
# 0                             0.367194                             0.340738
# 1                             1.497676                             1.595270
# 2                             0.882732                             0.427876
# 3                             0.120764                             0.165466
# 4                             0.654600                             0.824818
#
#    zReHo_17Networks_RH_DorsAttnA_SPL_4  zReHo_17Networks_RH_DorsAttnA_SPL_3  \
# 0                             0.339185                             0.632937
# 1                             1.006997                             1.272547
# 2                             0.378849                             0.510567
# 3                            -0.156583                            -0.357383
# 4                             0.137409                             0.387290
#
#    zReHo_17Networks_RH_DorsAttnA_SPL_2  zReHo_17Networks_RH_DorsAttnA_SPL_1  \
# 0                             0.484317                             0.878408
# 1                             0.551014                             1.482868
# 2                             0.323151                             0.741446
# 3                            -0.159408                             0.082269
# 4                             0.171799                             0.892404
#
#    zReHo_17Networks_RH_DorsAttnA_ParOcc_3
# 0                                0.776844
# 1                                1.110642
# 2                                0.395507
# 3                                0.183071
# 4                                0.532177
#
# [5 rows x 1024 columns]

# %%
#df_wave['Subject_ID'].loc[0]
#df['Subject_ID'].loc[0]

# %%
df.insert(1, 'age', 'NaN')

# %%
df.head()
# Out:
#   Subject_ID  age  diagadhd  CHILDgender  zfALFF_17Networks_9  \
# 0   sub-0015  NaN         0            1            -0.787030
# 1   sub-0085  NaN         0            0            -0.601078
# 2   sub-0134  NaN         0            1            -0.799635
# 3   sub-0152  NaN         0            0            -0.485006
# 4   sub-0260  NaN         1            1            -0.853856
#
#    zfALFF_17Networks_2  zfALFF_lPFtha_L  zfALFF_cTtha_L  zfALFF_Otha_L  \
# 0            -0.445804        -0.929277       -0.743303      -0.701746
# 1            -0.304966        -0.397031       -0.381863      -0.449357
# 2            -0.231216        -0.840667       -0.901478      -0.487365
# 3            -0.223685        -0.294288       -0.634390      -0.597999
# 4            -0.356149        -0.863769       -0.617213      -0.475704
#
#    zfALFF_rTtha_R  ...  zDCwei_17Networks_RH_SomMotA_6  \
# 0       -0.843242  ...                        0.570004
# 1       -0.341996  ...                        0.280915
# 2       -0.710494  ...                        0.631763
# 3       -0.640255  ...                       -0.034122
# 4       -0.797962  ...                       -0.181578
#
#    zDCwei_17Networks_LH_DefaultC_PHC_3  zDCwei_17Networks_LH_DefaultB_Temp_5  \
# 0                            -0.130038                             -0.047269
# 1                            -0.321277                             -0.009029
# 2                             0.249275                              0.492542
# 3                             0.082488                              0.263105
# 4                             0.304288                              0.449225
#
#    zDCwei_17Networks_LH_ContB_Temp_2  \
# 0                           0.388094
# 1                          -0.196261
# 2                           0.465131
# 3                           0.375573
# 4                           0.739805
#
#    zDCwei_17Networks_LH_SalVentAttnA_FrMed_2  \
# 0                                   0.158019
# 1                                   0.080881
# 2                                   0.149572
# 3                                  -0.179384
# 4                                   0.125963
#
#    zDCwei_17Networks_LH_SalVentAttnA_FrMed_1  \
# 0                                   0.257226
# 1                                   0.170051
# 2                                   0.168241
# 3                                   0.009714
# 4                                   0.116520
#
#    zDCwei_17Networks_LH_SalVentAttnA_ParMed_1  \
# 0                                    0.094419
# 1                                    0.153607
# 2                                    0.310641
# 3                                    0.205987
# 4                                    0.293805
#
#    zDCwei_17Networks_LH_SalVentAttnA_ParOper_1  \
# 0                                     0.157887
# 1                                     0.192767
# 2                                     0.219820
# 3                                     0.018744
# 4                                     0.122458
#
#    zDCwei_17Networks_LH_DorsAttnB_PostC_1  \
# 0                                0.042376
# 1                               -0.052853
# 2                                0.148504
# 3                                0.069715
# 4                               -0.000745
#
#    zDCwei_17Networks_LH_DorsAttnA_TempOcc_2
# 0                                 -0.074321
# 1                                  0.049870
# 2                                  0.236822
# 3                                  0.291880
# 4                                  0.174841
#
# [5 rows x 188 columns]

# %%
j=0
for i, sub in enumerate(df_wave['Subject_ID']):
    for subb in df['Subject_ID']:
        if sub == subb:
            if df_wave['imaging waves'].loc[i] == 'ses-wave2':
                df['age'].loc[i] = 11.5
            elif df_wave['imaging waves'].loc[i] == 'ses-wave3':
                df['age'].loc[i] = 13
# Out:
# /home/tara/Programming/env/lib/python3.8/site-packages/pandas/core/indexing.py:1636: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
df['age'][df['Subject_ID']== 'sub-0856'] = 11.5
# Out:
# <ipython-input-43-da0a261ede8b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['age'][df['Subject_ID']== 'sub-0856'] = 11.5

# %%
df.head()
# Out:
#   Subject_ID   age  diagadhd  CHILDgender  zfALFF_17Networks_9  \
# 0   sub-0015    13         0            1            -0.787030
# 1   sub-0085  11.5         0            0            -0.601078
# 2   sub-0134    13         0            1            -0.799635
# 3   sub-0152  11.5         0            0            -0.485006
# 4   sub-0260  11.5         1            1            -0.853856
#
#    zfALFF_17Networks_2  zfALFF_lPFtha_L  zfALFF_cTtha_L  zfALFF_Otha_L  \
# 0            -0.445804        -0.929277       -0.743303      -0.701746
# 1            -0.304966        -0.397031       -0.381863      -0.449357
# 2            -0.231216        -0.840667       -0.901478      -0.487365
# 3            -0.223685        -0.294288       -0.634390      -0.597999
# 4            -0.356149        -0.863769       -0.617213      -0.475704
#
#    zfALFF_rTtha_R  ...  zDCwei_17Networks_RH_SomMotA_6  \
# 0       -0.843242  ...                        0.570004
# 1       -0.341996  ...                        0.280915
# 2       -0.710494  ...                        0.631763
# 3       -0.640255  ...                       -0.034122
# 4       -0.797962  ...                       -0.181578
#
#    zDCwei_17Networks_LH_DefaultC_PHC_3  zDCwei_17Networks_LH_DefaultB_Temp_5  \
# 0                            -0.130038                             -0.047269
# 1                            -0.321277                             -0.009029
# 2                             0.249275                              0.492542
# 3                             0.082488                              0.263105
# 4                             0.304288                              0.449225
#
#    zDCwei_17Networks_LH_ContB_Temp_2  \
# 0                           0.388094
# 1                          -0.196261
# 2                           0.465131
# 3                           0.375573
# 4                           0.739805
#
#    zDCwei_17Networks_LH_SalVentAttnA_FrMed_2  \
# 0                                   0.158019
# 1                                   0.080881
# 2                                   0.149572
# 3                                  -0.179384
# 4                                   0.125963
#
#    zDCwei_17Networks_LH_SalVentAttnA_FrMed_1  \
# 0                                   0.257226
# 1                                   0.170051
# 2                                   0.168241
# 3                                   0.009714
# 4                                   0.116520
#
#    zDCwei_17Networks_LH_SalVentAttnA_ParMed_1  \
# 0                                    0.094419
# 1                                    0.153607
# 2                                    0.310641
# 3                                    0.205987
# 4                                    0.293805
#
#    zDCwei_17Networks_LH_SalVentAttnA_ParOper_1  \
# 0                                     0.157887
# 1                                     0.192767
# 2                                     0.219820
# 3                                     0.018744
# 4                                     0.122458
#
#    zDCwei_17Networks_LH_DorsAttnB_PostC_1  \
# 0                                0.042376
# 1                               -0.052853
# 2                                0.148504
# 3                                0.069715
# 4                               -0.000745
#
#    zDCwei_17Networks_LH_DorsAttnA_TempOcc_2
# 0                                 -0.074321
# 1                                  0.049870
# 2                                  0.236822
# 3                                  0.291880
# 4                                  0.174841
#
# [5 rows x 188 columns]

# %%
df_adhd = df[df['diagadhd']==1]
df_adhd.shape
# Out:
# (46, 188)

# %%
df_cn = df[df['diagadhd']==0]
df_cn.shape
# Out:
# (71, 188)

# %% [markdown]
# # gender

# %%
t1 = df_adhd['CHILDgender']
t2 = df_cn['CHILDgender']

# %%
t_value,p_value=stats.ttest_ind(t1,t2)

# %%
print('Test statistic is %f'%float("{:.6f}".format(t_value)))
# Out:
# Test statistic is 3.055818

# %%
print('p-value for two tailed test is %f'%p_value)
# Out:
# p-value for two tailed test is 0.002791

# %%
alpha = 0.05

if p_value<=alpha:
    print('we conclude that the difference between boys and girls is significant')
elif p_value>alpha:
    print('we conclude that the difference between boys and girls is not significant')
# Out:
# we conclude that the difference between boys and girls is significant

# %% [markdown]
# # age

# %%
t1 = df_adhd['age']
t2 = df_cn['age']

# %%
df["age"] = pd.to_numeric(df["age"])

# %%
df["age"]
# Out:
# 0      13.0
# 1      11.5
# 2      13.0
# 3      11.5
# 4      11.5
#        ...
# 112    11.5
# 113    11.5
# 114    11.5
# 115    11.5
# 116    11.5
# Name: age, Length: 117, dtype: float64

# %%
#df_adhd['CHILDgender']
# Out:
# 4      1
# 6      1
# 9      1
# 16     1
# 17     1
# 22     1
# 23     1
# 27     1
# 30     1
# 31     0
# 38     1
# 43     1
# 46     1
# 55     1
# 58     1
# 59     1
# 61     1
# 62     0
# 64     0
# 66     1
# 69     0
# 70     1
# 75     1
# 76     1
# 77     1
# 78     1
# 80     1
# 82     1
# 84     1
# 85     1
# 86     0
# 90     1
# 92     0
# 93     0
# 94     0
# 95     1
# 96     1
# 97     1
# 99     1
# 102    1
# 104    1
# 108    1
# 110    1
# 112    1
# 115    0
# 116    1
# Name: CHILDgender, dtype: int64

# %%
t_value,p_value=stats.ttest_ind(t1,t2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-ca3e4c014d0d> in <module>
# ----> 1 t_value,p_value=stats.ttest_ind(t1,t2)
#
# ~/Programming/env/lib/python3.8/site-packages/scipy/stats/stats.py in ttest_ind(a, b, axis, equal_var, nan_policy, permutations, random_state, alternative, trim)
#    6131
#    6132         if trim == 0:
# -> 6133             v1 = np.var(a, axis, ddof=1)
#    6134             v2 = np.var(b, axis, ddof=1)
#    6135             m1 = np.mean(a, axis)
#
# <__array_function__ internals> in var(*args, **kwargs)
#
# ~/Programming/env/lib/python3.8/site-packages/numpy/core/fromnumeric.py in var(a, axis, dtype, out, ddof, keepdims)
#    3619             return var(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
#    3620
# -> 3621     return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
#    3622                          **kwargs)
#    3623
#
# ~/Programming/env/lib/python3.8/site-packages/numpy/core/_methods.py in _var(a, axis, dtype, out, ddof, keepdims)
#     190     # Note that if dtype is not of inexact type then arraymean will
#     191     # not be either.
# --> 192     arrmean = umr_sum(arr, axis, dtype, keepdims=True)
#     193     if isinstance(arrmean, mu.ndarray):
#     194         arrmean = um.true_divide(
#
# TypeError: can only concatenate str (not "float") to str

# %%
df['age'].iloc[[17]]

# %%
df['age'].values

# %%
df[df['age']=='0']

# %%
df_wave[df_wave['Subject_ID']== 'sub-0856']
# Out:
#    Subject_ID imaging waves  snr_total  cpadhd_raw  z-score_cpadhd  \
# 17   sub-0856     ses-wave2  11.839517          16        4.466667
#
#     t-score_cpadhd  conners_adhd_dich  sws_rw    sws_rs  sws_ms  ...  \
# 17       94.666667                  1     3.0  2.833333     3.0  ...
#
#     zReHo_17Networks_RH_DorsAttnB_TempOcc_1  \
# 17                                 1.432148
#
#     zReHo_17Networks_RH_DorsAttnA_SPL_8  zReHo_17Networks_RH_DorsAttnA_SPL_7  \
# 17                             1.594856                             0.880394
#
#     zReHo_17Networks_RH_DorsAttnA_SPL_6  zReHo_17Networks_RH_DorsAttnA_SPL_5  \
# 17                             0.780194                             2.015546
#
#     zReHo_17Networks_RH_DorsAttnA_SPL_4  zReHo_17Networks_RH_DorsAttnA_SPL_3  \
# 17                              1.05233                              1.37248
#
#     zReHo_17Networks_RH_DorsAttnA_SPL_2  zReHo_17Networks_RH_DorsAttnA_SPL_1  \
# 17                             0.639157                             1.491111
#
#     zReHo_17Networks_RH_DorsAttnA_ParOcc_3
# 17                                1.242057
#
# [1 rows x 1024 columns]

# %%
df[df['Subject_ID']== 'sub-0856']
# Out:
#    Subject_ID  age  diagadhd  CHILDgender  zfALFF_17Networks_9  \
# 16   sub-0856  NaN         1            1            -0.157126
#
#     zfALFF_17Networks_2  zfALFF_lPFtha_L  zfALFF_cTtha_L  zfALFF_Otha_L  \
# 16             0.110511         -0.65897       -0.606422      -0.697269
#
#     zfALFF_rTtha_R  ...  zDCwei_17Networks_RH_SomMotA_6  \
# 16       -0.465275  ...                         0.39759
#
#     zDCwei_17Networks_LH_DefaultC_PHC_3  zDCwei_17Networks_LH_DefaultB_Temp_5  \
# 16                            -0.380469                             -0.097885
#
#     zDCwei_17Networks_LH_ContB_Temp_2  \
# 16                          -0.011879
#
#     zDCwei_17Networks_LH_SalVentAttnA_FrMed_2  \
# 16                                   0.061109
#
#     zDCwei_17Networks_LH_SalVentAttnA_FrMed_1  \
# 16                                   -0.12133
#
#     zDCwei_17Networks_LH_SalVentAttnA_ParMed_1  \
# 16                                   -0.012883
#
#     zDCwei_17Networks_LH_SalVentAttnA_ParOper_1  \
# 16                                    -0.063305
#
#     zDCwei_17Networks_LH_DorsAttnB_PostC_1  \
# 16                               -0.196291
#
#     zDCwei_17Networks_LH_DorsAttnA_TempOcc_2
# 16                                 -0.203779
#
# [1 rows x 188 columns]

# %%
df['age'][df['Subject_ID']== 'sub-0856'] = 11.5
# Out:
# <ipython-input-15-da0a261ede8b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['age'][df['Subject_ID']== 'sub-0856'] = 11.5

# %%
df[df['Subject_ID']== 'sub-0856']
# Out:
#    Subject_ID   age  diagadhd  CHILDgender  zfALFF_17Networks_9  \
# 16   sub-0856  11.5         1            1            -0.157126
#
#     zfALFF_17Networks_2  zfALFF_lPFtha_L  zfALFF_cTtha_L  zfALFF_Otha_L  \
# 16             0.110511         -0.65897       -0.606422      -0.697269
#
#     zfALFF_rTtha_R  ...  zDCwei_17Networks_RH_SomMotA_6  \
# 16       -0.465275  ...                         0.39759
#
#     zDCwei_17Networks_LH_DefaultC_PHC_3  zDCwei_17Networks_LH_DefaultB_Temp_5  \
# 16                            -0.380469                             -0.097885
#
#     zDCwei_17Networks_LH_ContB_Temp_2  \
# 16                          -0.011879
#
#     zDCwei_17Networks_LH_SalVentAttnA_FrMed_2  \
# 16                                   0.061109
#
#     zDCwei_17Networks_LH_SalVentAttnA_FrMed_1  \
# 16                                   -0.12133
#
#     zDCwei_17Networks_LH_SalVentAttnA_ParMed_1  \
# 16                                   -0.012883
#
#     zDCwei_17Networks_LH_SalVentAttnA_ParOper_1  \
# 16                                    -0.063305
#
#     zDCwei_17Networks_LH_DorsAttnB_PostC_1  \
# 16                               -0.196291
#
#     zDCwei_17Networks_LH_DorsAttnA_TempOcc_2
# 16                                 -0.203779
#
# [1 rows x 188 columns]
